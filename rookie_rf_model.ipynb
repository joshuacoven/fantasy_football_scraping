# %% [markdown]
# # To do

# %% [markdown]
# * Clean up output
# * Make functions for a lot of this

# %% [markdown]
# # Import packages and define functions

# %%
###################### Import Packages #############################################
import requests
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
import copy
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from ffb_functions import *


pd.options.display.max_rows = 999
pd.set_option('display.max_columns', 500)

####################################### Functions ######################################
shifted = pd.read_csv('rookie_database.csv')
shifted = shifted.rename(columns = {'PPR': 'pts_next_year'})
################ Seperate database by position ####################################################
pos_dict = {}
for pos in ['TE', 'WR', 'RB', 'QB']:
    pos_dict[pos] = shifted.loc[shifted.FantPos == pos].reset_index(drop = True)
    
    # center age to prepare for power relationship to reduce multicollinearity
    pos_dict[pos]['Age'] = pos_dict[pos]['Age'] - np.mean(pos_dict[pos]['Age']) 
    pos_dict[pos]['agesq'] = pos_dict[pos]['Age'] * pos_dict[pos]['Age']
    pos_dict[pos] = pos_dict[pos].drop(['College', 'School', 'Conf', 'FantPos'
                                       , 'Ht'], axis = 1)

# %% [markdown]
# # Random Forest Regressions

# %%
all_cross_val = {}
for sz in [8]:
    cross_val = {}
    ## chose the year one before, ex: want to predict for 2019 season choose 2018, last year of data
    for predict_year in [2014, 2015, 2016, 2017, 2018, 2019
                        ]:
        
        #### rf model
        final_dict = rf_model(pos_dict, predict_year, sz)

        ##### plot and evaluate outputs #################################
        results_frame = pd.DataFrame()
        for pos in ['WR', 'RB', 'QB', 'TE']:
            testtest = final_dict[pos].sort_values(['prediction'], ascending = False
                )[['Names', 'Overall', 'prediction', 'pts_next_year']].reset_index(drop = True)
            testtest['Year'] = predict_year
            testtest['window_size'] = sz
            testtest['ADP_Pos_Rank'] = testtest['Overall'].rank()
            testtest['Predicted_Pos_Rank'] = testtest['prediction'].rank(ascending = False)
            testtest['Actual_Next_Pos_Rank'] = testtest['pts_next_year'].rank(ascending = False)
            
            results_frame.loc[len(results_frame), 'Year'] = predict_year
            results_frame.loc[len(results_frame) - 1, 'Pos'] = pos
            val = sum((testtest['ADP_Pos_Rank'] - testtest['Actual_Next_Pos_Rank'])**2)
            results_frame.loc[len(results_frame) - 1, 'ADP_As_Predictor'] = val
            val = sum((testtest['Predicted_Pos_Rank'] - testtest['Actual_Next_Pos_Rank'])**2)
            results_frame.loc[len(results_frame) - 1, 'Model_As_Predictor'] = val
            cross_val[predict_year] = results_frame
            
            print(pos)
            print('residual rank')
            plt.scatter(testtest['Actual_Next_Pos_Rank'], testtest['Actual_Next_Pos_Rank'] - testtest['Predicted_Pos_Rank'], label = 'Model')
            plt.scatter(testtest['Actual_Next_Pos_Rank'], testtest['Actual_Next_Pos_Rank'] - testtest['ADP_Pos_Rank'], label = 'ADP')
            plt.hlines(0, 0, 60, label = 'actual')
            plt.legend(loc='upper left')
            plt.title('above is the model/adp predicting they would do better than they did')
            plt.show()
            
            print('points fit')
            plt.scatter(testtest['prediction'], testtest['pts_next_year'])
            x = testtest['prediction']
            y = testtest['pts_next_year']
            plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 1))(np.unique(x)))
            plt.title('points predicted vs actual performance')
            plt.show()
            
        print(results_frame)
        
    all_cross_val[sz] = cross_val
# Out:
# TE
# Variable: Rec                  Importance: 0.15
# Variable: Overall              Importance: 0.12
# Variable: Pick                 Importance: 0.09
# Variable: Broad_Jump           Importance: 0.07
# Variable: Three_Cone           Importance: 0.07
# Variable: ReYds                Importance: 0.07
# Variable: Wt                   Importance: 0.06
# Variable: Dash                 Importance: 0.05
# Variable: agesq                Importance: 0.04
# Variable: NEP                  Importance: 0.04
# Variable: Vertical             Importance: 0.03
# Variable: Bench                Importance: 0.03
# Variable: Shuttle              Importance: 0.03
# Variable: height               Importance: 0.03
# Variable: ReTD                 Importance: 0.03
# Variable: TEN                  Importance: 0.02
# Variable: Age                  Importance: 0.01
# Variable: G                    Importance: 0.01
# Variable: RuYds                Importance: 0.01
# Variable: CIN                  Importance: 0.01
# Variable: MIN                  Importance: 0.01
# Variable: Cmp                  Importance: 0.0
# Variable: PaAtt                Importance: 0.0
# Variable: Pct                  Importance: 0.0
# Variable: PaYds                Importance: 0.0
# Variable: PaTD                 Importance: 0.0
# Variable: Int                  Importance: 0.0
# Variable: RuTD                 Importance: 0.0
# Variable: RuAtt                Importance: 0.0
# Variable: Std.Dev              Importance: 0.0
# Variable: ARI                  Importance: 0.0
# Variable: ATL                  Importance: 0.0
# Variable: BAL                  Importance: 0.0
# Variable: CAR                  Importance: 0.0
# Variable: CHI                  Importance: 0.0
# Variable: CLE                  Importance: 0.0
# Variable: DEN                  Importance: 0.0
# Variable: DET                  Importance: 0.0
# Variable: FA                   Importance: 0.0
# Variable: GNB                  Importance: 0.0
# Variable: HOU                  Importance: 0.0
# Variable: IND                  Importance: 0.0
# Variable: JAX                  Importance: 0.0
# Variable: KAN                  Importance: 0.0
# Variable: LAR                  Importance: 0.0
# Variable: MIA                  Importance: 0.0
# Variable: NYG                  Importance: 0.0
# Variable: NYJ                  Importance: 0.0
# Variable: OAK                  Importance: 0.0
# Variable: PHI                  Importance: 0.0
# Variable: PIT                  Importance: 0.0
# Variable: RAM                  Importance: 0.0
# Variable: SDC                  Importance: 0.0
# Variable: SEA                  Importance: 0.0
# Variable: SFO                  Importance: 0.0
# Variable: STL                  Importance: 0.0
# Variable: TBB                  Importance: 0.0
# WR
# Variable: Overall              Importance: 0.25
# Variable: Pick                 Importance: 0.12
# Variable: Wt                   Importance: 0.06
# Variable: Dash                 Importance: 0.05
# Variable: RuYds                Importance: 0.05
# Variable: ReYds                Importance: 0.05
# Variable: Three_Cone           Importance: 0.04
# Variable: Rec                  Importance: 0.04
# Variable: Vertical             Importance: 0.03
# Variable: Bench                Importance: 0.03
# Variable: Broad_Jump           Importance: 0.03
# Variable: Shuttle              Importance: 0.03
# Variable: height               Importance: 0.03
# Variable: RuAtt                Importance: 0.03
# Variable: ReTD                 Importance: 0.03
# Variable: SDC                  Importance: 0.03
# Variable: G                    Importance: 0.02
# Variable: Age                  Importance: 0.01
# Variable: RuTD                 Importance: 0.01
# Variable: Std.Dev              Importance: 0.01
# Variable: agesq                Importance: 0.01
# Variable: BAL                  Importance: 0.01
# Variable: IND                  Importance: 0.01
# Variable: NYG                  Importance: 0.01
# Variable: Cmp                  Importance: 0.0
# Variable: PaAtt                Importance: 0.0
# Variable: Pct                  Importance: 0.0
# Variable: PaYds                Importance: 0.0
# Variable: PaTD                 Importance: 0.0
# Variable: Int                  Importance: 0.0
# Variable: ARI                  Importance: 0.0
# Variable: ATL                  Importance: 0.0
# Variable: BUF                  Importance: 0.0
# Variable: CAR                  Importance: 0.0
# Variable: CHI                  Importance: 0.0
# Variable: CIN                  Importance: 0.0
# Variable: CLE                  Importance: 0.0
# Variable: DAL                  Importance: 0.0
# Variable: DEN                  Importance: 0.0
# Variable: DET                  Importance: 0.0
# Variable: GNB                  Importance: 0.0
# Variable: HOU                  Importance: 0.0
# Variable: JAX                  Importance: 0.0
# Variable: KAN                  Importance: 0.0
# Variable: LAR                  Importance: 0.0
# Variable: MIA                  Importance: 0.0
# Variable: MIN                  Importance: 0.0
# Variable: NEP                  Importance: 0.0
# Variable: NOR                  Importance: 0.0
# Variable: NYJ                  Importance: 0.0
# Variable: OAK                  Importance: 0.0
# Variable: PHI                  Importance: 0.0
# Variable: PIT                  Importance: 0.0
# Variable: RAM                  Importance: 0.0
# Variable: SEA                  Importance: 0.0
# Variable: SFO                  Importance: 0.0
# Variable: STL                  Importance: 0.0
# Variable: TBB                  Importance: 0.0
# Variable: TEN                  Importance: 0.0
# Variable: WAS                  Importance: 0.0
# RB
# Variable: Overall              Importance: 0.4
# Variable: Pick                 Importance: 0.14
# Variable: HOU                  Importance: 0.04
# Variable: WAS                  Importance: 0.04
# Variable: Wt                   Importance: 0.03
# Variable: ReYds                Importance: 0.03
# Variable: Rec                  Importance: 0.03
# Variable: Dash                 Importance: 0.02
# Variable: Vertical             Importance: 0.02
# Variable: Shuttle              Importance: 0.02
# Variable: G                    Importance: 0.02
# Variable: RuYds                Importance: 0.02
# Variable: RuTD                 Importance: 0.02
# Variable: RuAtt                Importance: 0.02
# Variable: Age                  Importance: 0.01
# Variable: Bench                Importance: 0.01
# Variable: Broad_Jump           Importance: 0.01
# Variable: Three_Cone           Importance: 0.01
# Variable: height               Importance: 0.01
# Variable: ReTD                 Importance: 0.01
# Variable: Std.Dev              Importance: 0.01
# Variable: agesq                Importance: 0.01
# Variable: ARI                  Importance: 0.01
# Variable: CHI                  Importance: 0.01
# Variable: IND                  Importance: 0.01
# Variable: STL                  Importance: 0.01
# Variable: Cmp                  Importance: 0.0
# Variable: PaAtt                Importance: 0.0
# Variable: Pct                  Importance: 0.0
# Variable: PaYds                Importance: 0.0
# Variable: PaTD                 Importance: 0.0
# Variable: Int                  Importance: 0.0
# Variable: ATL                  Importance: 0.0
# Variable: BAL                  Importance: 0.0
# Variable: BUF                  Importance: 0.0
# Variable: CAR                  Importance: 0.0
# Variable: CIN                  Importance: 0.0
# Variable: CLE                  Importance: 0.0
# Variable: DAL                  Importance: 0.0
# Variable: DEN                  Importance: 0.0
# Variable: DET                  Importance: 0.0
# Variable: FA                   Importance: 0.0
# Variable: GNB                  Importance: 0.0
# Variable: JAX                  Importance: 0.0
# Variable: KAN                  Importance: 0.0
# Variable: LAC                  Importance: 0.0
# Variable: LAR                  Importance: 0.0
# Variable: MIA                  Importance: 0.0
# Variable: MIN                  Importance: 0.0
# Variable: NEP                  Importance: 0.0
# Variable: NOR                  Importance: 0.0
# Variable: NYG                  Importance: 0.0
# Variable: NYJ                  Importance: 0.0
# Variable: OAK                  Importance: 0.0
# Variable: PHI                  Importance: 0.0
# Variable: PIT                  Importance: 0.0
# Variable: SDC                  Importance: 0.0
# Variable: SEA                  Importance: 0.0
# Variable: SFO                  Importance: 0.0
# Variable: TBB                  Importance: 0.0
# Variable: TEN                  Importance: 0.0
# QB
# Variable: Overall              Importance: 0.32
# Variable: PaTD                 Importance: 0.11
# Variable: Wt                   Importance: 0.1
# Variable: PaAtt                Importance: 0.07
# Variable: Dash                 Importance: 0.05
# Variable: Broad_Jump           Importance: 0.04
# Variable: Pct                  Importance: 0.04
# Variable: RuAtt                Importance: 0.03
# Variable: Pick                 Importance: 0.02
# Variable: Vertical             Importance: 0.02
# Variable: Three_Cone           Importance: 0.02
# Variable: height               Importance: 0.02
# Variable: Cmp                  Importance: 0.02
# Variable: PaYds                Importance: 0.02
# Variable: RuYds                Importance: 0.02
# Variable: RuTD                 Importance: 0.02
# Variable: agesq                Importance: 0.02
# Variable: Bench                Importance: 0.01
# Variable: Shuttle              Importance: 0.01
# Variable: G                    Importance: 0.01
# Variable: Int                  Importance: 0.01
# Variable: Std.Dev              Importance: 0.01
# Variable: Age                  Importance: 0.0
# Variable: ReYds                Importance: 0.0
# Variable: ReTD                 Importance: 0.0
# Variable: Rec                  Importance: 0.0
# Variable: ARI                  Importance: 0.0
# Variable: ATL                  Importance: 0.0
# Variable: BAL                  Importance: 0.0
# Variable: BUF                  Importance: 0.0
# Variable: CAR                  Importance: 0.0
# Variable: CHI                  Importance: 0.0
# Variable: CIN                  Importance: 0.0
# Variable: CLE                  Importance: 0.0
# Variable: DAL                  Importance: 0.0
# Variable: DEN                  Importance: 0.0
# Variable: DET                  Importance: 0.0
# Variable: IND                  Importance: 0.0
# Variable: JAX                  Importance: 0.0
# Variable: KAN                  Importance: 0.0
# Variable: MIA                  Importance: 0.0
# Variable: MIN                  Importance: 0.0
# Variable: NOR                  Importance: 0.0
# Variable: NYG                  Importance: 0.0
# Variable: NYJ                  Importance: 0.0
# Variable: OAK                  Importance: 0.0
# Variable: PHI                  Importance: 0.0
# Variable: PIT                  Importance: 0.0
# Variable: RAM                  Importance: 0.0
# Variable: SDC                  Importance: 0.0
# Variable: SEA                  Importance: 0.0
# Variable: SFO                  Importance: 0.0
# Variable: STL                  Importance: 0.0
# Variable: TBB                  Importance: 0.0
# Variable: TEN                  Importance: 0.0
# Variable: WAS                  Importance: 0.0
# WR
# residual rank
# points fit
# RB
# residual rank
# points fit
# QB
# residual rank
# points fit
# TE
# residual rank
# points fit
#      Year Pos  ADP_As_Predictor  Model_As_Predictor
# 0  2014.0  WR             142.0               142.0
# 1  2014.0  RB              66.0                54.0
# 2  2014.0  QB               6.0                 0.0
# 3  2014.0  TE               4.0                12.0
# TE
# Variable: Overall              Importance: 0.2
# Variable: Broad_Jump           Importance: 0.16
# Variable: Pick                 Importance: 0.12
# Variable: Rec                  Importance: 0.09
# Variable: agesq                Importance: 0.05
# Variable: Wt                   Importance: 0.04
# Variable: Vertical             Importance: 0.04
# Variable: NEP                  Importance: 0.04
# Variable: Three_Cone           Importance: 0.03
# Variable: height               Importance: 0.03
# Variable: G                    Importance: 0.03
# Variable: ReYds                Importance: 0.03
# Variable: ReTD                 Importance: 0.03
# Variable: Dash                 Importance: 0.02
# Variable: Bench                Importance: 0.02
# Variable: RuAtt                Importance: 0.02
# Variable: Age                  Importance: 0.01
# Variable: Shuttle              Importance: 0.01
# Variable: Std.Dev              Importance: 0.01
# Variable: Cmp                  Importance: 0.0
# Variable: PaAtt                Importance: 0.0
# Variable: Pct                  Importance: 0.0
# Variable: PaYds                Importance: 0.0
# Variable: PaTD                 Importance: 0.0
# Variable: Int                  Importance: 0.0
# Variable: RuYds                Importance: 0.0
# Variable: RuTD                 Importance: 0.0
# Variable: ARI                  Importance: 0.0
# Variable: ATL                  Importance: 0.0
# Variable: BAL                  Importance: 0.0
# Variable: CAR                  Importance: 0.0
# Variable: CHI                  Importance: 0.0
# Variable: CIN                  Importance: 0.0
# Variable: CLE                  Importance: 0.0
# Variable: DEN                  Importance: 0.0
# Variable: DET                  Importance: 0.0
# Variable: FA                   Importance: 0.0
# Variable: GNB                  Importance: 0.0
# Variable: HOU                  Importance: 0.0
# Variable: IND                  Importance: 0.0
# Variable: JAX                  Importance: 0.0
# Variable: KAN                  Importance: 0.0
# Variable: LAR                  Importance: 0.0
# Variable: MIA                  Importance: 0.0
# Variable: MIN                  Importance: 0.0
# Variable: NYG                  Importance: 0.0
# Variable: NYJ                  Importance: 0.0
# Variable: OAK                  Importance: 0.0
# Variable: PHI                  Importance: 0.0
# Variable: PIT                  Importance: 0.0
# Variable: RAM                  Importance: 0.0
# Variable: SDC                  Importance: 0.0
# Variable: SEA                  Importance: 0.0
# Variable: SFO                  Importance: 0.0
# Variable: STL                  Importance: 0.0
# Variable: TBB                  Importance: 0.0
# Variable: TEN                  Importance: 0.0
# WR
# Variable: Overall              Importance: 0.37
# Variable: Pick                 Importance: 0.07
# Variable: Wt                   Importance: 0.06
# Variable: Bench                Importance: 0.04
# Variable: Shuttle              Importance: 0.04
# Variable: height               Importance: 0.04
# Variable: ReYds                Importance: 0.04
# Variable: Dash                 Importance: 0.03
# Variable: Vertical             Importance: 0.03
# Variable: Three_Cone           Importance: 0.03
# Variable: RuYds                Importance: 0.03
# Variable: Rec                  Importance: 0.03
# Variable: SDC                  Importance: 0.03
# Variable: Broad_Jump           Importance: 0.02
# Variable: G                    Importance: 0.02
# Variable: RuAtt                Importance: 0.02
# Variable: ReTD                 Importance: 0.02
# Variable: Age                  Importance: 0.01
# Variable: RuTD                 Importance: 0.01
# Variable: Std.Dev              Importance: 0.01
# Variable: agesq                Importance: 0.01
# Variable: BAL                  Importance: 0.01
# Variable: IND                  Importance: 0.01
# Variable: SFO                  Importance: 0.01
# Variable: Cmp                  Importance: 0.0
# Variable: PaAtt                Importance: 0.0
# Variable: Pct                  Importance: 0.0
# Variable: PaYds                Importance: 0.0
# Variable: PaTD                 Importance: 0.0
# Variable: Int                  Importance: 0.0
# Variable: ARI                  Importance: 0.0
# Variable: ATL                  Importance: 0.0
# Variable: BUF                  Importance: 0.0
# Variable: CAR                  Importance: 0.0
# Variable: CHI                  Importance: 0.0
# Variable: CIN                  Importance: 0.0
# Variable: CLE                  Importance: 0.0
# Variable: DAL                  Importance: 0.0
# Variable: DEN                  Importance: 0.0
# Variable: DET                  Importance: 0.0
# Variable: GNB                  Importance: 0.0
# Variable: HOU                  Importance: 0.0
# Variable: JAX                  Importance: 0.0
# Variable: KAN                  Importance: 0.0
# Variable: LAR                  Importance: 0.0
# Variable: MIA                  Importance: 0.0
# Variable: MIN                  Importance: 0.0
# Variable: NEP                  Importance: 0.0
# Variable: NOR                  Importance: 0.0
# Variable: NYG                  Importance: 0.0
# Variable: NYJ                  Importance: 0.0
# Variable: OAK                  Importance: 0.0
# Variable: PHI                  Importance: 0.0
# Variable: PIT                  Importance: 0.0
# Variable: RAM                  Importance: 0.0
# Variable: SEA                  Importance: 0.0
# Variable: STL                  Importance: 0.0
# Variable: TBB                  Importance: 0.0
# Variable: TEN                  Importance: 0.0
# Variable: WAS                  Importance: 0.0
# RB
# Variable: Overall              Importance: 0.44
# Variable: WAS                  Importance: 0.05
# Variable: Pick                 Importance: 0.04
# Variable: ReYds                Importance: 0.04
# Variable: Rec                  Importance: 0.04
# Variable: Wt                   Importance: 0.03
# Variable: Dash                 Importance: 0.03
# Variable: Std.Dev              Importance: 0.03
# Variable: HOU                  Importance: 0.03
# Variable: Vertical             Importance: 0.02
# Variable: Broad_Jump           Importance: 0.02
# Variable: Three_Cone           Importance: 0.02
# Variable: Shuttle              Importance: 0.02
# Variable: height               Importance: 0.02
# Variable: RuYds                Importance: 0.02
# Variable: RuTD                 Importance: 0.02
# Variable: RuAtt                Importance: 0.02
# Variable: Age                  Importance: 0.01
# Variable: Bench                Importance: 0.01
# Variable: G                    Importance: 0.01
# Variable: ReTD                 Importance: 0.01
# Variable: agesq                Importance: 0.01
# Variable: ARI                  Importance: 0.01
# Variable: CIN                  Importance: 0.01
# Variable: IND                  Importance: 0.01
# Variable: STL                  Importance: 0.01
# Variable: Cmp                  Importance: 0.0
# Variable: PaAtt                Importance: 0.0
# Variable: Pct                  Importance: 0.0
# Variable: PaYds                Importance: 0.0
# Variable: PaTD                 Importance: 0.0
# Variable: Int                  Importance: 0.0
# Variable: ATL                  Importance: 0.0
# Variable: BAL                  Importance: 0.0
# Variable: BUF                  Importance: 0.0
# Variable: CAR                  Importance: 0.0
# Variable: CHI                  Importance: 0.0
# Variable: CLE                  Importance: 0.0
# Variable: DAL                  Importance: 0.0
# Variable: DEN                  Importance: 0.0
# Variable: DET                  Importance: 0.0
# Variable: FA                   Importance: 0.0
# Variable: GNB                  Importance: 0.0
# Variable: JAX                  Importance: 0.0
# Variable: KAN                  Importance: 0.0
# Variable: LAC                  Importance: 0.0
# Variable: LAR                  Importance: 0.0
# Variable: MIA                  Importance: 0.0
# Variable: MIN                  Importance: 0.0
# Variable: NEP                  Importance: 0.0
# Variable: NOR                  Importance: 0.0
# Variable: NYG                  Importance: 0.0
# Variable: NYJ                  Importance: 0.0
# Variable: OAK                  Importance: 0.0
# Variable: PHI                  Importance: 0.0
# Variable: PIT                  Importance: 0.0
# Variable: SDC                  Importance: 0.0
# Variable: SEA                  Importance: 0.0
# Variable: SFO                  Importance: 0.0
# Variable: TBB                  Importance: 0.0
# Variable: TEN                  Importance: 0.0
# QB
# Variable: Overall              Importance: 0.38
# Variable: PaTD                 Importance: 0.13
# Variable: Pick                 Importance: 0.08
# Variable: Dash                 Importance: 0.05
# Variable: PaAtt                Importance: 0.05
# Variable: RuAtt                Importance: 0.05
# Variable: Wt                   Importance: 0.04
# Variable: RuYds                Importance: 0.03
# Variable: Vertical             Importance: 0.02
# Variable: Broad_Jump           Importance: 0.02
# Variable: Three_Cone           Importance: 0.02
# Variable: Pct                  Importance: 0.02
# Variable: Shuttle              Importance: 0.01
# Variable: height               Importance: 0.01
# Variable: G                    Importance: 0.01
# Variable: Cmp                  Importance: 0.01
# Variable: PaYds                Importance: 0.01
# Variable: Int                  Importance: 0.01
# Variable: RuTD                 Importance: 0.01
# Variable: Std.Dev              Importance: 0.01
# Variable: BUF                  Importance: 0.01
# Variable: Age                  Importance: 0.0
# Variable: Bench                Importance: 0.0
# Variable: ReYds                Importance: 0.0
# Variable: ReTD                 Importance: 0.0
# Variable: Rec                  Importance: 0.0
# Variable: agesq                Importance: 0.0
# Variable: ARI                  Importance: 0.0
# Variable: ATL                  Importance: 0.0
# Variable: BAL                  Importance: 0.0
# Variable: CAR                  Importance: 0.0
# Variable: CHI                  Importance: 0.0
# Variable: CIN                  Importance: 0.0
# Variable: CLE                  Importance: 0.0
# Variable: DAL                  Importance: 0.0
# Variable: DEN                  Importance: 0.0
# Variable: DET                  Importance: 0.0
# Variable: IND                  Importance: 0.0
# Variable: JAX                  Importance: 0.0
# Variable: KAN                  Importance: 0.0
# Variable: MIA                  Importance: 0.0
# Variable: MIN                  Importance: 0.0
# Variable: NOR                  Importance: 0.0
# Variable: NYG                  Importance: 0.0
# Variable: NYJ                  Importance: 0.0
# Variable: OAK                  Importance: 0.0
# Variable: PHI                  Importance: 0.0
# Variable: PIT                  Importance: 0.0
# Variable: RAM                  Importance: 0.0
# Variable: SDC                  Importance: 0.0
# Variable: SEA                  Importance: 0.0
# Variable: SFO                  Importance: 0.0
# Variable: STL                  Importance: 0.0
# Variable: TBB                  Importance: 0.0
# Variable: TEN                  Importance: 0.0
# Variable: WAS                  Importance: 0.0
# WR
# residual rank
# points fit
# RB
# residual rank
# points fit
# QB
# residual rank
# points fit
# TE
# residual rank
# points fit
#      Year Pos  ADP_As_Predictor  Model_As_Predictor
# 0  2015.0  WR             200.0               178.0
# 1  2015.0  RB             242.0               250.0
# 2  2015.0  QB               0.5                 2.5
# 3  2015.0  TE               2.0                 2.0
# TE
# Variable: Broad_Jump           Importance: 0.19
# Variable: Overall              Importance: 0.19
# Variable: Pick                 Importance: 0.09
# Variable: G                    Importance: 0.09
# Variable: NEP                  Importance: 0.09
# Variable: Rec                  Importance: 0.07
# Variable: Vertical             Importance: 0.05
# Variable: Wt                   Importance: 0.04
# Variable: Dash                 Importance: 0.02
# Variable: Three_Cone           Importance: 0.02
# Variable: height               Importance: 0.02
# Variable: ReYds                Importance: 0.02
# Variable: ReTD                 Importance: 0.02
# Variable: agesq                Importance: 0.02
# Variable: Age                  Importance: 0.01
# Variable: Bench                Importance: 0.01
# Variable: Shuttle              Importance: 0.01
# Variable: RuAtt                Importance: 0.01
# Variable: Std.Dev              Importance: 0.01
# Variable: KAN                  Importance: 0.01
# Variable: Cmp                  Importance: 0.0
# Variable: PaAtt                Importance: 0.0
# Variable: Pct                  Importance: 0.0
# Variable: PaYds                Importance: 0.0
# Variable: PaTD                 Importance: 0.0
# Variable: Int                  Importance: 0.0
# Variable: RuYds                Importance: 0.0
# Variable: RuTD                 Importance: 0.0
# Variable: ARI                  Importance: 0.0
# Variable: ATL                  Importance: 0.0
# Variable: BAL                  Importance: 0.0
# Variable: CAR                  Importance: 0.0
# Variable: CHI                  Importance: 0.0
# Variable: CIN                  Importance: 0.0
# Variable: CLE                  Importance: 0.0
# Variable: DEN                  Importance: 0.0
# Variable: DET                  Importance: 0.0
# Variable: FA                   Importance: 0.0
# Variable: GNB                  Importance: 0.0
# Variable: HOU                  Importance: 0.0
# Variable: IND                  Importance: 0.0
# Variable: JAX                  Importance: 0.0
# Variable: LAR                  Importance: 0.0
# Variable: MIA                  Importance: 0.0
# Variable: MIN                  Importance: 0.0
# Variable: NYG                  Importance: 0.0
# Variable: NYJ                  Importance: 0.0
# Variable: OAK                  Importance: 0.0
# Variable: PHI                  Importance: 0.0
# Variable: PIT                  Importance: 0.0
# Variable: RAM                  Importance: 0.0
# Variable: SDC                  Importance: 0.0
# Variable: SEA                  Importance: 0.0
# Variable: SFO                  Importance: 0.0
# Variable: STL                  Importance: 0.0
# Variable: TBB                  Importance: 0.0
# Variable: TEN                  Importance: 0.0
# WR
# Variable: Overall              Importance: 0.36
# Variable: Pick                 Importance: 0.08
# Variable: Vertical             Importance: 0.05
# Variable: Bench                Importance: 0.05
# Variable: RuYds                Importance: 0.05
# Variable: Wt                   Importance: 0.04
# Variable: Dash                 Importance: 0.04
# Variable: Three_Cone           Importance: 0.04
# Variable: ReYds                Importance: 0.04
# Variable: Rec                  Importance: 0.04
# Variable: Shuttle              Importance: 0.03
# Variable: Broad_Jump           Importance: 0.02
# Variable: height               Importance: 0.02
# Variable: G                    Importance: 0.02
# Variable: RuAtt                Importance: 0.02
# Variable: ReTD                 Importance: 0.02
# Variable: SDC                  Importance: 0.02
# Variable: Age                  Importance: 0.01
# Variable: RuTD                 Importance: 0.01
# Variable: Std.Dev              Importance: 0.01
# Variable: agesq                Importance: 0.01
# Variable: BAL                  Importance: 0.01
# Variable: SFO                  Importance: 0.01
# Variable: Cmp                  Importance: 0.0
# Variable: PaAtt                Importance: 0.0
# Variable: Pct                  Importance: 0.0
# Variable: PaYds                Importance: 0.0
# Variable: PaTD                 Importance: 0.0
# Variable: Int                  Importance: 0.0
# Variable: ARI                  Importance: 0.0
# Variable: ATL                  Importance: 0.0
# Variable: BUF                  Importance: 0.0
# Variable: CAR                  Importance: 0.0
# Variable: CHI                  Importance: 0.0
# Variable: CIN                  Importance: 0.0
# Variable: CLE                  Importance: 0.0
# Variable: DAL                  Importance: 0.0
# Variable: DEN                  Importance: 0.0
# Variable: DET                  Importance: 0.0
# Variable: GNB                  Importance: 0.0
# Variable: HOU                  Importance: 0.0
# Variable: IND                  Importance: 0.0
# Variable: JAX                  Importance: 0.0
# Variable: KAN                  Importance: 0.0
# Variable: LAR                  Importance: 0.0
# Variable: MIA                  Importance: 0.0
# Variable: MIN                  Importance: 0.0
# Variable: NEP                  Importance: 0.0
# Variable: NOR                  Importance: 0.0
# Variable: NYG                  Importance: 0.0
# Variable: NYJ                  Importance: 0.0
# Variable: OAK                  Importance: 0.0
# Variable: PHI                  Importance: 0.0
# Variable: PIT                  Importance: 0.0
# Variable: RAM                  Importance: 0.0
# Variable: SEA                  Importance: 0.0
# Variable: STL                  Importance: 0.0
# Variable: TBB                  Importance: 0.0
# Variable: TEN                  Importance: 0.0
# Variable: WAS                  Importance: 0.0
# RB
# Variable: Overall              Importance: 0.37
# Variable: Std.Dev              Importance: 0.09
# Variable: Pick                 Importance: 0.06
# Variable: WAS                  Importance: 0.06
# Variable: Wt                   Importance: 0.05
# Variable: Rec                  Importance: 0.04
# Variable: Dash                 Importance: 0.03
# Variable: RuTD                 Importance: 0.03
# Variable: ReYds                Importance: 0.03
# Variable: Vertical             Importance: 0.02
# Variable: Bench                Importance: 0.02
# Variable: Broad_Jump           Importance: 0.02
# Variable: Three_Cone           Importance: 0.02
# Variable: height               Importance: 0.02
# Variable: RuYds                Importance: 0.02
# Variable: Age                  Importance: 0.01
# Variable: Shuttle              Importance: 0.01
# Variable: G                    Importance: 0.01
# Variable: RuAtt                Importance: 0.01
# Variable: ReTD                 Importance: 0.01
# Variable: agesq                Importance: 0.01
# Variable: ARI                  Importance: 0.01
# Variable: BAL                  Importance: 0.01
# Variable: BUF                  Importance: 0.01
# Variable: CIN                  Importance: 0.01
# Variable: IND                  Importance: 0.01
# Variable: STL                  Importance: 0.01
# Variable: Cmp                  Importance: 0.0
# Variable: PaAtt                Importance: 0.0
# Variable: Pct                  Importance: 0.0
# Variable: PaYds                Importance: 0.0
# Variable: PaTD                 Importance: 0.0
# Variable: Int                  Importance: 0.0
# Variable: ATL                  Importance: 0.0
# Variable: CAR                  Importance: 0.0
# Variable: CHI                  Importance: 0.0
# Variable: CLE                  Importance: 0.0
# Variable: DAL                  Importance: 0.0
# Variable: DEN                  Importance: 0.0
# Variable: DET                  Importance: 0.0
# Variable: FA                   Importance: 0.0
# Variable: GNB                  Importance: 0.0
# Variable: HOU                  Importance: 0.0
# Variable: JAX                  Importance: 0.0
# Variable: KAN                  Importance: 0.0
# Variable: LAC                  Importance: 0.0
# Variable: LAR                  Importance: 0.0
# Variable: MIA                  Importance: 0.0
# Variable: MIN                  Importance: 0.0
# Variable: NEP                  Importance: 0.0
# Variable: NOR                  Importance: 0.0
# Variable: NYG                  Importance: 0.0
# Variable: NYJ                  Importance: 0.0
# Variable: OAK                  Importance: 0.0
# Variable: PHI                  Importance: 0.0
# Variable: PIT                  Importance: 0.0
# Variable: SDC                  Importance: 0.0
# Variable: SEA                  Importance: 0.0
# Variable: SFO                  Importance: 0.0
# Variable: TBB                  Importance: 0.0
# Variable: TEN                  Importance: 0.0
# QB
# Variable: Overall              Importance: 0.52
# Variable: Pick                 Importance: 0.19
# Variable: PaTD                 Importance: 0.05
# Variable: Wt                   Importance: 0.03
# Variable: PaAtt                Importance: 0.03
# Variable: Dash                 Importance: 0.02
# Variable: Broad_Jump           Importance: 0.02
# Variable: Cmp                  Importance: 0.02
# Variable: PaYds                Importance: 0.02
# Variable: RuYds                Importance: 0.02
# Variable: Vertical             Importance: 0.01
# Variable: Three_Cone           Importance: 0.01
# Variable: Shuttle              Importance: 0.01
# Variable: G                    Importance: 0.01
# Variable: Pct                  Importance: 0.01
# Variable: Int                  Importance: 0.01
# Variable: RuTD                 Importance: 0.01
# Variable: RuAtt                Importance: 0.01
# Variable: Age                  Importance: 0.0
# Variable: Bench                Importance: 0.0
# Variable: height               Importance: 0.0
# Variable: ReYds                Importance: 0.0
# Variable: ReTD                 Importance: 0.0
# Variable: Rec                  Importance: 0.0
# Variable: Std.Dev              Importance: 0.0
# Variable: agesq                Importance: 0.0
# Variable: ARI                  Importance: 0.0
# Variable: ATL                  Importance: 0.0
# Variable: BAL                  Importance: 0.0
# Variable: BUF                  Importance: 0.0
# Variable: CAR                  Importance: 0.0
# Variable: CHI                  Importance: 0.0
# Variable: CIN                  Importance: 0.0
# Variable: CLE                  Importance: 0.0
# Variable: DAL                  Importance: 0.0
# Variable: DEN                  Importance: 0.0
# Variable: DET                  Importance: 0.0
# Variable: IND                  Importance: 0.0
# Variable: JAX                  Importance: 0.0
# Variable: KAN                  Importance: 0.0
# Variable: MIA                  Importance: 0.0
# Variable: MIN                  Importance: 0.0
# Variable: NOR                  Importance: 0.0
# Variable: NYG                  Importance: 0.0
# Variable: NYJ                  Importance: 0.0
# Variable: OAK                  Importance: 0.0
# Variable: PHI                  Importance: 0.0
# Variable: PIT                  Importance: 0.0
# Variable: RAM                  Importance: 0.0
# Variable: SDC                  Importance: 0.0
# Variable: SEA                  Importance: 0.0
# Variable: SFO                  Importance: 0.0
# Variable: STL                  Importance: 0.0
# Variable: TBB                  Importance: 0.0
# Variable: TEN                  Importance: 0.0
# Variable: WAS                  Importance: 0.0
# WR
# residual rank
# points fit
# RB
# residual rank
# points fit
# QB
# residual rank
# points fit
# TE
# residual rank
# points fit
#      Year Pos  ADP_As_Predictor  Model_As_Predictor
# 0  2016.0  WR             256.0               236.0
# 1  2016.0  RB              58.0               352.0
# 2  2016.0  QB               6.0                 6.0
# 3  2016.0  TE               4.0                 2.0
# TE
# Variable: Rec                  Importance: 0.27
# Variable: Broad_Jump           Importance: 0.2
# Variable: Overall              Importance: 0.11
# Variable: Pick                 Importance: 0.1
# Variable: ReYds                Importance: 0.07
# Variable: G                    Importance: 0.04
# Variable: NEP                  Importance: 0.04
# Variable: height               Importance: 0.03
# Variable: Bench                Importance: 0.02
# Variable: KAN                  Importance: 0.02
# Variable: Age                  Importance: 0.01
# Variable: Wt                   Importance: 0.01
# Variable: Dash                 Importance: 0.01
# Variable: Vertical             Importance: 0.01
# Variable: Three_Cone           Importance: 0.01
# Variable: Shuttle              Importance: 0.01
# Variable: RuAtt                Importance: 0.01
# Variable: ReTD                 Importance: 0.01
# Variable: Std.Dev              Importance: 0.01
# Variable: agesq                Importance: 0.01
# Variable: Cmp                  Importance: 0.0
# Variable: PaAtt                Importance: 0.0
# Variable: Pct                  Importance: 0.0
# Variable: PaYds                Importance: 0.0
# Variable: PaTD                 Importance: 0.0
# Variable: Int                  Importance: 0.0
# Variable: RuYds                Importance: 0.0
# Variable: RuTD                 Importance: 0.0
# Variable: ARI                  Importance: 0.0
# Variable: ATL                  Importance: 0.0
# Variable: BAL                  Importance: 0.0
# Variable: CAR                  Importance: 0.0
# Variable: CHI                  Importance: 0.0
# Variable: CIN                  Importance: 0.0
# Variable: CLE                  Importance: 0.0
# Variable: DEN                  Importance: 0.0
# Variable: DET                  Importance: 0.0
# Variable: FA                   Importance: 0.0
# Variable: GNB                  Importance: 0.0
# Variable: HOU                  Importance: 0.0
# Variable: IND                  Importance: 0.0
# Variable: JAX                  Importance: 0.0
# Variable: LAR                  Importance: 0.0
# Variable: MIA                  Importance: 0.0
# Variable: MIN                  Importance: 0.0
# Variable: NYG                  Importance: 0.0
# Variable: NYJ                  Importance: 0.0
# Variable: OAK                  Importance: 0.0
# Variable: PHI                  Importance: 0.0
# Variable: PIT                  Importance: 0.0
# Variable: RAM                  Importance: 0.0
# Variable: SDC                  Importance: 0.0
# Variable: SEA                  Importance: 0.0
# Variable: SFO                  Importance: 0.0
# Variable: STL                  Importance: 0.0
# Variable: TBB                  Importance: 0.0
# Variable: TEN                  Importance: 0.0
# WR
# Variable: Overall              Importance: 0.31
# Variable: Pick                 Importance: 0.09
# Variable: Wt                   Importance: 0.06
# Variable: RuYds                Importance: 0.05
# Variable: Dash                 Importance: 0.04
# Variable: Bench                Importance: 0.04
# Variable: Rec                  Importance: 0.04
# Variable: Std.Dev              Importance: 0.04
# Variable: Vertical             Importance: 0.03
# Variable: Broad_Jump           Importance: 0.03
# Variable: Three_Cone           Importance: 0.03
# Variable: Shuttle              Importance: 0.03
# Variable: height               Importance: 0.03
# Variable: ReYds                Importance: 0.03
# Variable: ReTD                 Importance: 0.03
# Variable: G                    Importance: 0.02
# Variable: RuAtt                Importance: 0.02
# Variable: SDC                  Importance: 0.02
# Variable: Age                  Importance: 0.01
# Variable: RuTD                 Importance: 0.01
# Variable: agesq                Importance: 0.01
# Variable: Cmp                  Importance: 0.0
# Variable: PaAtt                Importance: 0.0
# Variable: Pct                  Importance: 0.0
# Variable: PaYds                Importance: 0.0
# Variable: PaTD                 Importance: 0.0
# Variable: Int                  Importance: 0.0
# Variable: ARI                  Importance: 0.0
# Variable: ATL                  Importance: 0.0
# Variable: BAL                  Importance: 0.0
# Variable: BUF                  Importance: 0.0
# Variable: CAR                  Importance: 0.0
# Variable: CHI                  Importance: 0.0
# Variable: CIN                  Importance: 0.0
# Variable: CLE                  Importance: 0.0
# Variable: DAL                  Importance: 0.0
# Variable: DEN                  Importance: 0.0
# Variable: DET                  Importance: 0.0
# Variable: GNB                  Importance: 0.0
# Variable: HOU                  Importance: 0.0
# Variable: IND                  Importance: 0.0
# Variable: JAX                  Importance: 0.0
# Variable: KAN                  Importance: 0.0
# Variable: LAR                  Importance: 0.0
# Variable: MIA                  Importance: 0.0
# Variable: MIN                  Importance: 0.0
# Variable: NEP                  Importance: 0.0
# Variable: NOR                  Importance: 0.0
# Variable: NYG                  Importance: 0.0
# Variable: NYJ                  Importance: 0.0
# Variable: OAK                  Importance: 0.0
# Variable: PHI                  Importance: 0.0
# Variable: PIT                  Importance: 0.0
# Variable: RAM                  Importance: 0.0
# Variable: SEA                  Importance: 0.0
# Variable: SFO                  Importance: 0.0
# Variable: STL                  Importance: 0.0
# Variable: TBB                  Importance: 0.0
# Variable: TEN                  Importance: 0.0
# Variable: WAS                  Importance: 0.0
# RB
# Variable: Overall              Importance: 0.34
# Variable: Std.Dev              Importance: 0.18
# Variable: Pick                 Importance: 0.06
# Variable: Wt                   Importance: 0.04
# Variable: RuTD                 Importance: 0.04
# Variable: Dash                 Importance: 0.03
# Variable: Vertical             Importance: 0.03
# Variable: Bench                Importance: 0.02
# Variable: height               Importance: 0.02
# Variable: RuYds                Importance: 0.02
# Variable: ReYds                Importance: 0.02
# Variable: Rec                  Importance: 0.02
# Variable: agesq                Importance: 0.02
# Variable: Age                  Importance: 0.01
# Variable: Broad_Jump           Importance: 0.01
# Variable: Three_Cone           Importance: 0.01
# Variable: Shuttle              Importance: 0.01
# Variable: G                    Importance: 0.01
# Variable: RuAtt                Importance: 0.01
# Variable: ReTD                 Importance: 0.01
# Variable: ARI                  Importance: 0.01
# Variable: CHI                  Importance: 0.01
# Variable: CIN                  Importance: 0.01
# Variable: IND                  Importance: 0.01
# Variable: WAS                  Importance: 0.01
# Variable: Cmp                  Importance: 0.0
# Variable: PaAtt                Importance: 0.0
# Variable: Pct                  Importance: 0.0
# Variable: PaYds                Importance: 0.0
# Variable: PaTD                 Importance: 0.0
# Variable: Int                  Importance: 0.0
# Variable: ATL                  Importance: 0.0
# Variable: BAL                  Importance: 0.0
# Variable: BUF                  Importance: 0.0
# Variable: CAR                  Importance: 0.0
# Variable: CLE                  Importance: 0.0
# Variable: DAL                  Importance: 0.0
# Variable: DEN                  Importance: 0.0
# Variable: DET                  Importance: 0.0
# Variable: FA                   Importance: 0.0
# Variable: GNB                  Importance: 0.0
# Variable: HOU                  Importance: 0.0
# Variable: JAX                  Importance: 0.0
# Variable: KAN                  Importance: 0.0
# Variable: LAC                  Importance: 0.0
# Variable: LAR                  Importance: 0.0
# Variable: MIA                  Importance: 0.0
# Variable: MIN                  Importance: 0.0
# Variable: NEP                  Importance: 0.0
# Variable: NOR                  Importance: 0.0
# Variable: NYG                  Importance: 0.0
# Variable: NYJ                  Importance: 0.0
# Variable: OAK                  Importance: 0.0
# Variable: PHI                  Importance: 0.0
# Variable: PIT                  Importance: 0.0
# Variable: SDC                  Importance: 0.0
# Variable: SEA                  Importance: 0.0
# Variable: SFO                  Importance: 0.0
# Variable: STL                  Importance: 0.0
# Variable: TBB                  Importance: 0.0
# Variable: TEN                  Importance: 0.0
# QB
# Variable: Overall              Importance: 0.32
# Variable: Pick                 Importance: 0.11
# Variable: Pct                  Importance: 0.09
# Variable: PaTD                 Importance: 0.07
# Variable: Cmp                  Importance: 0.04
# Variable: PaAtt                Importance: 0.04
# Variable: RuYds                Importance: 0.04
# Variable: RuTD                 Importance: 0.04
# Variable: Wt                   Importance: 0.03
# Variable: Dash                 Importance: 0.03
# Variable: Broad_Jump           Importance: 0.03
# Variable: Std.Dev              Importance: 0.03
# Variable: Vertical             Importance: 0.02
# Variable: PaYds                Importance: 0.02
# Variable: RuAtt                Importance: 0.02
# Variable: Three_Cone           Importance: 0.01
# Variable: Shuttle              Importance: 0.01
# Variable: height               Importance: 0.01
# Variable: Int                  Importance: 0.01
# Variable: Age                  Importance: 0.0
# Variable: Bench                Importance: 0.0
# Variable: G                    Importance: 0.0
# Variable: ReYds                Importance: 0.0
# Variable: ReTD                 Importance: 0.0
# Variable: Rec                  Importance: 0.0
# Variable: agesq                Importance: 0.0
# Variable: ARI                  Importance: 0.0
# Variable: ATL                  Importance: 0.0
# Variable: BAL                  Importance: 0.0
# Variable: BUF                  Importance: 0.0
# Variable: CAR                  Importance: 0.0
# Variable: CHI                  Importance: 0.0
# Variable: CIN                  Importance: 0.0
# Variable: CLE                  Importance: 0.0
# Variable: DAL                  Importance: 0.0
# Variable: DEN                  Importance: 0.0
# Variable: DET                  Importance: 0.0
# Variable: IND                  Importance: 0.0
# Variable: JAX                  Importance: 0.0
# Variable: KAN                  Importance: 0.0
# Variable: MIA                  Importance: 0.0
# Variable: MIN                  Importance: 0.0
# Variable: NOR                  Importance: 0.0
# Variable: NYG                  Importance: 0.0
# Variable: NYJ                  Importance: 0.0
# Variable: OAK                  Importance: 0.0
# Variable: PHI                  Importance: 0.0
# Variable: PIT                  Importance: 0.0
# Variable: RAM                  Importance: 0.0
# Variable: SDC                  Importance: 0.0
# Variable: SEA                  Importance: 0.0
# Variable: SFO                  Importance: 0.0
# Variable: STL                  Importance: 0.0
# Variable: TBB                  Importance: 0.0
# Variable: TEN                  Importance: 0.0
# Variable: WAS                  Importance: 0.0
# WR
# residual rank
# points fit
# RB
# residual rank
# points fit
# QB
# residual rank
# points fit
# TE
# residual rank
# points fit
#      Year Pos  ADP_As_Predictor  Model_As_Predictor
# 0  2017.0  WR              54.0               108.0
# 1  2017.0  RB              44.5                64.5
# 2  2017.0  QB               2.0                 2.0
# 3  2017.0  TE               0.0                 4.0
# TE
# Variable: Overall              Importance: 0.25
# Variable: Rec                  Importance: 0.22
# Variable: Pick                 Importance: 0.17
# Variable: ReYds                Importance: 0.06
# Variable: Dash                 Importance: 0.04
# Variable: Wt                   Importance: 0.03
# Variable: Bench                Importance: 0.03
# Variable: Broad_Jump           Importance: 0.03
# Variable: Three_Cone           Importance: 0.02
# Variable: G                    Importance: 0.02
# Variable: ReTD                 Importance: 0.02
# Variable: NYG                  Importance: 0.02
# Variable: Age                  Importance: 0.01
# Variable: Vertical             Importance: 0.01
# Variable: Shuttle              Importance: 0.01
# Variable: height               Importance: 0.01
# Variable: RuAtt                Importance: 0.01
# Variable: agesq                Importance: 0.01
# Variable: SDC                  Importance: 0.01
# Variable: Cmp                  Importance: 0.0
# Variable: PaAtt                Importance: 0.0
# Variable: Pct                  Importance: 0.0
# Variable: PaYds                Importance: 0.0
# Variable: PaTD                 Importance: 0.0
# Variable: Int                  Importance: 0.0
# Variable: RuYds                Importance: 0.0
# Variable: RuTD                 Importance: 0.0
# Variable: Std.Dev              Importance: 0.0
# Variable: ARI                  Importance: 0.0
# Variable: ATL                  Importance: 0.0
# Variable: BAL                  Importance: 0.0
# Variable: CAR                  Importance: 0.0
# Variable: CHI                  Importance: 0.0
# Variable: CIN                  Importance: 0.0
# Variable: CLE                  Importance: 0.0
# Variable: DEN                  Importance: 0.0
# Variable: DET                  Importance: 0.0
# Variable: FA                   Importance: 0.0
# Variable: GNB                  Importance: 0.0
# Variable: HOU                  Importance: 0.0
# Variable: IND                  Importance: 0.0
# Variable: JAX                  Importance: 0.0
# Variable: KAN                  Importance: 0.0
# Variable: LAR                  Importance: 0.0
# ...
# Variable: PaYds                Importance: 0.0
# Variable: PaTD                 Importance: 0.0
# Variable: Int                  Importance: 0.0
# Variable: ATL                  Importance: 0.0
# Variable: BAL                  Importance: 0.0
# Variable: BUF                  Importance: 0.0
# Variable: CAR                  Importance: 0.0
# Variable: CLE                  Importance: 0.0
# Variable: DAL                  Importance: 0.0
# Variable: DEN                  Importance: 0.0
# Variable: DET                  Importance: 0.0
# Variable: FA                   Importance: 0.0
# Variable: GNB                  Importance: 0.0
# Variable: HOU                  Importance: 0.0
# Variable: JAX                  Importance: 0.0
# Variable: KAN                  Importance: 0.0
# Variable: LAC                  Importance: 0.0
# Variable: LAR                  Importance: 0.0
# Variable: MIA                  Importance: 0.0
# Variable: MIN                  Importance: 0.0
# Variable: NEP                  Importance: 0.0
# Variable: NYG                  Importance: 0.0
# Variable: NYJ                  Importance: 0.0
# Variable: OAK                  Importance: 0.0
# Variable: PHI                  Importance: 0.0
# Variable: PIT                  Importance: 0.0
# Variable: SDC                  Importance: 0.0
# Variable: SEA                  Importance: 0.0
# Variable: SFO                  Importance: 0.0
# Variable: STL                  Importance: 0.0
# Variable: TBB                  Importance: 0.0
# Variable: TEN                  Importance: 0.0
# QB
# Variable: Overall              Importance: 0.27
# Variable: Pct                  Importance: 0.14
# Variable: Pick                 Importance: 0.13
# Variable: Wt                   Importance: 0.04
# Variable: Broad_Jump           Importance: 0.04
# Variable: Dash                 Importance: 0.03
# Variable: Cmp                  Importance: 0.03
# Variable: PaAtt                Importance: 0.03
# Variable: PaTD                 Importance: 0.03
# Variable: Int                  Importance: 0.03
# Variable: RuYds                Importance: 0.03
# Variable: RuTD                 Importance: 0.03
# Variable: Vertical             Importance: 0.02
# Variable: Three_Cone           Importance: 0.02
# Variable: Shuttle              Importance: 0.02
# Variable: PaYds                Importance: 0.02
# Variable: RuAtt                Importance: 0.02
# Variable: Std.Dev              Importance: 0.02
# Variable: height               Importance: 0.01
# Variable: G                    Importance: 0.01
# Variable: JAX                  Importance: 0.01
# Variable: Age                  Importance: 0.0
# Variable: Bench                Importance: 0.0
# Variable: ReYds                Importance: 0.0
# Variable: ReTD                 Importance: 0.0
# Variable: Rec                  Importance: 0.0
# Variable: agesq                Importance: 0.0
# Variable: ARI                  Importance: 0.0
# Variable: ATL                  Importance: 0.0
# Variable: BAL                  Importance: 0.0
# Variable: BUF                  Importance: 0.0
# Variable: CAR                  Importance: 0.0
# Variable: CHI                  Importance: 0.0
# Variable: CIN                  Importance: 0.0
# Variable: CLE                  Importance: 0.0
# Variable: DAL                  Importance: 0.0
# Variable: DEN                  Importance: 0.0
# Variable: DET                  Importance: 0.0
# Variable: IND                  Importance: 0.0
# Variable: KAN                  Importance: 0.0
# Variable: MIA                  Importance: 0.0
# Variable: MIN                  Importance: 0.0
# Variable: NOR                  Importance: 0.0
# Variable: NYG                  Importance: 0.0
# Variable: NYJ                  Importance: 0.0
# Variable: OAK                  Importance: 0.0
# Variable: PHI                  Importance: 0.0
# Variable: PIT                  Importance: 0.0
# Variable: RAM                  Importance: 0.0
# Variable: SDC                  Importance: 0.0
# Variable: SEA                  Importance: 0.0
# Variable: SFO                  Importance: 0.0
# Variable: STL                  Importance: 0.0
# Variable: TBB                  Importance: 0.0
# Variable: TEN                  Importance: 0.0
# Variable: WAS                  Importance: 0.0
# WR
# residual rank
# points fit
# RB
# residual rank
# points fit
# QB
# residual rank
# points fit
# TE
# residual rank
# points fit
#      Year Pos  ADP_As_Predictor  Model_As_Predictor
# 0  2018.0  WR              97.5               122.5
# 1  2018.0  RB             181.5               170.5
# 2  2018.0  QB              18.0                18.0
# 3  2018.0  TE              40.0                32.0
# TE
# Variable: ReYds                Importance: 0.23
# Variable: Rec                  Importance: 0.21
# Variable: Pick                 Importance: 0.1
# Variable: Dash                 Importance: 0.07
# Variable: Overall              Importance: 0.06
# Variable: Broad_Jump           Importance: 0.05
# Variable: Vertical             Importance: 0.03
# Variable: G                    Importance: 0.03
# Variable: ReTD                 Importance: 0.03
# Variable: NYG                  Importance: 0.03
# Variable: Age                  Importance: 0.02
# Variable: Wt                   Importance: 0.02
# Variable: Bench                Importance: 0.02
# Variable: Three_Cone           Importance: 0.02
# Variable: Shuttle              Importance: 0.02
# Variable: height               Importance: 0.02
# Variable: RuYds                Importance: 0.01
# Variable: RuAtt                Importance: 0.01
# Variable: agesq                Importance: 0.01
# Variable: CAR                  Importance: 0.01
# Variable: FA                   Importance: 0.01
# Variable: Cmp                  Importance: 0.0
# Variable: PaAtt                Importance: 0.0
# Variable: Pct                  Importance: 0.0
# Variable: PaYds                Importance: 0.0
# Variable: PaTD                 Importance: 0.0
# Variable: Int                  Importance: 0.0
# Variable: RuTD                 Importance: 0.0
# Variable: Std.Dev              Importance: 0.0
# Variable: ARI                  Importance: 0.0
# Variable: ATL                  Importance: 0.0
# Variable: BAL                  Importance: 0.0
# Variable: CHI                  Importance: 0.0
# Variable: CIN                  Importance: 0.0
# Variable: CLE                  Importance: 0.0
# Variable: DEN                  Importance: 0.0
# Variable: DET                  Importance: 0.0
# Variable: GNB                  Importance: 0.0
# Variable: HOU                  Importance: 0.0
# Variable: IND                  Importance: 0.0
# Variable: JAX                  Importance: 0.0
# Variable: KAN                  Importance: 0.0
# Variable: LAR                  Importance: 0.0
# Variable: MIA                  Importance: 0.0
# Variable: MIN                  Importance: 0.0
# Variable: NEP                  Importance: 0.0
# Variable: NYJ                  Importance: 0.0
# Variable: OAK                  Importance: 0.0
# Variable: PHI                  Importance: 0.0
# Variable: PIT                  Importance: 0.0
# Variable: RAM                  Importance: 0.0
# Variable: SDC                  Importance: 0.0
# Variable: SEA                  Importance: 0.0
# Variable: SFO                  Importance: 0.0
# Variable: STL                  Importance: 0.0
# Variable: TBB                  Importance: 0.0
# Variable: TEN                  Importance: 0.0
# WR
# Variable: Overall              Importance: 0.35
# Variable: Rec                  Importance: 0.07
# Variable: RuYds                Importance: 0.06
# Variable: Pick                 Importance: 0.04
# Variable: Wt                   Importance: 0.04
# Variable: Dash                 Importance: 0.04
# Variable: Vertical             Importance: 0.04
# Variable: Shuttle              Importance: 0.04
# Variable: Std.Dev              Importance: 0.04
# Variable: Bench                Importance: 0.03
# Variable: Broad_Jump           Importance: 0.03
# Variable: Three_Cone           Importance: 0.03
# Variable: height               Importance: 0.03
# Variable: ReTD                 Importance: 0.03
# Variable: G                    Importance: 0.02
# Variable: RuAtt                Importance: 0.02
# Variable: ReYds                Importance: 0.02
# Variable: SDC                  Importance: 0.02
# Variable: agesq                Importance: 0.01
# Variable: IND                  Importance: 0.01
# Variable: Age                  Importance: 0.0
# Variable: Cmp                  Importance: 0.0
# Variable: PaAtt                Importance: 0.0
# Variable: Pct                  Importance: 0.0
# Variable: PaYds                Importance: 0.0
# Variable: PaTD                 Importance: 0.0
# Variable: Int                  Importance: 0.0
# Variable: RuTD                 Importance: 0.0
# Variable: ARI                  Importance: 0.0
# Variable: ATL                  Importance: 0.0
# Variable: BAL                  Importance: 0.0
# Variable: BUF                  Importance: 0.0
# Variable: CAR                  Importance: 0.0
# Variable: CHI                  Importance: 0.0
# Variable: CIN                  Importance: 0.0
# Variable: CLE                  Importance: 0.0
# Variable: DAL                  Importance: 0.0
# Variable: DEN                  Importance: 0.0
# Variable: DET                  Importance: 0.0
# Variable: GNB                  Importance: 0.0
# Variable: HOU                  Importance: 0.0
# Variable: JAX                  Importance: 0.0
# Variable: KAN                  Importance: 0.0
# Variable: LAR                  Importance: 0.0
# Variable: MIA                  Importance: 0.0
# Variable: MIN                  Importance: 0.0
# Variable: NEP                  Importance: 0.0
# Variable: NOR                  Importance: 0.0
# Variable: NYG                  Importance: 0.0
# Variable: NYJ                  Importance: 0.0
# Variable: OAK                  Importance: 0.0
# Variable: PHI                  Importance: 0.0
# Variable: PIT                  Importance: 0.0
# Variable: RAM                  Importance: 0.0
# Variable: SEA                  Importance: 0.0
# Variable: SFO                  Importance: 0.0
# Variable: STL                  Importance: 0.0
# Variable: TBB                  Importance: 0.0
# Variable: TEN                  Importance: 0.0
# Variable: WAS                  Importance: 0.0
# RB
# Variable: Overall              Importance: 0.52
# Variable: Std.Dev              Importance: 0.07
# Variable: Pick                 Importance: 0.04
# Variable: RuTD                 Importance: 0.04
# Variable: Rec                  Importance: 0.04
# Variable: Wt                   Importance: 0.02
# Variable: Dash                 Importance: 0.02
# Variable: Vertical             Importance: 0.02
# Variable: Bench                Importance: 0.02
# Variable: Three_Cone           Importance: 0.02
# Variable: RuYds                Importance: 0.02
# Variable: RuAtt                Importance: 0.02
# Variable: ReYds                Importance: 0.02
# Variable: Age                  Importance: 0.01
# Variable: Broad_Jump           Importance: 0.01
# Variable: Shuttle              Importance: 0.01
# Variable: height               Importance: 0.01
# Variable: G                    Importance: 0.01
# Variable: ReTD                 Importance: 0.01
# Variable: agesq                Importance: 0.01
# Variable: ARI                  Importance: 0.01
# Variable: IND                  Importance: 0.01
# Variable: NOR                  Importance: 0.01
# Variable: Cmp                  Importance: 0.0
# Variable: PaAtt                Importance: 0.0
# Variable: Pct                  Importance: 0.0
# Variable: PaYds                Importance: 0.0
# Variable: PaTD                 Importance: 0.0
# Variable: Int                  Importance: 0.0
# Variable: ATL                  Importance: 0.0
# Variable: BAL                  Importance: 0.0
# Variable: BUF                  Importance: 0.0
# Variable: CAR                  Importance: 0.0
# Variable: CHI                  Importance: 0.0
# Variable: CIN                  Importance: 0.0
# Variable: CLE                  Importance: 0.0
# Variable: DAL                  Importance: 0.0
# Variable: DEN                  Importance: 0.0
# Variable: DET                  Importance: 0.0
# Variable: FA                   Importance: 0.0
# Variable: GNB                  Importance: 0.0
# Variable: HOU                  Importance: 0.0
# Variable: JAX                  Importance: 0.0
# Variable: KAN                  Importance: 0.0
# Variable: LAC                  Importance: 0.0
# Variable: LAR                  Importance: 0.0
# Variable: MIA                  Importance: 0.0
# Variable: MIN                  Importance: 0.0
# Variable: NEP                  Importance: 0.0
# Variable: NYG                  Importance: 0.0
# Variable: NYJ                  Importance: 0.0
# Variable: OAK                  Importance: 0.0
# Variable: PHI                  Importance: 0.0
# Variable: PIT                  Importance: 0.0
# Variable: SDC                  Importance: 0.0
# Variable: SEA                  Importance: 0.0
# Variable: SFO                  Importance: 0.0
# Variable: STL                  Importance: 0.0
# Variable: TBB                  Importance: 0.0
# Variable: TEN                  Importance: 0.0
# Variable: WAS                  Importance: 0.0
# QB
# Variable: Overall              Importance: 0.28
# Variable: Pick                 Importance: 0.22
# Variable: Pct                  Importance: 0.09
# Variable: RuYds                Importance: 0.06
# Variable: Int                  Importance: 0.04
# Variable: RuTD                 Importance: 0.04
# Variable: Wt                   Importance: 0.03
# Variable: Dash                 Importance: 0.03
# Variable: Vertical             Importance: 0.02
# Variable: Broad_Jump           Importance: 0.02
# Variable: Three_Cone           Importance: 0.02
# Variable: Shuttle              Importance: 0.02
# Variable: PaYds                Importance: 0.02
# Variable: PaTD                 Importance: 0.02
# Variable: RuAtt                Importance: 0.02
# Variable: height               Importance: 0.01
# Variable: G                    Importance: 0.01
# Variable: Cmp                  Importance: 0.01
# Variable: PaAtt                Importance: 0.01
# Variable: KAN                  Importance: 0.01
# Variable: Age                  Importance: 0.0
# Variable: Bench                Importance: 0.0
# Variable: ReYds                Importance: 0.0
# Variable: ReTD                 Importance: 0.0
# Variable: Rec                  Importance: 0.0
# Variable: Std.Dev              Importance: 0.0
# Variable: agesq                Importance: 0.0
# Variable: ARI                  Importance: 0.0
# Variable: ATL                  Importance: 0.0
# Variable: BAL                  Importance: 0.0
# Variable: BUF                  Importance: 0.0
# Variable: CAR                  Importance: 0.0
# Variable: CHI                  Importance: 0.0
# Variable: CIN                  Importance: 0.0
# Variable: CLE                  Importance: 0.0
# Variable: DAL                  Importance: 0.0
# Variable: DEN                  Importance: 0.0
# Variable: DET                  Importance: 0.0
# Variable: IND                  Importance: 0.0
# Variable: JAX                  Importance: 0.0
# Variable: MIA                  Importance: 0.0
# Variable: MIN                  Importance: 0.0
# Variable: NOR                  Importance: 0.0
# Variable: NYG                  Importance: 0.0
# Variable: NYJ                  Importance: 0.0
# Variable: OAK                  Importance: 0.0
# Variable: PHI                  Importance: 0.0
# Variable: PIT                  Importance: 0.0
# Variable: RAM                  Importance: 0.0
# Variable: SDC                  Importance: 0.0
# Variable: SEA                  Importance: 0.0
# Variable: SFO                  Importance: 0.0
# Variable: STL                  Importance: 0.0
# Variable: TBB                  Importance: 0.0
# Variable: TEN                  Importance: 0.0
# Variable: WAS                  Importance: 0.0
# WR
# residual rank
# points fit
# RB
# residual rank
# points fit
# QB
# residual rank
# points fit
# TE
# residual rank
# points fit
#      Year Pos  ADP_As_Predictor  Model_As_Predictor
# 0  2019.0  WR              82.0                82.5
# 1  2019.0  RB              82.5                82.5
# 2  2019.0  QB              10.0                10.0
# 3  2019.0  TE               2.0                 2.0

# %%
output_dict = copy.deepcopy(final_dict)

#output_dict['TE'][['Names', 'prediction', 'Overall', 'PPR', 'Win_PCT']]\
#.sort_values('prediction', ascending = False)\
#.to_csv('test.csv', index = False)

output_dict['TE'].sort_values('prediction', ascending = False)[['Names', 'prediction', 'Overall', 'pts_next_year']]
# Out:
#             Names  prediction  Overall  pts_next_year
# 0  T.J. Hockenson   81.584100   118.25            0.0
# 1       Noah Fant   60.840133   148.50            0.0
# 2  Kahale Warring   47.197600   153.00            0.0
