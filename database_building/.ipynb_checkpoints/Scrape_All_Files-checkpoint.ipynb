# %%
###################### Import Packages #############################################
import requests
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
import statsmodels.formula.api as smf
from ffb_functions import *
pd.set_option('display.max_columns', 500)
pd.options.display.max_rows = 999

# %%
#database = data_assembly(1970, 2020)                            # can go back to 1970
#database.to_csv('profootballreference.csv', index = False)      # save original db
database
# Out:
#         Rk              Name   Tm FantPos Age   G  GS Cmp PaAtt PaYds PaTD  \
# 0        1       Ron Johnson  NYG      RB  23  14  14   0     0     0    0
# 1        2       Dick Gordon  CHI      WR  26  14  14   0     0     0    0
# 2        3   Gene Washington  SFO      WR  23  13  13   0     0     0    0
# 3        4     Gary Garrison  SDG      WR  26  14  14   0     0     0    0
# 4        5    MacArthur Lane  STL      RB  28  14  14   0     0     0    0
# ...    ...               ...  ...     ...  ..  ..  ..  ..   ...   ...  ...
# 26970  616   Ray-Ray McCloud  CAR     NaN  23   6   0   0     0     0    0
# 26971  617  Darrius Shepherd  GNB      WR  24   6   0   0     0     0    0
# 26972  618   Jarrett Stidham  NWE      QB  23   3   0   2     4    14    0
# 26973  619    Michael Walker  JAX      WR  23   7   0   0     0     0    0
# 26974  620     Corey Clement  PHI     NaN  25   4   0   0     0     0    0
#
# ...

# %%
#adp_frame = newer_assembly(2013, 2020, 'not_rookie')         #can go back to 1999, end year is 1 year greater than other end years
#adp_frame.to_csv('adp.csv', index = False)
adp_frame.loc[adp_frame.Year == 2019]
#adp_frame.to_csv('adp_latest.csv', index = False)
# Out:
#                           Name   Tm Overall  Year
# 1713            Saquon Barkley  NYG    1.45  2019
# 1714       Christian McCaffrey  CAR    2.65  2019
# 1715              Alvin Kamara  NOR    2.81  2019
# 1716           Ezekiel Elliott  DAL    5.26  2019
# 1717           DeAndre Hopkins  HOU    6.03  2019
# 1718             Davante Adams  GNB    8.89  2019
# 1719             David Johnson  ARI   10.28  2019
# 1720              James Conner  PIT   10.98  2019
# 1721              Le'Veon Bell  NYJ   11.17  2019
# 1722            Michael Thomas  NOR   11.27  2019
# 1723               Julio Jones  ATL   12.54  2019
# 1724             Odell Beckham  CLE   13.32  2019
# 1725           Patrick Mahomes  KAN   14.53  2019
# 1726       JuJu Smith-Schuster  PIT   14.83  2019
# 1727               Todd Gurley  LAR   14.84  2019
# 1728              Travis Kelce  KAN   15.91  2019
# 1729               Dalvin Cook  MIN   17.18  2019
# 1730                Nick Chubb  CLE   17.26  2019
# ...

# %%
# need to visit this site before new scraping or else there are problems
#adp_frame_alt = ADP_assembly(2007, 2020)         # 2010 is earliest
#adp_frame_alt.to_csv('std.csv', index = False)

adp_frame_alt
# Out:
#                     Name  Year  Std.Dev
# 0          Chris Johnson  2010      1.3
# 1        Adrian Peterson  2010      1.3
# 2               Ray Rice  2010      1.5
# 3     Maurice Jones-Drew  2010      1.5
# 4          Andre Johnson  2010      2.6
# ...                  ...   ...      ...
# 1845        Robbie Gould  2019      6.0
# 1846   Giorgio Tavecchio  2019     11.1
# 1847         Jason Myers  2019     11.8
# 1848          Dan Bailey  2019      4.0
# 1849         Brett Maher  2019      4.6
#
# [1850 rows x 3 columns]

# %%
#adp_frame_alt.loc[adp_frame_alt.Year == 2019]

# %%
draft = rookie_assembly(1936, 2020)              # goes back to 1936
#draft.to_csv('draft.csv', index = False)

# %%
comb_0 = combine_assembly(2000, 2020)            # goes back to 2000
#comb_0.to_csv('combine.csv', index = False)

# %%
team_temp = team_assembly(2003, 2019)            # goes back to 2003
#team_temp.to_csv('teams.csv', index = False)

# %%
college_0 = college_assembly(1990, 2001)         # need to find how far this goes back to
#college_0.to_csv('college_stats.csv', index = False)

# %%
college_0
# Out:
#                   Name  Year         School      Conf   G  Cmp PaAtt   Pct  \
# 0         Chris Weinke  2000  Florida State       ACC  12  266   431  61.7
# 1       Bart Hendricks  2000    Boise State  Big West  11  210   347  60.5
# 2          John Turman  2000           Pitt  Big East  11  128   233  54.9
# 3        Mike Thiessen  2000      Air Force       MWC  11  112   195  57.4
# 4     Jonathan Beasley  2000   Kansas State    Big 12  13  156   313  49.8
# ...                ...   ...            ...       ...  ..  ...   ...   ...
# 7317     Hendon Hooker  2019  Virginia Tech       ACC   7    0     0     0
# 7318      Cam Roberson  2019  Massachusetts       Ind  11    0     0     0
# 7319    Charlie Booker  2019           Rice      CUSA   7    0     0     0
# 7320     Johnny Langan  2019        Rutgers   Big Ten   8    0     0     0
# 7321      Stone Smartt  2019   Old Dominion      CUSA   8    0     0     0
#
#      PaYds PaTD Int RuYds RuTD RuAtt ReYds ReTD Rec
# ...
