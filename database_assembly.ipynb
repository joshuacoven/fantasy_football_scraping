# %%
import requests
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup

#Pull data from Pro Football Reference
database = []
start_year = 2014 #Input Earliest Year of Data
current_year = 2019 #Input Current Year
for x in range(start_year, current_year):
    page = requests.get("https://www.pro-football-reference.com/years/%d/fantasy.htm" % x)
    soup = BeautifulSoup(page.content, 'html.parser')
    table = soup.find_all('table')[0]
    df = pd.read_html(str(table), header = 1)
    dfyear = df[0]
    dfyear['Year'] = x
    if x == start_year:
        database = dfyear
    else: database = database.append(dfyear, ignore_index = True)
        
#Rename columns, eliminate duplicate column titles as rows
database = database.rename(columns = {'Player':'Name', 'Att':'PaAtt', 'Yds':'PaYds', 'TD':'PaTD','Att.1':'RuAtt', 'Yds.1':'RuYds', 'TD.1':'RuTD', 'Y/A':'RuY/A', 'Y/R':'ReYds/R', 'Att.2':'ReAtt', 'Yds.2':'ReYds', 'TD.2':'ReTD'})
database = database[database.Rk != 'Rk']

#Clean out +'s and *'s from names to help linking players across years
for x in range(len(database.iloc[:, database.columns.get_loc('Name')])):
    if database.iloc[x, database.columns.get_loc('Name')].endswith('+'):
        database.iloc[x, database.columns.get_loc('Name')] = database.iloc[x, database.columns.get_loc('Name')][:-1]
for x in range(len(database.iloc[:, database.columns.get_loc('Name')])):
    if database.iloc[x, database.columns.get_loc('Name')].endswith('*'):
        database.iloc[x, database.columns.get_loc('Name')] = database.iloc[x, database.columns.get_loc('Name')][:-1]

# %%
database
# Out:
#        Rk               Name   Tm FantPos Age   G  GS  Cmp PaAtt PaYds  ...   \
# 0       1     DeMarco Murray  DAL      RB  26  16  16    0     0     0  ...
# 1       2       Le'Veon Bell  PIT      RB  22  16  16    0     0     0  ...
# 2       3     Marshawn Lynch  SEA      RB  28  16  14    0     0     0  ...
# 3       4      Antonio Brown  PIT      WR  26  16  16    2     2    20  ...
# 4       5         Matt Forte  CHI      RB  29  16  16    0     0     0  ...
# 5       6       Arian Foster  HOU      RB  28  13  13    1     1     5  ...
# 6       7         Eddie Lacy  GNB      RB  24  16  16    0     0     0  ...
# 7       8       Jordy Nelson  GNB      WR  29  16  16    0     0     0  ...
# 8       9   Demaryius Thomas  DEN      WR  27  16  16    0     0     0  ...
# 9      10         Dez Bryant  DAL      WR  26  16  16    0     0     0  ...
# 10     11     Rob Gronkowski  NWE      TE  25  15  10    0     0     0  ...
# 11     12      Aaron Rodgers  GNB      QB  31  16  16  341   520  4381  ...
# 12     13     Jamaal Charles  KAN      RB  28  15  15    0     0     0  ...
# 13     14        Andrew Luck  IND      QB  25  16  16  380   616  4761  ...
# 14     15     Justin Forsett  BAL      RB  29  16  14    0     0     0  ...
# 15     16      Odell Beckham  NYG      WR  22  12  11    0     1     0  ...
# 16     17       Randall Cobb  GNB      WR  24  16  16    0     0     0  ...
# 17     18   Emmanuel Sanders  DEN      WR  27  16  16    0     0     0  ...
# 18     19        Julio Jones  ATL      WR  25  15  15    0     0     0  ...
# 19     20      Jeremy Maclin  PHI      WR  26  16  16    0     0     0  ...
# 20     21       Lamar Miller  MIA      RB  23  16  16    0     0     0  ...
# 21     22     Russell Wilson  SEA      QB  26  16  16  285   452  3475  ...
# 22     23        Jeremy Hill  CIN      RB  22  16   8    0     0     0  ...
# 23     24      Antonio Gates  SDG      TE  34  16  14    0     0     0  ...
# 24     25      C.J. Anderson  DEN      RB  23  15   7    0     0     0  ...
# 25     26        T.Y. Hilton  IND      WR  25  15  15    0     0     0  ...
# 26     27       Jimmy Graham  NOR      TE  28  16  13    0     0     0  ...
# 27     28         Mike Evans  TAM      WR  21  15  15    0     0     0  ...
# 28     29     Alshon Jeffery  CHI      WR  24  16  16    0     0     0  ...
# 30     30       LeSean McCoy  PHI      RB  26  16  16    0     0     0  ...
# ...   ...                ...  ...     ...  ..  ..  ..  ...   ...   ...  ...
# 3167  593     Alonzo Russell  NYG     NaN  26   1   0    0     0     0  ...
# 3168  594       Mark Sanchez  WAS      QB  32   2   1   19    35   138  ...
# 3169  595        Matt Schaub  ATL      QB  37   3   0    5     7    20  ...
# 3170  596      Mason Schreck  CIN     NaN  25   6   0    0     0     0  ...
# 3171  597       Boston Scott  PHI     NaN  23   2   0    0     0     0  ...
# 3172  598      Da'Mari Scott  BUF     NaN  23   3   0    0     0     0  ...
# 3173  599           Cam Sims  WAS     NaN  22   1   0    0     0     0  ...
# 3175  600     Matthew Slater  NWE     NaN  33  16   0    0     0     0  ...
# 3176  601        Nate Solder  NYG     NaN  30  16  16    0     0     0  ...
# 3177  602       Brandon Tate  NOR     NaN  31   1   0    0     0     0  ...
# 3178  603        Mike Thomas  LAR     NaN  24   1   0    0     0     0  ...
# 3179  604       Danny Vitale  GNB      RB  25   5   0    0     0     0  ...
# 3180  605      Clive Walford  NYJ     NaN  27   1   1    0     0     0  ...
# 3181  606       Mike Wallace  PHI     NaN  32   2   2    0     0     0  ...
# 3182  607     Brandon Weeden  HOU      QB  35   1   0    0     0     0  ...
# 3183  608     Markus Wheaton  PHI     NaN  27   1   0    0     0     0  ...
# 3184  609          Cole Wick  SFO     NaN  25   5   0    0     0     0  ...
# 3185  610  Jonathan Williams  NOR      RB  24   3   0    0     0     0  ...
# 3186  611        Deon Yelder  KAN     NaN  23   3   0    0     0     0  ...
# 3187  612    Jacoby Brissett  IND      QB  26   4   0    2     4     2  ...
# 3188  613        Brian Hoyer  NWE      QB  33   5   0    1     2     7  ...
# 3189  614        J'Mon Moore  GNB      WR  23  12   0    0     0     0  ...
# 30    NaN  NaN    171  199.4  208.4  185.4   52      12     30  2014
# ...   ...  ...    ...    ...    ...    ...  ...     ...    ...   ...
# 3167  NaN  NaN    NaN    NaN    NaN    NaN  NaN     227    NaN  2018
# 3168  NaN  NaN    NaN    0.3    3.3    3.3  NaN      64    NaN  2018
# 3169  NaN  NaN    NaN    1.1    1.1    0.6  NaN      66    NaN  2018
# 3170  NaN  NaN    NaN    NaN    NaN    NaN  NaN     121    NaN  2018
# 3171  NaN  NaN    NaN    NaN    NaN    NaN  NaN     158    NaN  2018
# 3172  NaN  NaN    NaN    NaN    NaN    NaN  NaN     224    NaN  2018
# 3173  NaN  NaN    NaN    NaN    NaN    NaN  NaN     238    NaN  2018
# 3175  NaN  NaN    NaN    NaN    NaN    NaN  NaN     217    NaN  2018
# 3176  NaN  NaN    NaN    NaN    NaN    NaN  NaN     135    NaN  2018
# 3177  NaN  NaN    NaN    NaN    NaN    NaN  NaN     214    NaN  2018
# 3178  NaN  NaN    NaN    NaN    NaN    NaN  NaN     207    NaN  2018
# 3179  NaN  NaN    NaN    1.2    1.2    0.7  NaN     152    NaN  2018
# 3180  NaN  NaN    NaN    NaN    NaN    NaN  NaN     122    NaN  2018
# 3181  NaN  NaN    NaN    NaN    NaN    NaN  NaN     209    NaN  2018
# 3182  NaN  NaN    NaN   -0.1   -0.1   -0.1  NaN      70    NaN  2018
# 3183  NaN  NaN    NaN    NaN    NaN    NaN  NaN     225    NaN  2018
# 3184  NaN  NaN    NaN    NaN    NaN    NaN  NaN     130    NaN  2018
# 3185  NaN  NaN    NaN    1.1    1.1    0.6  NaN     153    NaN  2018
# 3186  NaN  NaN    NaN    NaN    NaN    NaN  NaN     127    NaN  2018
# 3187  NaN  NaN     -1   -0.6   -0.6   -0.6  NaN      72    NaN  2018
# 3188  NaN  NaN     -1   -0.5   -0.5   -0.5  NaN      71    NaN  2018
# 3189  NaN  NaN     -1    1.5    2.5    0.5  NaN     241    NaN  2018
# 3190  NaN  NaN     -1   -1.5   -0.5   -1.5  NaN      73    NaN  2018
# 3191  NaN  NaN     -1   -1.1   -1.1   -1.1  NaN     242    NaN  2018
# 3192  NaN  NaN     -1    0.3    1.3   -0.2  NaN     166    NaN  2018
# 3193  NaN  NaN     -2   -2.0   -1.0   -2.0  NaN     246    NaN  2018
# 3194  NaN  NaN     -2   -0.7    0.3   -1.2  NaN     243    NaN  2018
# 3195  NaN  NaN     -2   -2.2   -1.2   -1.2  NaN      74    NaN  2018
# 3196  NaN  NaN     -2   -2.0   -1.0   -2.0  NaN     245    NaN  2018
# 3197  NaN  NaN     -2   -2.0   -1.0   -2.0  NaN     244    NaN  2018
#
# [3097 rows x 34 columns]
