# %%
import requests
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
import statsmodels.formula.api as smf

#Pull data from Pro Football Reference
def data_assembly(start_year, current_year):
    database = []
    #start_year = 2014 #Input Earliest Year of Data
    #current_year = 2019 #Input Current Year
    for x in range(start_year, current_year):
        page = requests.get("https://www.pro-football-reference.com/years/%d/fantasy.htm" % x)
        soup = BeautifulSoup(page.content, 'html.parser')
        table = soup.find_all('table')[0]
        df = pd.read_html(str(table), header = 1)
        dfyear = df[0]
        dfyear['Year'] = x
        if x == start_year:
            database = dfyear
        else: database = database.append(dfyear, ignore_index = True)

    #Rename columns, eliminate duplicate column titles as rows
    database = database.rename(columns = {'Player':'Name', 'Att':'PaAtt', 'Yds':'PaYds', 'TD':'PaTD','Att.1':'RuAtt', 'Yds.1':'RuYds', 'TD.1':'RuTD', 'Y/A':'RuY/A', 'Y/R':'ReYds/R', 'Att.2':'ReAtt', 'Yds.2':'ReYds', 'TD.2':'ReTD'})
    database = database[database.Rk != 'Rk']

    database['Name'] = database['Name'].apply(lambda x: x[0:len(x)-1] if x[len(x)-1] == '+' else x)
    database['Name'] = database['Name'].apply(lambda x: x[0:len(x)-1] if x[len(x)-1] == '*' else x)
    return database

def shift_col(frame, new_name, col_to_shift, magnitude):
    frame1 = frame.sort_values(['Name', 'Year']).reset_index(drop = True)
    frame1[new_name] = frame1[col_to_shift].shift(magnitude)
    for i in range(len(frame1) - 1):
        if frame1.loc[i, 'Name'] != frame1.loc[i+1, 'Name']:
            if magnitude == -1:
                frame1.loc[i, new_name] = np.nan
            elif magnitude == 1:
                frame1.loc[i+1, new_name] = np.nan
    return frame1

# %%
database = data_assembly(2014, 2019)
shifted = shift_col(database, 'pts_next_year', 'PPR', -1)
shifted = shift_col(shifted, 'G_prev_year', 'G', 1)
cols_to_change = ['VBD',
                  'Age',
                  'PPR',
                  'pts_next_year',
                  'G_prev_year',
                  'GS',
                  'G',
                  'PaTD',
                  'RuTD',
                  'ReTD',
                  'PaYds',
                  'RuYds',
                  'ReYds',
                 'Rec']
for col in cols_to_change:
    shifted[col] = shifted[col].astype(float)
shifted['season_frac_1'] = shifted['G'] / 16
shifted['season_frac_2'] = (shifted['G'] + shifted['G_prev_year']) / 32
shifted['agesq'] = shifted['Age'] * shifted['Age']

# %%
shifted
# Out:
#        Rk               Name   Tm FantPos   Age     G    GS  Cmp PaAtt  \
# 0     357         A.J. Derby  2TM      TE  25.0  10.0   3.0    0     0
# 1     271         A.J. Derby  2TM      TE  26.0  11.0   1.0    0     0
# 2     388         A.J. Derby  MIA      TE  27.0   4.0   0.0    0     0
# 3      59         A.J. Green  CIN      WR  26.0  13.0  13.0    0     0
# 4      17         A.J. Green  CIN      WR  27.0  16.0  16.0    0     0
# 5     101         A.J. Green  CIN      WR  28.0  10.0  10.0    0     0
# 6      27         A.J. Green  CIN      WR  29.0  16.0  16.0    0     0
# 7     118         A.J. Green  CIN      WR  30.0   9.0   9.0    0     0
# 8     403       A.J. Jenkins  KAN      WR  25.0   9.0   2.0    0     0
# 9     620      A.J. McCarron  CIN     NaN  24.0   0.0   NaN    0     0
# 10    218      A.J. McCarron  CIN      QB  25.0   7.0   3.0   79   119
# 11    555      A.J. McCarron  CIN     NaN  26.0   1.0   0.0    0     0
# 12    476      A.J. McCarron  CIN      QB  27.0   3.0   0.0    7    14
# 13    583      A.J. McCarron  OAK      QB  28.0   2.0   0.0    1     3
# 14    422    Aaron Burbridge  SFO      WR  23.0  16.0   3.0    0     0
# 15    452       Aaron Dobson  NWE      WR  23.0   4.0   1.0    0     0
# 16    372       Aaron Dobson  NWE      WR  24.0   8.0   3.0    0     0
# 17    164        Aaron Jones  GNB      RB  23.0  12.0   4.0    0     0
# 18     62        Aaron Jones  GNB      RB  24.0  12.0   8.0    0     0
# 19    637       Aaron Murray  KAN     NaN  24.0   0.0   NaN    0     0
# 20    493    Aaron Ripkowski  GNB      RB  23.0  15.0   0.0    0     0
# 21    248    Aaron Ripkowski  GNB      RB  24.0  16.0   8.0    0     0
# 22    450    Aaron Ripkowski  GNB      RB  25.0  16.0   2.0    0     0
# 23     12      Aaron Rodgers  GNB      QB  31.0  16.0  16.0  341   520
# 24     52      Aaron Rodgers  GNB      QB  32.0  16.0  16.0  347   572
# 25      4      Aaron Rodgers  GNB      QB  33.0  16.0  16.0  401   610
# 26     95      Aaron Rodgers  GNB      QB  34.0   7.0   7.0  154   238
# 27     43      Aaron Rodgers  GNB      QB  35.0  16.0  16.0  372   597
# 28    459        Ace Sanders  JAX      WR  23.0  12.0   0.0    0     0
# 29    267     Adam Humphries  TAM      WR  22.0  13.0   0.0    0     0
# ...   ...                ...  ...     ...   ...   ...   ...  ...   ...
# 3067  564         Zac Dysert  DEN     NaN  24.0   0.0   NaN    0     0
# 3068  238          Zac Stacy  STL      RB  23.0  13.0   5.0    0     0
# 3069  334          Zac Stacy  NYJ      RB  24.0   8.0   0.0    0     0
# 3070  147          Zach Ertz  PHI      TE  24.0  16.0   5.0    0     0
# 3071   66          Zach Ertz  PHI      TE  25.0  15.0   7.0    0     0
# 3072   49          Zach Ertz  PHI      TE  26.0  14.0  12.0    0     0
# 3073   21          Zach Ertz  PHI      TE  27.0  14.0  13.0    0     0
# 3074   17          Zach Ertz  PHI      TE  28.0  16.0  16.0    0     0
# 3075  615          Zach Line  MIN     NaN  24.0   1.0   0.0    0     0
# 3076  285          Zach Line  MIN      RB  25.0  16.0   5.0    0     0
# 3077  482          Zach Line  MIN      RB  26.0  15.0   4.0    0     0
# 3078  386          Zach Line  NOR      RB  27.0  12.0   4.0    0     0
# 3079  346          Zach Line  NOR      RB  28.0  16.0   6.0    0     0
# 3080  168  Zach Mettenberger  TEN      QB  23.0   7.0   6.0  107   179
# 3081  244  Zach Mettenberger  TEN      QB  24.0   7.0   4.0  101   166
# 3082  413        Zach Miller  SEA      TE  29.0   3.0   3.0    0     0
# 3083  626        Zach Miller  CHI     NaN  30.0   0.0   NaN    0     0
# 3084  169        Zach Miller  CHI      TE  31.0  15.0  14.0    0     0
# 3085  172        Zach Miller  CHI      TE  32.0  10.0   8.0    0     0
# 3086  267        Zach Miller  CHI      TE  33.0   8.0   6.0    0     0
# 3087  253        Zach Pascal  IND      WR  24.0  16.0   4.0    0     0
# 3088  406       Zach Sudfeld  NYJ      TE  25.0  16.0   3.0    0     0
# 3089  440        Zach Zenner  DET      RB  24.0   6.0   1.0    0     0
# 3090  167        Zach Zenner  DET      RB  25.0  14.0   4.0    0     0
# 3091  406        Zach Zenner  DET      RB  26.0   8.0   0.0    0     0
# 3092  222        Zach Zenner  DET      RB  27.0   8.0   1.0    0     0
# 3093  230          Zay Jones  BUF      WR  22.0  15.0  10.0    0     0
# 3094  113          Zay Jones  BUF      WR  23.0  16.0  15.0    0     1
# 3095  354      Zurlon Tipton  IND      RB  24.0   6.0   0.0    0     0
# 3096  436      Zurlon Tipton  IND      RB  25.0  10.0   0.0    0     0
#
#        PaYds  ...   FDPt    VBD PosRank  OvRank  Year  pts_next_year  \
# 0        0.0  ...   22.0    NaN      62     NaN  2016           55.4
# 1        0.0  ...   44.9    NaN      42     NaN  2017           13.8
# 2        0.0  ...   12.3    NaN      77     NaN  2018            NaN
# 3        0.0  ...  170.8   13.0      23      59  2014          273.7
# 4        0.0  ...  230.7   63.0       8      17  2015          186.4
# 5        0.0  ...  153.4    NaN      35     NaN  2016          226.8
# 6        0.0  ...  189.3   41.0      10      27  2017          149.4
# 7        0.0  ...  126.4    NaN      37     NaN  2018            NaN
# 8        0.0  ...   13.6    NaN     155     NaN  2014            NaN
# 9        0.0  ...    NaN    NaN      70     NaN  2014           55.3
# 10     854.0  ...   57.3    NaN      39     NaN  2015            NaN
# 11       0.0  ...    NaN    NaN      67     NaN  2016            2.6
# 12      66.0  ...    2.6    NaN      60     NaN  2017            0.1
# 13       8.0  ...    0.1    NaN      65     NaN  2018            NaN
# 14       0.0  ...   10.3    NaN     168     NaN  2016            NaN
# 15       0.0  ...    5.3    NaN     179     NaN  2014           27.1
# 16       0.0  ...   20.6    NaN     146     NaN  2015            NaN
# 17       0.0  ...   75.5    NaN      50     NaN  2017          171.4
# 18       0.0  ...  158.4   10.0      23      62  2018            NaN
# 19       0.0  ...    NaN    NaN      93     NaN  2014            NaN
# 20       0.0  ...    2.3    NaN     146     NaN  2015           46.6
# 21       0.0  ...   42.1    NaN      71     NaN  2016           12.2
# 22       0.0  ...    8.7    NaN     127     NaN  2017            NaN
# 23    4381.0  ...  359.1   93.0       1      12  2014          301.2
# 24    3821.0  ...  309.2   20.0       7      52  2015          380.0
# 25    4428.0  ...  387.0  114.0       1       4  2016          129.6
# 26    1675.0  ...  135.6    NaN      29     NaN  2017          312.6
# 27    4442.0  ...  314.6   30.0       6      43  2018            NaN
# 28       0.0  ...    6.5    NaN     180     NaN  2014            NaN
# 29       0.0  ...   45.5    NaN     108     NaN  2015          133.0
# ...      ...  ...    ...    ...     ...     ...   ...            ...
# 3067     0.0  ...    NaN    NaN      87     NaN  2014            NaN
# 3068     0.0  ...   55.5    NaN      70     NaN  2014           30.4
# 3069     0.0  ...   25.9    NaN      99     NaN  2015            NaN
# 3070     0.0  ...  115.2    NaN      13     NaN  2014          170.3
# 3071     0.0  ...  132.8    8.0      10      66  2015          183.6
# 3072     0.0  ...  144.6   16.0       8      49  2016          202.4
# 3073     0.0  ...  165.4   47.0       3      21  2017          280.3
# 3074     0.0  ...  222.3   81.0       3      17  2018            NaN
# 3075     0.0  ...    NaN    NaN      10     NaN  2014           34.5
# 3076     0.0  ...   31.5    NaN      83     NaN  2015            1.5
# 3077     0.0  ...    1.5    NaN     147     NaN  2016           11.6
# 3078     0.0  ...   10.6    NaN     115     NaN  2017           22.5
# 3079     0.0  ...   20.0    NaN      91     NaN  2018            NaN
# 3080  1412.0  ...   77.9    NaN      38     NaN  2014           42.2
# 3081   935.0  ...   49.2    NaN      40     NaN  2015            NaN
# 3082     0.0  ...   10.6    NaN      69     NaN  2014            NaN
# 3083     0.0  ...    NaN    NaN     109     NaN  2014          107.9
# 3084     0.0  ...   90.9    NaN      17     NaN  2015          119.6
# 3085     0.0  ...   96.1    NaN      21     NaN  2016           55.6
# 3086     0.0  ...   45.6    NaN      39     NaN  2017            NaN
# 3087     0.0  ...   53.3    NaN     102     NaN  2018            NaN
# 3088     0.0  ...   11.0    NaN      68     NaN  2014            NaN
# 3089     0.0  ...    8.1    NaN     126     NaN  2015           93.0
# 3090     0.0  ...   84.0    NaN      48     NaN  2016            8.6
# 3091     0.0  ...    8.6    NaN     116     NaN  2017           57.1
# 3092     0.0  ...   53.6    NaN      67     NaN  2018            NaN
# 3093     0.0  ...   57.1    NaN      89     NaN  2017          165.2
# 3094     0.0  ...  137.2    NaN      34     NaN  2018            NaN
# 3095     0.0  ...   17.6    NaN     107     NaN  2014           12.7
# 3096     0.0  ...   10.2    NaN     125     NaN  2015            NaN
#
#      G_prev_year  season_frac_1  season_frac_2   agesq
# 0            NaN         0.6250            NaN   625.0
# 1           10.0         0.6875        0.65625   676.0
# 2           11.0         0.2500        0.46875   729.0
# 3            NaN         0.8125            NaN   676.0
# 4           13.0         1.0000        0.90625   729.0
# 5           16.0         0.6250        0.81250   784.0
# 6           10.0         1.0000        0.81250   841.0
# 7           16.0         0.5625        0.78125   900.0
# 8            NaN         0.5625            NaN   625.0
# 9            NaN         0.0000            NaN   576.0
# 10           0.0         0.4375        0.21875   625.0
# 11           7.0         0.0625        0.25000   676.0
# 12           1.0         0.1875        0.12500   729.0
# 13           3.0         0.1250        0.15625   784.0
# 14           NaN         1.0000            NaN   529.0
# 15           NaN         0.2500            NaN   529.0
# 16           4.0         0.5000        0.37500   576.0
# 17           NaN         0.7500            NaN   529.0
# 18          12.0         0.7500        0.75000   576.0
# 19           NaN         0.0000            NaN   576.0
# 20           NaN         0.9375            NaN   529.0
# 21          15.0         1.0000        0.96875   576.0
# 22          16.0         1.0000        1.00000   625.0
# 23           NaN         1.0000            NaN   961.0
# 24          16.0         1.0000        1.00000  1024.0
# 25          16.0         1.0000        1.00000  1089.0
# 26          16.0         0.4375        0.71875  1156.0
# 27           7.0         1.0000        0.71875  1225.0
# 28           NaN         0.7500            NaN   529.0
# 29           NaN         0.8125            NaN   484.0
# ...          ...            ...            ...     ...
# 3067         NaN         0.0000            NaN   576.0
# 3068         NaN         0.8125            NaN   529.0
# 3069        13.0         0.5000        0.65625   576.0
# 3070         NaN         1.0000            NaN   576.0
# 3071        16.0         0.9375        0.96875   625.0
# 3072        15.0         0.8750        0.90625   676.0
# 3073        14.0         0.8750        0.87500   729.0
# 3074        14.0         1.0000        0.93750   784.0
# 3075         NaN         0.0625            NaN   576.0
# 3076         1.0         1.0000        0.53125   625.0
# 3077        16.0         0.9375        0.96875   676.0
# 3078        15.0         0.7500        0.84375   729.0
# 3079        12.0         1.0000        0.87500   784.0
# 3080         NaN         0.4375            NaN   529.0
# 3081         7.0         0.4375        0.43750   576.0
# 3082         NaN         0.1875            NaN   841.0
# 3083         3.0         0.0000        0.09375   900.0
# 3084         0.0         0.9375        0.46875   961.0
# 3085        15.0         0.6250        0.78125  1024.0
# 3086        10.0         0.5000        0.56250  1089.0
# 3087         NaN         1.0000            NaN   576.0
# 3088         NaN         1.0000            NaN   625.0
# 3089         NaN         0.3750            NaN   576.0
# 3090         6.0         0.8750        0.62500   625.0
# 3091        14.0         0.5000        0.68750   676.0
# 3092         8.0         0.5000        0.50000   729.0
# 3093         NaN         0.9375            NaN   484.0
# 3094        15.0         1.0000        0.96875   529.0
# 3095         NaN         0.3750            NaN   576.0
# 3096         6.0         0.6250        0.50000   625.0
#
# [3097 rows x 39 columns]

# %%
pos_dict = {}
for pos in shifted.FantPos.unique():
    pos_dict[pos] = shifted.loc[shifted.FantPos == pos].reset_index(drop = True)
    pos_dict[pos]['season_frac_1'] = pos_dict[pos]['season_frac_1'] - pos_dict[pos]['season_frac_1'].mean()
    pos_dict[pos]['season_frac_2'] = pos_dict[pos]['season_frac_2'] - pos_dict[pos]['season_frac_2'].mean()
    pos_dict[pos]['Age'] = pos_dict[pos]['Age'] - pos_dict[pos]['Age'].mean()
    pos_dict[pos]['agesq'] = pos_dict[pos]['agesq'] - pos_dict[pos]['agesq'].mean()
pos_dict['RB']
# Out:
#       Rk               Name   Tm FantPos      Age     G    GS Cmp PaAtt  \
# 0    164        Aaron Jones  GNB      RB -2.61834  12.0   4.0   0     0
# 1     62        Aaron Jones  GNB      RB -1.61834  12.0   8.0   0     0
# 2    493    Aaron Ripkowski  GNB      RB -2.61834  15.0   0.0   0     0
# 3    248    Aaron Ripkowski  GNB      RB -1.61834  16.0   8.0   0     0
# 4    450    Aaron Ripkowski  GNB      RB -0.61834  16.0   2.0   0     0
# 5    405    Adrian Peterson  MIN      RB  3.38166   1.0   1.0   0     0
# 6      4    Adrian Peterson  MIN      RB  4.38166  16.0  16.0   0     0
# 7    438    Adrian Peterson  MIN      RB  5.38166   3.0   3.0   0     0
# 8    171    Adrian Peterson  2TM      RB  6.38166  10.0   7.0   0     0
# 9     42    Adrian Peterson  WAS      RB  7.38166  16.0  16.0   0     0
# 10   102     Ahmad Bradshaw  IND      RB  2.38166  10.0   1.0   0     0
# 11   272     Ahmad Bradshaw  IND      RB  3.38166   6.0   0.0   0     0
# 12   374         Akeem Hunt  HOU      RB -3.61834   7.0   1.0   0     0
# 13   359         Akeem Hunt  HOU      RB -2.61834   8.0   0.0   0     0
# 14   445         Akeem Hunt  KAN      RB -1.61834  15.0   0.0   0     0
# 15   369         Alex Armah  CAR      RB -1.61834  16.0   2.0   0     0
# 16   294       Alex Collins  SEA      RB -3.61834  11.0   0.0   0     0
# 17    48       Alex Collins  BAL      RB -2.61834  15.0  12.0   0     0
# 18   133       Alex Collins  BAL      RB -1.61834  10.0  10.0   0     0
# 19   469      Alfonso Smith  SFO      RB  1.38166   6.0   0.0   0     0
# 20   150        Alfred Blue  HOU      RB -2.61834  16.0   3.0   0     0
# 21   128        Alfred Blue  HOU      RB -1.61834  15.0   9.0   0     0
# 22   223        Alfred Blue  HOU      RB -0.61834  14.0   2.0   0     0
# 23   249        Alfred Blue  HOU      RB  0.38166  11.0   0.0   0     0
# 24   159        Alfred Blue  HOU      RB  1.38166  16.0   2.0   0     0
# 25    31      Alfred Morris  WAS      RB  0.38166  16.0  16.0   0     0
# 26   144      Alfred Morris  WAS      RB  1.38166  16.0  16.0   0     0
# 27   260      Alfred Morris  DAL      RB  2.38166  14.0   0.0   0     0
# 28   177      Alfred Morris  DAL      RB  3.38166  14.0   5.0   0     0
# 29   199      Alfred Morris  SFO      RB  4.38166  12.0   1.0   0     0
# ..   ...                ...  ...     ...      ...   ...   ...  ..   ...
# 777  544       Tyler Clutts  DAL      RB  4.38166  16.0   1.0   0     0
# 778  535       Tyler Clutts  DAL      RB  5.38166  16.0   5.0   0     0
# 779  579        Tyler Ervin  HOU      RB -2.61834  12.0   0.0   0     0
# 780  443        Tyler Ervin  HOU      RB -1.61834   4.0   0.0   0     0
# 781  452        Tyler Ervin  HOU      RB -0.61834   9.0   0.0   0     0
# 782  495        Tyler Varga  IND      RB -3.61834   3.0   0.0   0     0
# 783  362        Walt Powell  BUF      RB -0.61834   9.0   2.0   0     0
# 784  162      Wayne Gallman  NYG      RB -2.61834  13.0   1.0   0     0
# 785  286      Wayne Gallman  NYG      RB -1.61834  15.0   2.0   0     0
# 786  246  Wendell Smallwood  PHI      RB -3.61834  13.0   3.0   0     0
# 787  275  Wendell Smallwood  PHI      RB -2.61834   8.0   3.0   0     0
# 788  141  Wendell Smallwood  PHI      RB -1.61834  16.0   6.0   0     0
# 789  456       Will Johnson  PIT      RB -0.61834  16.0   5.0   0     0
# 790  417       Will Johnson  PIT      RB  0.38166  16.0   4.0   0     0
# 791  415     Will Ta'ufo'ou  JAX      RB  2.38166  16.0   4.0   0     0
# 792  508       Will Tukuafu  SEA      RB  4.38166   9.0   2.0   0     0
# 793  409       Will Tukuafu  SEA      RB  5.38166  14.0   1.0   0     0
# 794  570       Will Tukuafu  SEA      RB  6.38166   7.0   1.0   0     0
# 795  238          Zac Stacy  STL      RB -2.61834  13.0   5.0   0     0
# 796  334          Zac Stacy  NYJ      RB -1.61834   8.0   0.0   0     0
# 797  285          Zach Line  MIN      RB -0.61834  16.0   5.0   0     0
# 798  482          Zach Line  MIN      RB  0.38166  15.0   4.0   0     0
# 799  386          Zach Line  NOR      RB  1.38166  12.0   4.0   0     0
# 800  346          Zach Line  NOR      RB  2.38166  16.0   6.0   0     0
# 801  440        Zach Zenner  DET      RB -1.61834   6.0   1.0   0     0
# 802  167        Zach Zenner  DET      RB -0.61834  14.0   4.0   0     0
# 803  406        Zach Zenner  DET      RB  0.38166   8.0   0.0   0     0
# 804  222        Zach Zenner  DET      RB  1.38166   8.0   1.0   0     0
# 805  354      Zurlon Tipton  IND      RB -1.61834   6.0   0.0   0     0
# 806  436      Zurlon Tipton  IND      RB -0.61834  10.0   0.0   0     0
#
#      PaYds  ...   FDPt    VBD PosRank  OvRank  Year  pts_next_year  \
# 0      0.0  ...   75.5    NaN      50     NaN  2017          171.4
# 1      0.0  ...  158.4   10.0      23      62  2018            NaN
# 2      0.0  ...    2.3    NaN     146     NaN  2015           46.6
# 3      0.0  ...   42.1    NaN      71     NaN  2016           12.2
# 4      0.0  ...    8.7    NaN     127     NaN  2017            NaN
# 5      0.0  ...   10.3    NaN     123     NaN  2014          260.7
# 6      0.0  ...  245.7  107.0       2       4  2015            9.0
# 7      0.0  ...    7.5    NaN     126     NaN  2016           78.9
# 8      0.0  ...   73.4    NaN      53     NaN  2017          189.0
# 9      0.0  ...  179.0   34.0      16      42  2018            NaN
# 10     0.0  ...  135.5    NaN      25     NaN  2014           42.9
# 11     0.0  ...   37.9    NaN      81     NaN  2015            NaN
# 12     0.0  ...   16.5    NaN     112     NaN  2015           16.8
# 13     0.0  ...   15.3    NaN     106     NaN  2016            9.4
# 14     0.0  ...    7.4    NaN     126     NaN  2017            NaN
# 15     0.0  ...   14.5    NaN      97     NaN  2018            NaN
# 16     0.0  ...   30.4    NaN      86     NaN  2016          171.0
# 17     0.0  ...  159.5   21.0      16      48  2017          108.6
# 18     0.0  ...  101.1    NaN      39     NaN  2018            NaN
# 19     0.0  ...    4.5    NaN     142     NaN  2014            NaN
# 20     0.0  ...   89.6    NaN      38     NaN  2014          111.7
# 21     0.0  ...  104.2    NaN      39     NaN  2015           62.0
# 22     0.0  ...   56.0    NaN      62     NaN  2016           44.6
# 23     0.0  ...   41.1    NaN      76     NaN  2017           97.3
# 24     0.0  ...   87.3    NaN      49     NaN  2018            NaN
# 25     0.0  ...  179.4   52.0      13      31  2014           96.6
# 26     0.0  ...   91.6    NaN      46     NaN  2015           40.4
# 27     0.0  ...   38.9    NaN      75     NaN  2016           72.2
# 28     0.0  ...   68.7    NaN      56     NaN  2017           68.1
# 29     0.0  ...   64.1    NaN      61     NaN  2018            NaN
# ..     ...  ...    ...    ...     ...     ...   ...            ...
# 777    0.0  ...    0.6    NaN     156     NaN  2014            1.4
# 778    0.0  ...    0.9    NaN     158     NaN  2015            NaN
# 779    0.0  ...   -0.4    NaN     172     NaN  2016           13.0
# 780    0.0  ...    9.0    NaN     128     NaN  2017            6.5
# 781    0.0  ...    5.0    NaN     125     NaN  2018            NaN
# 782    0.0  ...    2.5    NaN     144     NaN  2015            NaN
# 783    0.0  ...   21.2    NaN     104     NaN  2016            NaN
# 784    0.0  ...   87.9    NaN      51     NaN  2017           44.5
# 785    0.0  ...   37.5    NaN      85     NaN  2018            NaN
# 786    0.0  ...   49.7    NaN      70     NaN  2016           46.7
# 787    0.0  ...   40.2    NaN      82     NaN  2017          117.4
# 788    0.0  ...  103.4    NaN      42     NaN  2018            NaN
# 789    0.0  ...    7.1    NaN     138     NaN  2014           12.3
# 790    0.0  ...   11.3    NaN     119     NaN  2015            NaN
# 791    0.0  ...   11.6    NaN     127     NaN  2014            NaN
# 792    0.0  ...    1.1    NaN     154     NaN  2014           11.8
# 793    0.0  ...   11.3    NaN     117     NaN  2015            0.2
# 794    0.0  ...    0.2    NaN     166     NaN  2016            NaN
# 795    0.0  ...   55.5    NaN      70     NaN  2014           30.4
# 796    0.0  ...   25.9    NaN      99     NaN  2015            NaN
# 797    0.0  ...   31.5    NaN      83     NaN  2015            1.5
# 798    0.0  ...    1.5    NaN     147     NaN  2016           11.6
# 799    0.0  ...   10.6    NaN     115     NaN  2017           22.5
# 800    0.0  ...   20.0    NaN      91     NaN  2018            NaN
# 801    0.0  ...    8.1    NaN     126     NaN  2015           93.0
# 802    0.0  ...   84.0    NaN      48     NaN  2016            8.6
# 803    0.0  ...    8.6    NaN     116     NaN  2017           57.1
# 804    0.0  ...   53.6    NaN      67     NaN  2018            NaN
# 805    0.0  ...   17.6    NaN     107     NaN  2014           12.7
# 806    0.0  ...   10.2    NaN     125     NaN  2015            NaN
#
#     G_prev_year  season_frac_1  season_frac_2       agesq
# 0           NaN       0.035936            NaN -135.071871
# 1          12.0       0.035936       0.011947  -88.071871
# 2           NaN       0.223436            NaN -135.071871
# 3          15.0       0.285936       0.230697  -88.071871
# 4          16.0       0.285936       0.261947  -39.071871
# 5           NaN      -0.651564            NaN  176.928129
# 6           1.0       0.285936      -0.206803  235.928129
# 7          16.0      -0.526564      -0.144303  296.928129
# 8           3.0      -0.089064      -0.331803  359.928129
# 9          10.0       0.285936       0.074447  424.928129
# 10          NaN      -0.089064            NaN  119.928129
# 11         10.0      -0.339064      -0.238053  176.928129
# 12          NaN      -0.276564            NaN -180.071871
# 13          7.0      -0.214064      -0.269303 -135.071871
# 14          8.0       0.223436      -0.019303  -88.071871
# 15          9.0       0.285936       0.043197  -88.071871
# 16          NaN      -0.026564            NaN -180.071871
# 17         11.0       0.223436       0.074447 -135.071871
# 18         15.0      -0.089064       0.043197  -88.071871
# 19          NaN      -0.339064            NaN   64.928129
# 20          NaN       0.285936            NaN -135.071871
# 21         16.0       0.223436       0.230697  -88.071871
# 22         15.0       0.160936       0.168197  -39.071871
# 23         14.0      -0.026564       0.043197   11.928129
# 24         11.0       0.285936       0.105697   64.928129
# 25          NaN       0.285936            NaN   11.928129
# 26         16.0       0.285936       0.261947   64.928129
# 27         16.0       0.160936       0.199447  119.928129
# 28         14.0       0.160936       0.136947  176.928129
# 29         14.0       0.035936       0.074447  235.928129
# ..          ...            ...            ...         ...
# 777         NaN       0.285936            NaN  235.928129
# 778        16.0       0.285936       0.261947  296.928129
# 779         NaN       0.035936            NaN -135.071871
# 780        12.0      -0.464064      -0.238053  -88.071871
# 781         4.0      -0.151564      -0.331803  -39.071871
# 782         NaN      -0.526564            NaN -180.071871
# 783         2.0      -0.151564      -0.394303  -39.071871
# 784         NaN       0.098436            NaN -135.071871
# 785        13.0       0.223436       0.136947  -88.071871
# 786         NaN       0.098436            NaN -180.071871
# 787        13.0      -0.214064      -0.081803 -135.071871
# 788         8.0       0.285936       0.011947  -88.071871
# 789         NaN       0.285936            NaN  -39.071871
# 790        16.0       0.285936       0.261947   11.928129
# 791         NaN       0.285936            NaN  119.928129
# 792         NaN      -0.151564            NaN  235.928129
# 793         9.0       0.160936      -0.019303  296.928129
# 794        14.0      -0.276564      -0.081803  359.928129
# 795         NaN       0.098436            NaN -135.071871
# 796        13.0      -0.214064      -0.081803  -88.071871
# 797         1.0       0.285936      -0.206803  -39.071871
# 798        16.0       0.223436       0.230697   11.928129
# 799        15.0       0.035936       0.105697   64.928129
# 800        12.0       0.285936       0.136947  119.928129
# 801         NaN      -0.339064            NaN  -88.071871
# 802         6.0       0.160936      -0.113053  -39.071871
# 803        14.0      -0.214064      -0.050553   11.928129
# 804         8.0      -0.214064      -0.238053   64.928129
# 805         NaN      -0.339064            NaN  -88.071871
# 806         6.0      -0.089064      -0.238053  -39.071871
#
# [807 rows x 39 columns]

# %%
## to help with multicolinearity, can make ryds, tds, rec all per game metrics

all_cols = ['Age', 'agesq', 'season_frac_2']
xcols_dict = {
    'TE': ['ReTD','ReYds', 'Rec'],
    'WR': ['ReTD','ReYds', 'Rec'],
    'QB': ['PaTD','PaYds'],
    'RB': ['RuTD','RuYds', 'ReTD','ReYds', 'Rec'],
}
for pos in xcols_dict:
    print(pos)
    ycol = 'pts_next_year'
    xcols = xcols_dict[pos] + all_cols
    frame1 = pos_dict[pos]
    frame = frame1[['Name', ycol] + xcols].dropna()
    xform = ' + '.join(xcols)
    formula = ycol + " ~ " + xform
    model = smf.ols(formula, frame)
    results = model.fit(cov_type='cluster', cov_kwds={'groups': frame['Name']})
    print(results.summary())
# Out:
# TE
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          pts_next_year   R-squared:                       0.354
# Model:                            OLS   Adj. R-squared:                  0.333
# Method:                 Least Squares   F-statistic:                     13.67
# Date:                Wed, 31 Jul 2019   Prob (F-statistic):           4.21e-11
# Time:                        18:21:54   Log-Likelihood:                -1020.2
# No. Observations:                 189   AIC:                             2054.
# Df Residuals:                     182   BIC:                             2077.
# Df Model:                           6
# Covariance Type:              cluster
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept        22.7225      8.009      2.837      0.005       7.025      38.420
# ReTD              0.4173      2.315      0.180      0.857      -4.119       4.954
# ReYds             0.0913      0.045      2.011      0.044       0.002       0.180
# Rec               0.5839      0.557      1.049      0.294      -0.507       1.675
# Age               5.3637     14.886      0.360      0.719     -23.812      34.540
# agesq            -0.1109      0.257     -0.432      0.666      -0.614       0.392
# season_frac_2     5.0502     24.198      0.209      0.835     -42.376      52.477
# ==============================================================================
# Omnibus:                      122.090   Durbin-Watson:                   2.054
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1452.666
# Skew:                           2.199   Prob(JB):                         0.00
# Kurtosis:                      15.850   Cond. No.                     2.75e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are robust tocluster correlation (cluster)
# [2] The condition number is large, 2.75e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# WR
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          pts_next_year   R-squared:                       0.469
# Model:                            OLS   Adj. R-squared:                  0.460
# Method:                 Least Squares   F-statistic:                     47.92
# Date:                Wed, 31 Jul 2019   Prob (F-statistic):           6.74e-35
# Time:                        18:21:54   Log-Likelihood:                -2007.8
# No. Observations:                 364   AIC:                             4030.
# Df Residuals:                     357   BIC:                             4057.
# Df Model:                           6
# Covariance Type:              cluster
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept        30.5876      5.221      5.859      0.000      20.356      40.820
# ReTD              0.8743      1.896      0.461      0.645      -2.841       4.589
# ReYds             0.0661      0.034      1.951      0.051      -0.000       0.133
# Rec               0.9857      0.396      2.490      0.013       0.210       1.762
# Age             -16.5101     18.241     -0.905      0.365     -52.263      19.242
# agesq             0.2565      0.335      0.765      0.444      -0.400       0.913
# season_frac_2    -1.9148     18.282     -0.105      0.917     -37.747      33.917
# ==============================================================================
# Omnibus:                        7.546   Durbin-Watson:                   2.007
# Prob(Omnibus):                  0.023   Jarque-Bera (JB):                7.454
# Skew:                           0.309   Prob(JB):                       0.0241
# Kurtosis:                       3.330   Cond. No.                     4.19e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are robust tocluster correlation (cluster)
# [2] The condition number is large, 4.19e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# QB
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          pts_next_year   R-squared:                       0.689
# Model:                            OLS   Adj. R-squared:                  0.678
# Method:                 Least Squares   F-statistic:                     117.2
# Date:                Wed, 31 Jul 2019   Prob (F-statistic):           9.92e-32
# Time:                        18:21:54   Log-Likelihood:                -820.42
# No. Observations:                 146   AIC:                             1653.
# Df Residuals:                     140   BIC:                             1671.
# Df Model:                           5
# Covariance Type:              cluster
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept        14.2671     11.410      1.250      0.211      -8.095      36.629
# PaTD              3.5294      1.766      1.998      0.046       0.067       6.992
# PaYds             0.0291      0.013      2.271      0.023       0.004       0.054
# Age               5.3872     19.191      0.281      0.779     -32.226      43.000
# agesq            -0.0947      0.316     -0.299      0.765      -0.715       0.525
# season_frac_2    26.8490     30.037      0.894      0.371     -32.022      85.720
# ==============================================================================
# Omnibus:                        3.021   Durbin-Watson:                   2.268
# Prob(Omnibus):                  0.221   Jarque-Bera (JB):                3.177
# Skew:                           0.058   Prob(JB):                        0.204
# Kurtosis:                       3.713   Cond. No.                     1.78e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are robust tocluster correlation (cluster)
# [2] The condition number is large, 1.78e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# RB
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          pts_next_year   R-squared:                       0.421
# Model:                            OLS   Adj. R-squared:                  0.403
# Method:                 Least Squares   F-statistic:                     16.67
# Date:                Wed, 31 Jul 2019   Prob (F-statistic):           1.98e-17
# Time:                        18:21:54   Log-Likelihood:                -1520.9
# No. Observations:                 274   AIC:                             3060.
# Df Residuals:                     265   BIC:                             3092.
# Df Model:                           8
# Covariance Type:              cluster
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept        27.3594      5.830      4.693      0.000      15.934      38.785
# RuTD             -0.8690      2.511     -0.346      0.729      -5.791       4.053
# RuYds             0.0953      0.022      4.276      0.000       0.052       0.139
# ReTD              4.3244      4.035      1.072      0.284      -3.583      12.232
# ReYds            -0.1295      0.117     -1.106      0.269      -0.359       0.100
# Rec               2.1421      1.025      2.091      0.037       0.134       4.150
# Age             -66.4055     26.379     -2.517      0.012    -118.108     -14.703
# agesq             1.1225      0.470      2.387      0.017       0.201       2.044
# season_frac_2    -9.6991     15.507     -0.625      0.532     -40.093      20.694
# ==============================================================================
# Omnibus:                       18.664   Durbin-Watson:                   2.019
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               23.591
# Skew:                           0.525   Prob(JB):                     7.54e-06
# Kurtosis:                       3.982   Cond. No.                     3.80e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are robust tocluster correlation (cluster)
# [2] The condition number is large, 3.8e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# Out:
# ['Rk',
#  'Name',
#  'Tm',
#  'FantPos',
#  'Age',
#  'G',
#  'GS',
#  'Cmp',
#  'PaAtt',
#  'PaYds',
#  'PaTD',
#  'Int',
#  'RuAtt',
#  'RuYds',
#  'RuY/A',
#  'RuTD',
#  'Tgt',
#  'Rec',
#  'ReYds',
#  'ReYds/R',
#  'ReTD',
#  'Fmb',
#  'FL',
#  'TD.3',
#  '2PM',
#  '2PP',
#  'FantPt',
#  'PPR',
#  'DKPt',
#  'FDPt',
#  'VBD',
#  'PosRank',
#  'OvRank',
#  'Year']
