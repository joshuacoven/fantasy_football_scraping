# %%
###################### Import Packages #############################################
import requests
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
import statsmodels.formula.api as smf

####################################### Functions ######################################
#Pull data from Pro Football Reference
def data_assembly(start_year, current_year):
    database = []
    #start_year = 2014 #Input Earliest Year of Data
    #current_year = 2019 #Input Current Year
    for x in range(start_year, current_year):
        page = requests.get("https://www.pro-football-reference.com/years/%d/fantasy.htm" % x)
        soup = BeautifulSoup(page.content, 'html.parser')
        table = soup.find_all('table')[0]
        df = pd.read_html(str(table), header = 1)
        dfyear = df[0]
        dfyear['Year'] = x
        if x == start_year:
            database = dfyear
        else: database = database.append(dfyear, ignore_index = True)

    #Rename columns, eliminate duplicate column titles as rows
    database = database.rename(columns = {'Player':'Name', 'Att':'PaAtt', 'Yds':'PaYds', 'TD':'PaTD','Att.1':'RuAtt', 'Yds.1':'RuYds', 'TD.1':'RuTD', 'Y/A':'RuY/A', 'Y/R':'ReYds/R', 'Att.2':'ReAtt', 'Yds.2':'ReYds', 'TD.2':'ReTD'})
    database = database[database.Rk != 'Rk']

    database['Name'] = database['Name'].apply(lambda x: x[0:len(x)-1] if x[len(x)-1] == '+' else x)
    database['Name'] = database['Name'].apply(lambda x: x[0:len(x)-1] if x[len(x)-1] == '*' else x)
    return database

def shift_col(frame, new_name, col_to_shift, magnitude):
    frame1 = frame.sort_values(['Name', 'Year']).reset_index(drop = True)
    frame1[new_name] = frame1[col_to_shift].shift(magnitude)
    for i in range(len(frame1) - 1):
        if frame1.loc[i, 'Name'] != frame1.loc[i+1, 'Name']:
            if magnitude == -1:
                frame1.loc[i, new_name] = np.nan
            elif magnitude == 1:
                frame1.loc[i+1, new_name] = np.nan
    return frame1

# %%
############## Assemble the database #########################################
database = data_assembly(2012, 2019)                         # pull based on years
shifted = shift_col(database, 'pts_next_year', 'PPR', -1)    # create pts_next_year column for regressions
shifted = shift_col(shifted, 'G_prev_year', 'G', 1)          # create games prev year for injury history

# change columns to floats
cols_to_change = ['VBD',
                  'Age',
                  'PPR',
                  'pts_next_year',
                  'G_prev_year',
                  'GS',
                  'G',
                  'PaTD',
                  'RuTD',
                  'ReTD',
                  'PaYds',
                  'RuYds',
                  'ReYds',
                 'Rec', 
                 'RuY/A',
                  'ReYds/R']
for col in cols_to_change:
    shifted[col] = shifted[col].astype(float)
    
# create new metrics
shifted['season_frac_1'] = shifted['G'] / 16                                # 1 year injury history
shifted['season_frac_2'] = (shifted['G'] + shifted['G_prev_year']) / 32     # 2 year injury history
shifted['agesq'] = shifted['Age'] * shifted['Age']                          # Age squared
shifted['ReYds_per_R'] = shifted['ReYds/R']
shifted['RuYds_per_A'] = shifted['RuY/A']

for metric in ['PaTD', 'RuTD', 'ReTD', 'PaYds', 'RuYds', 'ReYds', 'Rec']:
    new_str = metric + '_pergame'
    shifted[new_str] = shifted[metric] / shifted['G']

# %%
shifted
# Out:
#        Rk               Name   Tm FantPos   Age     G    GS  Cmp PaAtt  \
# 0     357         A.J. Derby  2TM      TE  25.0  10.0   3.0    0     0
# 1     271         A.J. Derby  2TM      TE  26.0  11.0   1.0    0     0
# 2     388         A.J. Derby  MIA      TE  27.0   4.0   0.0    0     0
# 3      13         A.J. Green  CIN      WR  24.0  16.0  16.0    0     0
# 4      12         A.J. Green  CIN      WR  25.0  16.0  16.0    0     0
# 5      59         A.J. Green  CIN      WR  26.0  13.0  13.0    0     0
# 6      17         A.J. Green  CIN      WR  27.0  16.0  16.0    0     0
# 7     101         A.J. Green  CIN      WR  28.0  10.0  10.0    0     0
# 8      27         A.J. Green  CIN      WR  29.0  16.0  16.0    0     0
# 9     118         A.J. Green  CIN      WR  30.0   9.0   9.0    0     0
# 10    598       A.J. Jenkins  SFO     NaN  23.0   3.0   0.0    0     0
# 11    341       A.J. Jenkins  KAN      WR  24.0  16.0   1.0    0     0
# 12    403       A.J. Jenkins  KAN      WR  25.0   9.0   2.0    0     0
# 13    620      A.J. McCarron  CIN     NaN  24.0   0.0   NaN    0     0
# 14    218      A.J. McCarron  CIN      QB  25.0   7.0   3.0   79   119
# 15    555      A.J. McCarron  CIN     NaN  26.0   1.0   0.0    0     0
# 16    476      A.J. McCarron  CIN      QB  27.0   3.0   0.0    7    14
# 17    583      A.J. McCarron  OAK      QB  28.0   2.0   0.0    1     3
# 18    422    Aaron Burbridge  SFO      WR  23.0  16.0   3.0    0     0
# 19    168       Aaron Dobson  NWE      WR  22.0  12.0   9.0    0     0
# 20    452       Aaron Dobson  NWE      WR  23.0   4.0   1.0    0     0
# 21    372       Aaron Dobson  NWE      WR  24.0   8.0   3.0    0     0
# 22    155    Aaron Hernandez  NWE      TE  23.0  10.0  10.0    0     0
# 23    164        Aaron Jones  GNB      RB  23.0  12.0   4.0    0     0
# 24     62        Aaron Jones  GNB      RB  24.0  12.0   8.0    0     0
# 25    637       Aaron Murray  KAN     NaN  24.0   0.0   NaN    0     0
# 26    493    Aaron Ripkowski  GNB      RB  23.0  15.0   0.0    0     0
# 27    248    Aaron Ripkowski  GNB      RB  24.0  16.0   8.0    0     0
# 28    450    Aaron Ripkowski  GNB      RB  25.0  16.0   2.0    0     0
# 29      9      Aaron Rodgers  GNB      QB  29.0  16.0  16.0  371   552
# ...   ...                ...  ...     ...   ...   ...   ...  ...   ...
# 4339   49          Zach Ertz  PHI      TE  26.0  14.0  12.0    0     0
# 4340   21          Zach Ertz  PHI      TE  27.0  14.0  13.0    0     0
# 4341   17          Zach Ertz  PHI      TE  28.0  16.0  16.0    0     0
# 4342  493          Zach Line  MIN      RB  23.0   3.0   1.0    0     0
# 4343  615          Zach Line  MIN     NaN  24.0   1.0   0.0    0     0
# 4344  285          Zach Line  MIN      RB  25.0  16.0   5.0    0     0
# 4345  482          Zach Line  MIN      RB  26.0  15.0   4.0    0     0
# 4346  386          Zach Line  NOR      RB  27.0  12.0   4.0    0     0
# 4347  346          Zach Line  NOR      RB  28.0  16.0   6.0    0     0
# 4348  168  Zach Mettenberger  TEN      QB  23.0   7.0   6.0  107   179
# 4349  244  Zach Mettenberger  TEN      QB  24.0   7.0   4.0  101   166
# 4350  197        Zach Miller  SEA      TE  27.0  16.0  15.0    0     0
# 4351  179        Zach Miller  SEA      TE  28.0  14.0  12.0    0     0
# 4352  413        Zach Miller  SEA      TE  29.0   3.0   3.0    0     0
# 4353  626        Zach Miller  CHI     NaN  30.0   0.0   NaN    0     0
# 4354  169        Zach Miller  CHI      TE  31.0  15.0  14.0    0     0
# 4355  172        Zach Miller  CHI      TE  32.0  10.0   8.0    0     0
# 4356  267        Zach Miller  CHI      TE  33.0   8.0   6.0    0     0
# 4357  253        Zach Pascal  IND      WR  24.0  16.0   4.0    0     0
# 4358  504        Zach Potter  JAX      TE  26.0  16.0   5.0    0     0
# 4359  420       Zach Sudfeld  2TM      TE  24.0  14.0   2.0    0     0
# 4360  406       Zach Sudfeld  NYJ      TE  25.0  16.0   3.0    0     0
# 4361  440        Zach Zenner  DET      RB  24.0   6.0   1.0    0     0
# 4362  167        Zach Zenner  DET      RB  25.0  14.0   4.0    0     0
# 4363  406        Zach Zenner  DET      RB  26.0   8.0   0.0    0     0
# 4364  222        Zach Zenner  DET      RB  27.0   8.0   1.0    0     0
# 4365  230          Zay Jones  BUF      WR  22.0  15.0  10.0    0     0
# 4366  113          Zay Jones  BUF      WR  23.0  16.0  15.0    0     1
# 4367  354      Zurlon Tipton  IND      RB  24.0   6.0   0.0    0     0
# 4368  436      Zurlon Tipton  IND      RB  25.0  10.0   0.0    0     0
#
#        PaYds  ...  season_frac_1 season_frac_2   agesq  PaTD_pergame  \
# 0        0.0  ...         0.6250           NaN   625.0      0.000000
# 1        0.0  ...         0.6875       0.65625   676.0      0.000000
# 2        0.0  ...         0.2500       0.46875   729.0      0.000000
# 3        0.0  ...         1.0000           NaN   576.0      0.000000
# 4        0.0  ...         1.0000       1.00000   625.0      0.000000
# 5        0.0  ...         0.8125       0.90625   676.0      0.000000
# 6        0.0  ...         1.0000       0.90625   729.0      0.000000
# 7        0.0  ...         0.6250       0.81250   784.0      0.000000
# 8        0.0  ...         1.0000       0.81250   841.0      0.000000
# 9        0.0  ...         0.5625       0.78125   900.0      0.000000
# 10       0.0  ...         0.1875           NaN   529.0      0.000000
# 11       0.0  ...         1.0000       0.59375   576.0      0.000000
# 12       0.0  ...         0.5625       0.78125   625.0      0.000000
# 13       0.0  ...         0.0000           NaN   576.0           NaN
# 14     854.0  ...         0.4375       0.21875   625.0      0.857143
# 15       0.0  ...         0.0625       0.25000   676.0      0.000000
# 16      66.0  ...         0.1875       0.12500   729.0      0.000000
# 17       8.0  ...         0.1250       0.15625   784.0      0.000000
# 18       0.0  ...         1.0000           NaN   529.0      0.000000
# 19       0.0  ...         0.7500           NaN   484.0      0.000000
# 20       0.0  ...         0.2500       0.50000   529.0      0.000000
# 21       0.0  ...         0.5000       0.37500   576.0      0.000000
# 22       0.0  ...         0.6250           NaN   529.0      0.000000
# 23       0.0  ...         0.7500           NaN   529.0      0.000000
# 24       0.0  ...         0.7500       0.75000   576.0      0.000000
# 25       0.0  ...         0.0000           NaN   576.0           NaN
# 26       0.0  ...         0.9375           NaN   529.0      0.000000
# 27       0.0  ...         1.0000       0.96875   576.0      0.000000
# 28       0.0  ...         1.0000       1.00000   625.0      0.000000
# 29    4295.0  ...         1.0000           NaN   841.0      2.437500
# ...      ...  ...            ...           ...     ...           ...
# 4339     0.0  ...         0.8750       0.90625   676.0      0.000000
# 4361    0.333333
# 4362    1.285714
# 4363    0.000000
# 4364    0.875000
# 4365    1.800000
# 4366    3.500000
# 4367    1.000000
# 4368    0.500000
#
# [4369 rows x 46 columns]

# %%
################ Seperate database by position ####################################################
pos_dict = {}
for pos in shifted.FantPos.unique():
    pos_dict[pos] = shifted.loc[shifted.FantPos == pos].reset_index(drop = True)
    #pos_dict[pos]['season_frac_1'] = pos_dict[pos]['season_frac_1'] - pos_dict[pos]['season_frac_1'].mean()
    #pos_dict[pos]['season_frac_2'] = pos_dict[pos]['season_frac_2'] - pos_dict[pos]['season_frac_2'].mean()
    #pos_dict[pos]['Age'] = pos_dict[pos]['Age'] - pos_dict[pos]['Age'].mean()
    #pos_dict[pos]['agesq'] = pos_dict[pos]['agesq'] - pos_dict[pos]['agesq'].mean()
pos_dict['RB']
# Out:
#        Rk               Name   Tm FantPos   Age     G    GS Cmp PaAtt  PaYds  \
# 0     164        Aaron Jones  GNB      RB  23.0  12.0   4.0   0     0    0.0
# 1      62        Aaron Jones  GNB      RB  24.0  12.0   8.0   0     0    0.0
# 2     493    Aaron Ripkowski  GNB      RB  23.0  15.0   0.0   0     0    0.0
# 3     248    Aaron Ripkowski  GNB      RB  24.0  16.0   8.0   0     0    0.0
# 4     450    Aaron Ripkowski  GNB      RB  25.0  16.0   2.0   0     0    0.0
# 5       1    Adrian Peterson  MIN      RB  27.0  16.0  16.0   0     0    0.0
# 6      17    Adrian Peterson  MIN      RB  28.0  14.0  14.0   0     0    0.0
# 7     405    Adrian Peterson  MIN      RB  29.0   1.0   1.0   0     0    0.0
# 8       4    Adrian Peterson  MIN      RB  30.0  16.0  16.0   0     0    0.0
# 9     438    Adrian Peterson  MIN      RB  31.0   3.0   3.0   0     0    0.0
# 10    171    Adrian Peterson  2TM      RB  32.0  10.0   7.0   0     0    0.0
# 11     42    Adrian Peterson  WAS      RB  33.0  16.0  16.0   0     0    0.0
# 12     50     Ahmad Bradshaw  NYG      RB  26.0  14.0  12.0   0     0    0.0
# 13    269     Ahmad Bradshaw  IND      RB  27.0   3.0   2.0   0     0    0.0
# 14    102     Ahmad Bradshaw  IND      RB  28.0  10.0   1.0   0     0    0.0
# 15    272     Ahmad Bradshaw  IND      RB  29.0   6.0   0.0   0     0    0.0
# 16    374         Akeem Hunt  HOU      RB  22.0   7.0   1.0   0     0    0.0
# 17    359         Akeem Hunt  HOU      RB  23.0   8.0   0.0   0     0    0.0
# 18    445         Akeem Hunt  KAN      RB  24.0  15.0   0.0   0     0    0.0
# 19    369         Alex Armah  CAR      RB  24.0  16.0   2.0   0     0    0.0
# 20    294       Alex Collins  SEA      RB  22.0  11.0   0.0   0     0    0.0
# 21     48       Alex Collins  BAL      RB  23.0  15.0  12.0   0     0    0.0
# 22    133       Alex Collins  BAL      RB  24.0  10.0  10.0   0     0    0.0
# 23    196         Alex Green  GNB      RB  24.0  12.0   4.0   0     0    0.0
# 24    439         Alex Green  NYJ      RB  25.0  13.0   0.0   0     0    0.0
# 25    433         Alex Smith  CLE      RB  30.0  12.0   2.0   0     0    0.0
# 26    479      Alfonso Smith  ARI      RB  25.0  11.0   0.0   0     0    0.0
# 27    336      Alfonso Smith  ARI      RB  26.0  16.0   0.0   0     0    0.0
# 28    469      Alfonso Smith  SFO      RB  27.0   6.0   0.0   0     0    0.0
# 29    150        Alfred Blue  HOU      RB  23.0  16.0   3.0   0     0    0.0
# ...   ...                ...  ...     ...   ...   ...   ...  ..   ...    ...
# 1114  246  Wendell Smallwood  PHI      RB  22.0  13.0   3.0   0     0    0.0
# 1115  275  Wendell Smallwood  PHI      RB  23.0   8.0   3.0   0     0    0.0
# 1116  141  Wendell Smallwood  PHI      RB  24.0  16.0   6.0   0     0    0.0
# 1117  321       Will Johnson  PIT      RB  23.0  16.0   7.0   0     0    0.0
# 1118  372       Will Johnson  PIT      RB  24.0  15.0   5.0   0     0    0.0
# 1119  456       Will Johnson  PIT      RB  25.0  16.0   5.0   0     0    0.0
# 1120  417       Will Johnson  PIT      RB  26.0  16.0   4.0   0     0    0.0
# 1121  512     Will Ta'ufo'ou  JAX      RB  26.0   6.0   1.0   0     0    0.0
# 1122  445     Will Ta'ufo'ou  JAX      RB  27.0  16.0   7.0   0     0    0.0
# 1123  415     Will Ta'ufo'ou  JAX      RB  28.0  16.0   4.0   0     0    0.0
# 1124  508       Will Tukuafu  SEA      RB  30.0   9.0   2.0   0     0    0.0
# 1125  409       Will Tukuafu  SEA      RB  31.0  14.0   1.0   0     0    0.0
# 1126  570       Will Tukuafu  SEA      RB  32.0   7.0   1.0   0     0    0.0
# 1127  255     William Powell  ARI      RB  24.0  13.0   1.0   0     0    0.0
# 1128  105     Willis McGahee  DEN      RB  31.0  10.0   9.0   0     0    0.0
# 1129  232     Willis McGahee  CLE      RB  32.0  12.0   6.0   0     0    0.0
# 1130   44          Zac Stacy  STL      RB  22.0  14.0  12.0   0     0    0.0
# 1131  238          Zac Stacy  STL      RB  23.0  13.0   5.0   0     0    0.0
# 1132  334          Zac Stacy  NYJ      RB  24.0   8.0   0.0   0     0    0.0
# 1133  493          Zach Line  MIN      RB  23.0   3.0   1.0   0     0    0.0
# 1134  285          Zach Line  MIN      RB  25.0  16.0   5.0   0     0    0.0
# 1135  482          Zach Line  MIN      RB  26.0  15.0   4.0   0     0    0.0
# 1136  386          Zach Line  NOR      RB  27.0  12.0   4.0   0     0    0.0
# 1137  346          Zach Line  NOR      RB  28.0  16.0   6.0   0     0    0.0
# 1138  440        Zach Zenner  DET      RB  24.0   6.0   1.0   0     0    0.0
# 1139  167        Zach Zenner  DET      RB  25.0  14.0   4.0   0     0    0.0
# 1140  406        Zach Zenner  DET      RB  26.0   8.0   0.0   0     0    0.0
# 1141  222        Zach Zenner  DET      RB  27.0   8.0   1.0   0     0    0.0
# 1142  354      Zurlon Tipton  IND      RB  24.0   6.0   0.0   0     0    0.0
# 1143  436      Zurlon Tipton  IND      RB  25.0  10.0   0.0   0     0    0.0
#
#       ...   agesq ReYds_per_R RuYds_per_A  PaTD_pergame  RuTD_pergame  \
# 0     ...   529.0        2.44        5.53           0.0      0.333333
# 1     ...   576.0        7.92        5.47           0.0      0.666667
# 2     ...   529.0       18.00         NaN           0.0      0.000000
# 3     ...   576.0        5.11        4.41           0.0      0.125000
# 4     ...   625.0        5.57        2.60           0.0      0.000000
# 5     ...   729.0        5.43        6.03           0.0      0.750000
# 6     ...   784.0        5.90        4.54           0.0      0.714286
# 7     ...   841.0        9.00        3.57           0.0      0.000000
# 8     ...   900.0        7.40        4.54           0.0      0.687500
# 9     ...   961.0        2.67        1.95           0.0      0.000000
# 10    ...  1024.0        6.36        3.39           0.0      0.200000
# 11    ...  1089.0       10.40        4.15           0.0      0.437500
# 12    ...   676.0       10.65        4.59           0.0      0.428571
# 13    ...   729.0        6.00        4.54           0.0      0.666667
# 14    ...   784.0        7.89        4.72           0.0      0.200000
# 15    ...   841.0        6.40        2.74           0.0      0.000000
# 16    ...   484.0        6.50        5.65           0.0      0.000000
# 17    ...   529.0        9.67        5.45           0.0      0.000000
# 18    ...   576.0        7.75        2.88           0.0      0.000000
# 19    ...   576.0        5.00        1.67           0.0      0.125000
# 20    ...   484.0        7.64        4.03           0.0      0.090909
# 21    ...   529.0        8.13        4.59           0.0      0.400000
# 22    ...   576.0        7.00        3.61           0.0      0.700000
# 23    ...   576.0        6.94        3.44           0.0      0.000000
# 24    ...   625.0        4.00        3.18           0.0      0.000000
# 25    ...   900.0        3.62         NaN           0.0      0.000000
# 26    ...   625.0       10.50         NaN           0.0      0.000000
# 27    ...   676.0        6.80        3.00           0.0      0.062500
# 28    ...   729.0        3.67        2.71           0.0      0.000000
# 29    ...   529.0        7.53        3.12           0.0      0.125000
# ...   ...     ...         ...         ...           ...           ...
# 1114  ...   484.0        9.17        4.05           0.0      0.076923
# 1115  ...   529.0        7.92        3.70           0.0      0.125000
# 1116  ...   576.0        8.21        4.18           0.0      0.187500
# 1117  ...   529.0        9.13        3.50           0.0      0.000000
# 1118  ...   576.0        5.13         NaN           0.0      0.000000
# 1119  ...   625.0        6.83        0.00           0.0      0.000000
# 1120  ...   676.0        8.00        1.75           0.0      0.062500
# 1121  ...   676.0        5.00         NaN           0.0      0.000000
# 1122  ...   729.0        4.00        1.00           0.0      0.000000
# 1123  ...   784.0       11.57         NaN           0.0      0.000000
# 1124  ...   900.0        4.00        2.00           0.0      0.000000
# 1125  ...   961.0        7.00        0.25           0.0      0.071429
# 1126  ...  1024.0         NaN        1.00           0.0      0.000000
# 1127  ...   576.0        6.95        3.62           0.0      0.000000
# 1128  ...   961.0        8.50        4.38           0.0      0.400000
# 1129  ...  1024.0        2.50        2.73           0.0      0.166667
# 1130  ...   484.0        5.42        3.89           0.0      0.500000
# 1131  ...   529.0        8.44        3.86           0.0      0.076923
# 1132  ...   576.0        7.22        2.87           0.0      0.125000
# 1133  ...   529.0        8.00         NaN           0.0      0.000000
# 1134  ...   625.0       15.83        1.67           0.0      0.125000
# 1135  ...   676.0         NaN        2.14           0.0      0.000000
# 1136  ...   729.0        4.00        4.00           0.0      0.000000
# 1137  ...   784.0        2.80        4.56           0.0      0.000000
# 1138  ...   576.0        5.50        3.53           0.0      0.000000
# 1139  ...   625.0       10.89        3.80           0.0      0.285714
# 1140  ...   676.0         NaN        1.86           0.0      0.125000
# 1141  ...   729.0        8.00        4.82           0.0      0.375000
# 1136      0.083333           0.0       2.333333       0.666667     0.166667
# 1137      0.125000           0.0       2.562500       0.875000     0.312500
# 1138      0.000000           0.0      10.000000       1.833333     0.333333
# 1139      0.000000           0.0      23.857143      14.000000     1.285714
# 1140      0.000000           0.0       3.250000       0.000000     0.000000
# 1141      0.000000           0.0      33.125000       7.000000     0.875000
# 1142      0.166667           0.0       3.000000      11.333333     1.000000
# 1143      0.000000           0.0       2.000000       5.700000     0.500000
#
# [1144 rows x 48 columns]

# %%
## to help with multicolinearity, can make ryds, tds, rec all per game metrics

all_cols = ['Age', 'agesq', 'season_frac_2']
xcols_dict = {
    'TE': ['ReTD_pergame','ReYds_pergame', 'Rec_pergame', 'ReYds_per_R'],
    'WR': ['ReTD_pergame','ReYds_pergame', 'Rec_pergame', 'ReYds_per_R'],
    'QB': ['PaTD_pergame','PaYds_pergame', 'RuTD_pergame','RuYds_pergame', 'RuYds_per_A'],
    'RB': ['RuTD_pergame','RuYds_pergame', 'ReTD_pergame','ReYds_pergame', 'Rec_pergame', 'RuYds_per_A', 'ReYds_per_R'],
}

for pos in xcols_dict:
    print(pos)
    ycol = 'pts_next_year'
    xcols = xcols_dict[pos] + all_cols
    frame1 = pos_dict[pos]
    frame = frame1[['Name', ycol] + xcols].dropna()
    xform = ' + '.join(xcols)
    formula = ycol + " ~ " + xform
    model = smf.ols(formula, frame)
    results = model.fit(cov_type='cluster', cov_kwds={'groups': frame['Name']})
    print(results.summary())
# Out:
# TE
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          pts_next_year   R-squared:                       0.408
# Model:                            OLS   Adj. R-squared:                  0.395
# Method:                 Least Squares   F-statistic:                     37.15
# Date:                Thu, 01 Aug 2019   Prob (F-statistic):           4.07e-27
# Time:                        16:47:41   Log-Likelihood:                -1659.3
# No. Observations:                 308   AIC:                             3335.
# Df Residuals:                     300   BIC:                             3365.
# Df Model:                           7
# Covariance Type:              cluster
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept       189.6617    185.043      1.025      0.305    -173.016     552.340
# ReTD_pergame    -25.5643     25.329     -1.009      0.313     -75.209      24.081
# ReYds_pergame     3.2744      0.828      3.955      0.000       1.652       4.897
# Rec_pergame      -9.0341      9.978     -0.905      0.365     -28.590      10.522
# ReYds_per_R      -3.3002      1.736     -1.901      0.057      -6.703       0.103
# Age             -10.4834     13.627     -0.769      0.442     -37.192      16.225
# agesq             0.1951      0.237      0.825      0.409      -0.269       0.659
# season_frac_2     6.1705     11.878      0.519      0.603     -17.110      29.451
# ==============================================================================
# Omnibus:                      132.877   Durbin-Watson:                   1.968
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              889.217
# Skew:                           1.631   Prob(JB):                    8.11e-194
# Kurtosis:                      10.658   Cond. No.                     5.62e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are robust tocluster correlation (cluster)
# [2] The condition number is large, 5.62e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# WR
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          pts_next_year   R-squared:                       0.489
# Model:                            OLS   Adj. R-squared:                  0.483
# Method:                 Least Squares   F-statistic:                     54.75
# Date:                Thu, 01 Aug 2019   Prob (F-statistic):           3.47e-47
# Time:                        16:47:41   Log-Likelihood:                -3313.5
# No. Observations:                 598   AIC:                             6643.
# Df Residuals:                     590   BIC:                             6678.
# Df Model:                           7
# Covariance Type:              cluster
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept        11.4862    196.354      0.058      0.953    -373.360     396.332
# ReTD_pergame     36.5615     19.949      1.833      0.067      -2.538      75.661
# ReYds_pergame     1.1111      0.559      1.989      0.047       0.016       2.206
# Rec_pergame      12.9779      6.529      1.988      0.047       0.181      25.775
# ReYds_per_R       0.2603      0.951      0.274      0.784      -1.604       2.124
# Age               0.2644     14.300      0.018      0.985     -27.762      28.291
# agesq            -0.0525      0.259     -0.203      0.839      -0.559       0.454
# season_frac_2    37.2616     13.367      2.788      0.005      11.062      63.461
# ==============================================================================
# Omnibus:                        7.741   Durbin-Watson:                   2.094
# Prob(Omnibus):                  0.021   Jarque-Bera (JB):                7.963
# Skew:                           0.225   Prob(JB):                       0.0187
# Kurtosis:                       3.343   Cond. No.                     5.66e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are robust tocluster correlation (cluster)
# [2] The condition number is large, 5.66e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# QB
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          pts_next_year   R-squared:                       0.549
# Model:                            OLS   Adj. R-squared:                  0.533
# Method:                 Least Squares   F-statistic:                     49.48
# Date:                Thu, 01 Aug 2019   Prob (F-statistic):           1.88e-27
# Time:                        16:47:41   Log-Likelihood:                -1359.8
# No. Observations:                 234   AIC:                             2738.
# Df Residuals:                     225   BIC:                             2769.
# Df Model:                           8
# Covariance Type:              cluster
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept        -2.1748    296.886     -0.007      0.994    -584.062     579.712
# PaTD_pergame     66.7104     18.743      3.559      0.000      29.974     103.447
# PaYds_pergame     0.0623      0.141      0.442      0.659      -0.214       0.339
# RuTD_pergame     60.2934     80.276      0.751      0.453     -97.045     217.632
# RuYds_pergame     0.9370      1.266      0.740      0.459      -1.544       3.418
# RuYds_per_A      -8.2997      4.079     -2.035      0.042     -16.294      -0.306
# Age              -1.3678     19.755     -0.069      0.945     -40.087      37.351
# agesq             0.0103      0.328      0.031      0.975      -0.633       0.654
# season_frac_2   141.9183     29.421      4.824      0.000      84.255     199.582
# ==============================================================================
# Omnibus:                        0.679   Durbin-Watson:                   1.996
# Prob(Omnibus):                  0.712   Jarque-Bera (JB):                0.525
# Skew:                           0.113   Prob(JB):                        0.769
# Kurtosis:                       3.053   Cond. No.                     4.90e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are robust tocluster correlation (cluster)
# [2] The condition number is large, 4.9e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# RB
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          pts_next_year   R-squared:                       0.384
# Model:                            OLS   Adj. R-squared:                  0.368
# Method:                 Least Squares   F-statistic:                     22.51
# Date:                Thu, 01 Aug 2019   Prob (F-statistic):           4.19e-27
# Time:                        16:47:41   Log-Likelihood:                -2318.7
# No. Observations:                 416   AIC:                             4659.
# Df Residuals:                     405   BIC:                             4704.
# Df Model:                          10
# Covariance Type:              cluster
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept       613.6566    289.007      2.123      0.034      47.214    1180.100
# RuTD_pergame      1.0904     28.735      0.038      0.970     -55.229      57.410
# RuYds_pergame     1.3491      0.231      5.832      0.000       0.896       1.802
# ReTD_pergame    -30.1698     43.355     -0.696      0.487    -115.145      54.805
# ReYds_pergame    -1.5741      1.070     -1.471      0.141      -3.671       0.523
# Rec_pergame      29.8466     10.002      2.984      0.003      10.243      49.451
# RuYds_per_A       0.9460      0.991      0.955      0.340      -0.996       2.888
# ReYds_per_R       0.5783      0.635      0.911      0.362      -0.666       1.822
# Age             -43.6130     21.008     -2.076      0.038     -84.787      -2.439
# agesq             0.7313      0.377      1.940      0.052      -0.007       1.470
# season_frac_2    36.2472     15.676      2.312      0.021       5.523      66.972
# ==============================================================================
# Omnibus:                       21.015   Durbin-Watson:                   2.085
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               23.250
# Skew:                           0.517   Prob(JB):                     8.94e-06
# Kurtosis:                       3.523   Cond. No.                     6.54e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are robust tocluster correlation (cluster)
# [2] The condition number is large, 6.54e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# Out:
# ['Rk',
#  'Name',
#  'Tm',
#  'FantPos',
#  'Age',
#  'G',
#  'GS',
#  'Cmp',
#  'PaAtt',
#  'PaYds',
#  'PaTD',
#  'Int',
#  'RuAtt',
#  'RuYds',
#  'RuY/A',
#  'RuTD',
#  'Tgt',
#  'Rec',
#  'ReYds',
#  'ReYds/R',
#  'ReTD',
#  'Fmb',
#  'FL',
#  'TD.3',
#  '2PM',
#  '2PP',
#  'FantPt',
#  'PPR',
#  'DKPt',
#  'FDPt',
#  'VBD',
#  'PosRank',
#  'OvRank',
#  'Year']
