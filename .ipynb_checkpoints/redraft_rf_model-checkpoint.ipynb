# %% [markdown]
# # To do

# %% [markdown]
# * Clean up output
# * Make functions for a lot of this

# %% [markdown]
# # Import packages and define functions

# %%
###################### Import Packages #############################################
import requests
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
import copy
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from ffb_functions import *
pd.options.display.max_rows = 999
pd.set_option('display.max_columns', 500)

####################################### Functions ######################################
shifted = pd.read_csv('final_frame_teams.csv')
shifted = shifted.replace('NULL', np.nan)

################ Seperate database by position ####################################################
pos_dict = {}
for pos in ['TE', 'WR', 'RB', 'QB']:
    pos_dict[pos] = shifted.loc[shifted.FantPos == pos].reset_index(drop = True)
    
    # center age to prepare for power relationship to reduce multicollinearity
    pos_dict[pos]['Age'] = pos_dict[pos]['Age'] - np.mean(pos_dict[pos]['Age']) 
    pos_dict[pos]['agesq'] = pos_dict[pos]['Age'] * pos_dict[pos]['Age']
    pos_dict[pos] = pos_dict[pos].drop(['Rk', 'FantPos', 'College', 'Old_Team',
                    '2PP', 'delta_ppg', 'ppg_next_year', 'g_next_year'], axis = 1)
    if pos != 'QB':
        pos_dict[pos] = pos_dict[pos].drop(['PaAtt', 'PaTD', 'PaYds', 'PaYds_per_PaAtt', 'PaAtt_per_game'
                                          , 'PaTD_per_PaAtt', 'Cmp_per_PaAtt', 'Int_per_PaAtt'
                                           , 'Cmp', 'Int'], axis = 1)
    else:
        pos_dict[pos] = pos_dict[pos].drop(['Rec_per_tgt', 'ReTD_per_rec', 'ReYds_per_R'
                                           ,'Tgt_per_game', 'Tgt', 'Rec', 'ReYds', 'ReTD', 'ReYds/R'], axis = 1)

# %%
pos_dict['RB'].loc[pos_dict['RB'].Name.str.contains('Bell')]
# Out:
#              Name       Age     G    GS  RuAtt   RuYds  RuY/A  RuTD   Rec  \
# 318    Tatum Bell -0.508792  13.0  13.0  233.0  1025.0   4.40   2.0  24.0
# 420     Mike Bell -2.508792  15.0   3.0  157.0   677.0   4.31   8.0  20.0
# 440    Tatum Bell -2.508792  14.0   0.0   75.0   396.0   5.28   3.0   5.0
# 472    Tatum Bell  0.491208   5.0   5.0   44.0   182.0   4.14   1.0  14.0
# 647   Joique Bell  1.491208  16.0   4.0  166.0   650.0   3.92   8.0  53.0
# 649   Joique Bell  2.491208  15.0   6.0  223.0   860.0   3.86   7.0  34.0
# 665     Mike Bell  0.491208  13.0   3.0  172.0   654.0   3.80   5.0   4.0
# 693   Joique Bell  0.491208  16.0   0.0   82.0   414.0   5.05   3.0  52.0
# 720    Tatum Bell -1.508792  15.0   1.0  173.0   921.0   5.32   8.0  18.0
# 728  Le'Veon Bell -4.508792  13.0  13.0  244.0   860.0   3.52   8.0  45.0
# 745  Le'Veon Bell -2.508792   6.0   6.0  113.0   556.0   4.92   3.0  24.0
# 773  Le'Veon Bell -1.508792  12.0  12.0  261.0  1268.0   4.86   7.0  75.0
# 774  Le'Veon Bell -0.508792  15.0  15.0  321.0  1291.0   4.02   9.0  85.0
#
#      ReYds  ReYds/R  ReTD  Fmb   FL  TD.3  2PM  FantPt    PPR   DKPt   FDPt  \
# 318  115.0     4.79   0.0  5.0  0.0   2.0  0.0   126.0  150.0  156.0  138.0
# 420  158.0     7.90   0.0  1.0  0.0   8.0  0.0   132.0  151.5  157.5  141.5
# 745    7.163958  4.162326     62.5   6.294040
# 773    7.163958  4.162326     68.8   2.276455
# 774    7.163958  4.162326     81.2   0.258870

# %% [markdown]
# # Random Forest Regressions

# %%
all_cross_val = {}
for sz in [8]:
    cross_val = {}
    ## chose the year one before, ex: want to predict for 2019 season choose 2018, last year of data
    for predict_year in [#2014, 2015, 2016, 2017, 
                         2018
                        ]:
        
        #### rf model
        final_dict = rf_model(pos_dict, predict_year, sz)

        ##### plot and evaluate outputs #################################
        results_frame = pd.DataFrame()
        for pos in ['WR', 'RB', 'QB', 'TE']:
            testtest = final_dict[pos].sort_values(['prediction'], ascending = False
                )[['Names', 'PPR', 'Overall', 'prediction', 'pts_next_year']].reset_index(drop = True)
            testtest['Year'] = predict_year
            testtest['window_size'] = sz
            testtest['ADP_Pos_Rank'] = testtest['Overall'].rank()
            testtest['Predicted_Pos_Rank'] = testtest['prediction'].rank(ascending = False)
            testtest['Actual_Next_Pos_Rank'] = testtest['pts_next_year'].rank(ascending = False)
            
            results_frame.loc[len(results_frame), 'Year'] = predict_year
            results_frame.loc[len(results_frame) - 1, 'Pos'] = pos
            val = sum((testtest['ADP_Pos_Rank'] - testtest['Actual_Next_Pos_Rank'])**2)
            results_frame.loc[len(results_frame) - 1, 'ADP_As_Predictor'] = val
            val = sum((testtest['Predicted_Pos_Rank'] - testtest['Actual_Next_Pos_Rank'])**2)
            results_frame.loc[len(results_frame) - 1, 'Model_As_Predictor'] = val
            cross_val[predict_year] = results_frame
            
            print(pos)
            print('residual rank')
            plt.scatter(testtest['Actual_Next_Pos_Rank'], testtest['Actual_Next_Pos_Rank'] - testtest['Predicted_Pos_Rank'], label = 'Model')
            plt.scatter(testtest['Actual_Next_Pos_Rank'], testtest['Actual_Next_Pos_Rank'] - testtest['ADP_Pos_Rank'], label = 'ADP')
            plt.hlines(0, 0, 60, label = 'actual')
            plt.legend(loc='upper left')
            plt.title('above is the model/adp predicting they would do better than they did')
            plt.show()
            
            print('points fit')
            plt.scatter(testtest['prediction'], testtest['pts_next_year'])
            x = testtest['prediction']
            y = testtest['pts_next_year']
            plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 1))(np.unique(x)))
            plt.title('points predicted vs actual performance')
            plt.show()
            
        print(results_frame)
        
    all_cross_val[sz] = cross_val
# Out:
# TE
# Variable: Overall              Importance: 0.27
# Variable: ReYds                Importance: 0.11
# Variable: Rec_per_tgt          Importance: 0.05
# Variable: Rec                  Importance: 0.04
# Variable: ReTD_per_rec         Importance: 0.04
# Variable: PosRank              Importance: 0.03
# Variable: Tgt_per_game         Importance: 0.03
# Variable: Fant_Share           Importance: 0.03
# Variable: opp_difference       Importance: 0.03
# Variable: Pick                 Importance: 0.03
# Variable: ReYds/R              Importance: 0.02
# Variable: Tgt                  Importance: 0.02
# Variable: G_prev_year          Importance: 0.02
# Variable: ppg_this_year        Importance: 0.02
# Variable: ReYds_per_R          Importance: 0.02
# Variable: ru_opp               Importance: 0.02
# Variable: Win_PCT              Importance: 0.02
# Variable: Age                  Importance: 0.01
# Variable: G                    Importance: 0.01
# Variable: GS                   Importance: 0.01
# Variable: TD.3                 Importance: 0.01
# Variable: FantPt               Importance: 0.01
# Variable: PPR                  Importance: 0.01
# Variable: DKPt                 Importance: 0.01
# Variable: FDPt                 Importance: 0.01
# Variable: VBD                  Importance: 0.01
# Variable: G_prev_year_prev_year Importance: 0.01
# Variable: season_frac_1        Importance: 0.01
# Variable: season_frac_2        Importance: 0.01
# Variable: season_frac_3        Importance: 0.01
# Variable: start_frac           Importance: 0.01
# Variable: Std.Dev              Importance: 0.01
# Variable: agesq                Importance: 0.01
# Variable: SFO                  Importance: 0.01
# Variable: RuAtt                Importance: 0.0
# Variable: RuYds                Importance: 0.0
# Variable: RuY/A                Importance: 0.0
# Variable: RuTD                 Importance: 0.0
# Variable: ReTD                 Importance: 0.0
# Variable: Fmb                  Importance: 0.0
# Variable: FL                   Importance: 0.0
# Variable: 2PM                  Importance: 0.0
# Variable: OvRank               Importance: 0.0
# Variable: RuYds_per_A          Importance: 0.0
# Variable: RuTD_per_Att         Importance: 0.0
# Variable: RuAtt_per_game       Importance: 0.0
# Variable: Tm_change_flag       Importance: 0.0
# Variable: height               Importance: 0.0
# Variable: Wt                   Importance: 0.0
# Variable: Dash                 Importance: 0.0
# Variable: Vertical             Importance: 0.0
# Variable: Bench                Importance: 0.0
# Variable: Broad_Jump           Importance: 0.0
# Variable: Three_Cone           Importance: 0.0
# Variable: Shuttle              Importance: 0.0
# Variable: ARI                  Importance: 0.0
# Variable: ATL                  Importance: 0.0
# Variable: BAL                  Importance: 0.0
# Variable: BUF                  Importance: 0.0
# Variable: CAR                  Importance: 0.0
# Variable: CHI                  Importance: 0.0
# Variable: CIN                  Importance: 0.0
# Variable: CLE                  Importance: 0.0
# Variable: DAL                  Importance: 0.0
# Variable: DEN                  Importance: 0.0
# Variable: DET                  Importance: 0.0
# Variable: FA                   Importance: 0.0
# Variable: GNB                  Importance: 0.0
# Variable: HOU                  Importance: 0.0
# Variable: IND                  Importance: 0.0
# Variable: JAX                  Importance: 0.0
# Variable: KAN                  Importance: 0.0
# Variable: LAC                  Importance: 0.0
# Variable: LAR                  Importance: 0.0
# Variable: MIA                  Importance: 0.0
# Variable: MIN                  Importance: 0.0
# Variable: NOR                  Importance: 0.0
# Variable: NWE                  Importance: 0.0
# Variable: NYG                  Importance: 0.0
# Variable: NYJ                  Importance: 0.0
# Variable: OAK                  Importance: 0.0
# Variable: PHI                  Importance: 0.0
# Variable: PIT                  Importance: 0.0
# Variable: SDC                  Importance: 0.0
# Variable: SEA                  Importance: 0.0
# Variable: STL                  Importance: 0.0
# Variable: TBB                  Importance: 0.0
# Variable: TEN                  Importance: 0.0
# Variable: WAS                  Importance: 0.0
# WR
# Variable: Overall              Importance: 0.45
# Variable: Std.Dev              Importance: 0.05
# Variable: Rec_per_tgt          Importance: 0.03
# Variable: ru_opp               Importance: 0.03
# Variable: ReYds                Importance: 0.02
# Variable: ppg_this_year        Importance: 0.02
# Variable: ReTD_per_rec         Importance: 0.02
# Variable: Tgt_per_game         Importance: 0.02
# Variable: Fant_Share           Importance: 0.02
# Variable: opp_difference       Importance: 0.02
# Variable: Pick                 Importance: 0.02
# Variable: Win_PCT              Importance: 0.02
# Variable: agesq                Importance: 0.02
# Variable: CAR                  Importance: 0.02
# Variable: Age                  Importance: 0.01
# Variable: GS                   Importance: 0.01
# Variable: RuYds                Importance: 0.01
# Variable: RuY/A                Importance: 0.01
# Variable: Rec                  Importance: 0.01
# Variable: ReYds/R              Importance: 0.01
# Variable: TD.3                 Importance: 0.01
# Variable: FantPt               Importance: 0.01
# Variable: PPR                  Importance: 0.01
# Variable: DKPt                 Importance: 0.01
# Variable: FDPt                 Importance: 0.01
# Variable: VBD                  Importance: 0.01
# Variable: PosRank              Importance: 0.01
# Variable: Tgt                  Importance: 0.01
# Variable: G_prev_year          Importance: 0.01
# Variable: G_prev_year_prev_year Importance: 0.01
# Variable: season_frac_2        Importance: 0.01
# Variable: season_frac_3        Importance: 0.01
# Variable: ReYds_per_R          Importance: 0.01
# Variable: RuYds_per_A          Importance: 0.01
# Variable: start_frac           Importance: 0.01
# Variable: RuAtt_per_game       Importance: 0.01
# Variable: Tm_change_flag       Importance: 0.01
# Variable: FA                   Importance: 0.01
# Variable: SDC                  Importance: 0.01
# Variable: G                    Importance: 0.0
# Variable: RuAtt                Importance: 0.0
# Variable: RuTD                 Importance: 0.0
# Variable: ReTD                 Importance: 0.0
# Variable: Fmb                  Importance: 0.0
# Variable: FL                   Importance: 0.0
# Variable: 2PM                  Importance: 0.0
# Variable: OvRank               Importance: 0.0
# Variable: season_frac_1        Importance: 0.0
# Variable: RuTD_per_Att         Importance: 0.0
# Variable: height               Importance: 0.0
# Variable: Wt                   Importance: 0.0
# Variable: Dash                 Importance: 0.0
# Variable: Vertical             Importance: 0.0
# Variable: Bench                Importance: 0.0
# Variable: Broad_Jump           Importance: 0.0
# Variable: Three_Cone           Importance: 0.0
# Variable: Shuttle              Importance: 0.0
# Variable: ARI                  Importance: 0.0
# Variable: ATL                  Importance: 0.0
# Variable: BAL                  Importance: 0.0
# Variable: BUF                  Importance: 0.0
# Variable: CHI                  Importance: 0.0
# Variable: CIN                  Importance: 0.0
# Variable: CLE                  Importance: 0.0
# Variable: DAL                  Importance: 0.0
# Variable: DEN                  Importance: 0.0
# Variable: DET                  Importance: 0.0
# Variable: GNB                  Importance: 0.0
# Variable: HOU                  Importance: 0.0
# Variable: IND                  Importance: 0.0
# Variable: JAX                  Importance: 0.0
# Variable: KAN                  Importance: 0.0
# Variable: LAC                  Importance: 0.0
# Variable: LAR                  Importance: 0.0
# Variable: MIA                  Importance: 0.0
# Variable: MIN                  Importance: 0.0
# Variable: NOR                  Importance: 0.0
# Variable: NWE                  Importance: 0.0
# Variable: NYG                  Importance: 0.0
# Variable: NYJ                  Importance: 0.0
# Variable: OAK                  Importance: 0.0
# Variable: PHI                  Importance: 0.0
# Variable: PIT                  Importance: 0.0
# Variable: SEA                  Importance: 0.0
# Variable: SFO                  Importance: 0.0
# Variable: STL                  Importance: 0.0
# Variable: TBB                  Importance: 0.0
# Variable: TEN                  Importance: 0.0
# Variable: WAS                  Importance: 0.0
# RB
# Variable: Overall              Importance: 0.38
# Variable: RuAtt_per_game       Importance: 0.04
# Variable: RuAtt                Importance: 0.03
# Variable: ppg_this_year        Importance: 0.03
# Variable: Rec_per_tgt          Importance: 0.03
# Variable: ReYds                Importance: 0.02
# Variable: season_frac_2        Importance: 0.02
# Variable: RuTD_per_Att         Importance: 0.02
# Variable: ReTD_per_rec         Importance: 0.02
# Variable: Tgt_per_game         Importance: 0.02
# Variable: Fant_Share           Importance: 0.02
# Variable: Std.Dev              Importance: 0.02
# Variable: opp_difference       Importance: 0.02
# Variable: Pick                 Importance: 0.02
# Variable: Win_PCT              Importance: 0.02
# Variable: Age                  Importance: 0.01
# Variable: GS                   Importance: 0.01
# Variable: RuYds                Importance: 0.01
# Variable: RuY/A                Importance: 0.01
# Variable: Rec                  Importance: 0.01
# Variable: ReYds/R              Importance: 0.01
# Variable: Fmb                  Importance: 0.01
# Variable: FL                   Importance: 0.01
# Variable: TD.3                 Importance: 0.01
# Variable: FantPt               Importance: 0.01
# Variable: PPR                  Importance: 0.01
# Variable: DKPt                 Importance: 0.01
# Variable: FDPt                 Importance: 0.01
# Variable: VBD                  Importance: 0.01
# Variable: PosRank              Importance: 0.01
# Variable: Tgt                  Importance: 0.01
# Variable: G_prev_year          Importance: 0.01
# Variable: G_prev_year_prev_year Importance: 0.01
# Variable: season_frac_3        Importance: 0.01
# Variable: ReYds_per_R          Importance: 0.01
# Variable: RuYds_per_A          Importance: 0.01
# Variable: start_frac           Importance: 0.01
# Variable: ru_opp               Importance: 0.01
# Variable: agesq                Importance: 0.01
# Variable: G                    Importance: 0.0
# Variable: RuTD                 Importance: 0.0
# Variable: ReTD                 Importance: 0.0
# Variable: 2PM                  Importance: 0.0
# Variable: OvRank               Importance: 0.0
# Variable: season_frac_1        Importance: 0.0
# Variable: Tm_change_flag       Importance: 0.0
# Variable: height               Importance: 0.0
# Variable: Wt                   Importance: 0.0
# Variable: Dash                 Importance: 0.0
# Variable: Vertical             Importance: 0.0
# Variable: Bench                Importance: 0.0
# Variable: Broad_Jump           Importance: 0.0
# Variable: Three_Cone           Importance: 0.0
# Variable: Shuttle              Importance: 0.0
# Variable: ARI                  Importance: 0.0
# Variable: ATL                  Importance: 0.0
# Variable: BAL                  Importance: 0.0
# Variable: BUF                  Importance: 0.0
# Variable: CAR                  Importance: 0.0
# Variable: CHI                  Importance: 0.0
# Variable: CIN                  Importance: 0.0
# Variable: CLE                  Importance: 0.0
# Variable: DAL                  Importance: 0.0
# Variable: DEN                  Importance: 0.0
# Variable: DET                  Importance: 0.0
# Variable: FA                   Importance: 0.0
# Variable: GNB                  Importance: 0.0
# Variable: HOU                  Importance: 0.0
# Variable: IND                  Importance: 0.0
# Variable: JAX                  Importance: 0.0
# Variable: KAN                  Importance: 0.0
# Variable: LAC                  Importance: 0.0
# Variable: LAR                  Importance: 0.0
# Variable: MIA                  Importance: 0.0
# Variable: MIN                  Importance: 0.0
# Variable: NOR                  Importance: 0.0
# Variable: NWE                  Importance: 0.0
# Variable: NYG                  Importance: 0.0
# Variable: NYJ                  Importance: 0.0
# Variable: OAK                  Importance: 0.0
# Variable: PHI                  Importance: 0.0
# Variable: PIT                  Importance: 0.0
# Variable: SDC                  Importance: 0.0
# Variable: SEA                  Importance: 0.0
# Variable: SFO                  Importance: 0.0
# Variable: STL                  Importance: 0.0
# Variable: TBB                  Importance: 0.0
# Variable: TEN                  Importance: 0.0
# Variable: WAS                  Importance: 0.0
# QB
# Variable: Overall              Importance: 0.52
# Variable: PaAtt_per_game       Importance: 0.03
# Variable: PHI                  Importance: 0.03
# Variable: ppg_this_year        Importance: 0.02
# Variable: PaTD_per_PaAtt       Importance: 0.02
# Variable: Cmp_per_PaAtt        Importance: 0.02
# Variable: Int_per_PaAtt        Importance: 0.02
# Variable: Std.Dev              Importance: 0.02
# Variable: Pick                 Importance: 0.02
# Variable: Age                  Importance: 0.01
# Variable: Cmp                  Importance: 0.01
# Variable: PaYds                Importance: 0.01
# Variable: PaTD                 Importance: 0.01
# Variable: Int                  Importance: 0.01
# Variable: RuAtt                Importance: 0.01
# Variable: RuYds                Importance: 0.01
# Variable: RuY/A                Importance: 0.01
# Variable: Fmb                  Importance: 0.01
# Variable: FL                   Importance: 0.01
# Variable: PosRank              Importance: 0.01
# Variable: G_prev_year          Importance: 0.01
# Variable: G_prev_year_prev_year Importance: 0.01
# Variable: season_frac_2        Importance: 0.01
# Variable: season_frac_3        Importance: 0.01
# Variable: RuYds_per_A          Importance: 0.01
# Variable: RuTD_per_Att         Importance: 0.01
# Variable: PaYds_per_PaAtt      Importance: 0.01
# Variable: RuAtt_per_game       Importance: 0.01
# Variable: Fant_Share           Importance: 0.01
# Variable: opp_difference       Importance: 0.01
# Variable: ru_opp               Importance: 0.01
# Variable: Win_PCT              Importance: 0.01
# Variable: agesq                Importance: 0.01
# Variable: KAN                  Importance: 0.01
# Variable: G                    Importance: 0.0
# Variable: GS                   Importance: 0.0
# Variable: PaAtt                Importance: 0.0
# Variable: RuTD                 Importance: 0.0
# Variable: TD.3                 Importance: 0.0
# Variable: 2PM                  Importance: 0.0
# Variable: FantPt               Importance: 0.0
# Variable: PPR                  Importance: 0.0
# Variable: DKPt                 Importance: 0.0
# Variable: FDPt                 Importance: 0.0
# Variable: VBD                  Importance: 0.0
# Variable: OvRank               Importance: 0.0
# Variable: season_frac_1        Importance: 0.0
# Variable: start_frac           Importance: 0.0
# Variable: Tm_change_flag       Importance: 0.0
# Variable: height               Importance: 0.0
# Variable: Wt                   Importance: 0.0
# Variable: Dash                 Importance: 0.0
# Variable: Vertical             Importance: 0.0
# Variable: Bench                Importance: 0.0
# Variable: Broad_Jump           Importance: 0.0
# Variable: Three_Cone           Importance: 0.0
# Variable: Shuttle              Importance: 0.0
# Variable: ARI                  Importance: 0.0
# Variable: ATL                  Importance: 0.0
# Variable: BAL                  Importance: 0.0
# Variable: BUF                  Importance: 0.0
# Variable: CAR                  Importance: 0.0
# Variable: CHI                  Importance: 0.0
# Variable: CIN                  Importance: 0.0
# Variable: CLE                  Importance: 0.0
# Variable: DAL                  Importance: 0.0
# Variable: DEN                  Importance: 0.0
# Variable: DET                  Importance: 0.0
# Variable: FA                   Importance: 0.0
# Variable: GNB                  Importance: 0.0
# Variable: HOU                  Importance: 0.0
# Variable: IND                  Importance: 0.0
# Variable: JAX                  Importance: 0.0
# Variable: LAC                  Importance: 0.0
# Variable: LAR                  Importance: 0.0
# Variable: MIA                  Importance: 0.0
# Variable: MIN                  Importance: 0.0
# Variable: NOR                  Importance: 0.0
# Variable: NWE                  Importance: 0.0
# Variable: NYG                  Importance: 0.0
# Variable: NYJ                  Importance: 0.0
# Variable: OAK                  Importance: 0.0
# Variable: PIT                  Importance: 0.0
# Variable: SDC                  Importance: 0.0
# Variable: SEA                  Importance: 0.0
# Variable: SFO                  Importance: 0.0
# Variable: STL                  Importance: 0.0
# Variable: TBB                  Importance: 0.0
# Variable: TEN                  Importance: 0.0
# Variable: WAS                  Importance: 0.0
# WR
# residual rank
# points fit
# RB
# residual rank
# points fit
# QB
# residual rank
# points fit
# TE
# residual rank
# points fit
#      Year Pos  ADP_As_Predictor  Model_As_Predictor
# 0  2018.0  WR           23952.5             23952.5
# 1  2018.0  RB           15428.0             15428.0
# 2  2018.0  QB            1462.5              1462.5
# 3  2018.0  TE            1150.0              1150.0

# %%
output_dict = copy.deepcopy(final_dict)

#output_dict['TE'][['Names', 'prediction', 'Overall', 'PPR', 'Win_PCT']]\
#.sort_values('prediction', ascending = False)\
#.to_csv('test.csv', index = False)

output_dict['RB'].sort_values('prediction', ascending = False)[['Names', 'prediction', 'Overall', 'PPR', 'Win_PCT']]
# Out:
#                   Names  prediction  Overall    PPR  Win_PCT
# 16  Christian McCaffrey  272.157300     1.55  385.5     43.8
# 24      Ezekiel Elliott  270.921467     4.89  329.1     62.5
# 7          Alvin Kamara  265.726200     5.42  354.2     81.2
