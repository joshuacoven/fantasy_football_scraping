# %% [markdown]
# # To do

# %% [markdown]
# * Graph labels
# * Likelihood of finishing top 10 in pos, top 20 based on draft slot

# %% [markdown]
# # Import packages and define functions

# %%
###################### Import Packages #############################################
import requests
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
from ffb_functions import *
import seaborn as sns
####################################### Functions ######################################
shifted = pd.read_csv('redraft_metrics.csv')

# %%
for_graphs = pd.read_csv('for_graphs.csv')
shifted.groupby('Year').count()
for_graphs.groupby('Year').count()
for_graphs = for_graphs[['Name', 'Year', 'FantPos', 'Overall', 'PPR', 'pts_next_year']]
for_graphs['ADP_Pos_Rank'] = for_graphs.groupby(['Year', 'FantPos'
                                                           ])['Overall'].rank()
for_graphs['Actual_Next_Pos_Rank'] = for_graphs.groupby(['Year', 'FantPos'])['pts_next_year'
                                               ].rank(ascending = False)
#for_graphs

# %% [markdown]
# # Why RBs get drafted first

# %%
########## together but not on top of each other
plt.style.use('seaborn-deep')

plt.hist([for_graphs['PPR'].loc[for_graphs.FantPos == 'QB'],
         for_graphs['PPR'].loc[for_graphs.FantPos == 'RB'],
         for_graphs['PPR'].loc[for_graphs.FantPos == 'WR'],
         for_graphs['PPR'].loc[for_graphs.FantPos == 'TE']], 
        #alpha = 0.3,
        label = ['QB', 'RB', 'WR', 'TE'])
plt.ylabel('# of players')
plt.xlabel('Points')
plt.title('Distribution of Points (drafted, non-rookies)')
plt.legend(loc='upper right')
plt.savefig('non_rookie_hist.png')
plt.show()
#print('\n')

# Density Plot
for i in ['QB', 'RB', 'WR', 'TE']:
    data = for_graphs.loc[for_graphs.FantPos == i].reset_index(drop = True)
    sns.distplot(data['PPR'], hist=False, 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4}, label = i)
    plt.ylabel('% of players')
    plt.xlabel('Points')
    plt.title('Distribution of Points (drafted, non-rookies)')
plt.savefig('non_rookie_dist.png')
plt.show()

# %% [markdown]
# # Likelihood of finishing in top x of position
# ## Top WR's are more likely to maintain success, but also more likely to bust

# %%
for_graphs = for_graphs.loc[for_graphs.Year != 2018].reset_index(drop = True)
for i in ['QB', 'RB', 'WR', 'TE']:
    print(i)
    data = for_graphs.loc[for_graphs.FantPos == i]
    sns.regplot(x="ADP_Pos_Rank", y="Actual_Next_Pos_Rank", data=data);
    #plt.scatter(for_graphs['ADP_Pos_Rank'].loc[for_graphs.FantPos == i],
     #       for_graphs['Actual_Next_Pos_Rank'].loc[for_graphs.FantPos == i])
    plt.xlabel("ADP Rank Within Position")
    plt.ylabel("Actual Resulting Position Rank")
    plt.title(str(i) + ': ADP as a Predictor')
    plt.tight_layout()
    plt.show()
    
for i in ['QB', 'RB', 'WR', 'TE']:
    print(i)
    data = for_graphs.loc[for_graphs.FantPos == i]
    sns.lmplot(x="ADP_Pos_Rank", y="Actual_Next_Pos_Rank", data=data, x_estimator=np.mean);
    #plt.scatter(for_graphs['ADP_Pos_Rank'].loc[for_graphs.FantPos == i],
     #       for_graphs['Actual_Next_Pos_Rank'].loc[for_graphs.FantPos == i])
    plt.xlabel("ADP Rank Within Position")
    plt.ylabel("Actual Resulting Position Rank")
    plt.title(str(i) + ': ADP as a Predictor')
    plt.tight_layout()
    plt.show()

for i in ['QB', 'RB', 'WR', 'TE']:
    testdf = for_graphs.loc[for_graphs.FantPos == i].reset_index(drop = True)
    testdf = testdf.groupby('ADP_Pos_Rank').median().reset_index()
    #print(testdf)
    plt.plot(testdf['ADP_Pos_Rank'], testdf['Actual_Next_Pos_Rank'], label = i)

plt.xlabel("ADP Rank Within Position")
plt.ylabel("Median Resulting Position Rank")
plt.xlim([0, 40])
plt.ylim([0, 40])
plt.legend()
plt.title('Median Resulting Rank for Each ADP Rank')
plt.show()
# Out:
# QB
# RB
# WR
# TE
# QB
# RB
# WR
# TE

# %%
for_graphs['top_5_finish'] = for_graphs['Actual_Next_Pos_Rank'].apply(lambda x: 1 if x < 6 else 0)
for_graphs['top_10_finish'] = for_graphs['Actual_Next_Pos_Rank'].apply(lambda x: 1 if x < 11 else 0)
for_graphs['top_20_finish'] = for_graphs['Actual_Next_Pos_Rank'].apply(lambda x: 1 if x < 21 else 0)
for_graphs['top_30_finish'] = for_graphs['Actual_Next_Pos_Rank'].apply(lambda x: 1 if x < 31 else 0)
for_graphs['30+_finish'] = 1

for_graphs['top_5_start'] = for_graphs['ADP_Pos_Rank'].apply(lambda x: 1 if x < 6 else 0)
for_graphs['6_10_start'] = for_graphs['ADP_Pos_Rank'].apply(lambda x: 1 if (x < 11) & (x > 5)
                                                            else 0)
for_graphs['11_20_start'] = for_graphs['ADP_Pos_Rank'].apply(lambda x: 1 if (x < 21) & (x > 10)
                                                             else 0)
for_graphs['21_30_start'] = for_graphs['ADP_Pos_Rank'].apply(lambda x: 1 if (x < 31) & (x > 20)
                                                             else 0)
for_graphs['30+_start'] = for_graphs['ADP_Pos_Rank'].apply(lambda x: 1 if x > 30 else 0)

new_frame = pd.DataFrame(columns = ['QB', 'RB', 'WR', 'TE'])
rb_frame = pd.DataFrame(columns = ['top_5_start', '6_10_start', '11_20_start', '21_30_start', 'outside_30_start'])
wr_frame = pd.DataFrame(columns = ['top_5_start', '6_10_start', '11_20_start', '21_30_start', 'outside_30_start'])
qb_frame = pd.DataFrame(columns = ['top_5_start', '6_10_start', '11_20_start', '21_30_start', 'outside_30_start'])
te_frame = pd.DataFrame(columns = ['top_5_start', '6_10_start', '11_20_start', '21_30_start', 'outside_30_start'])

cols = ['top_5_finish', 'top_10_finish', 'top_20_finish', 'top_30_finish', '30+_finish']

for y in ['top_5_start', '6_10_start', '11_20_start', '21_30_start', 'outside_30_start']:
    print(y)
    
    for i in ['QB', 'RB', 'WR', 'TE']:
        #print(i)
        
        test2 = for_graphs.loc[(for_graphs.FantPos == i) & (for_graphs[y] == 1)
                              ].reset_index(drop = True)
        #print(test2)
        val = test2.mean()
        #print(val[cols])
        new_frame[i] = val[cols]
    new_frame = new_frame.fillna(1)
    rb_frame[y] = new_frame['RB']
    wr_frame[y] = new_frame['WR']
    qb_frame[y] = new_frame['QB']
    te_frame[y] = new_frame['TE']
#plt.show()
    new_frame
    #for i in ['30+_finish', 'top_30_finish', 'top_20_finish', 'top_10_finish', 'top_5_finish']:
     #   plt.bar(['QB', 'RB', 'WR', 'TE'], new_frame.loc[i, :], label = i)
    #plt.legend()
    #plt.savefig(str(y) + '_all_likelihood.png')
    #plt.show()
    

print('\n')
print('RB')
for col in ['30+_finish', 'top_30_finish', 'top_20_finish', 'top_10_finish',  'top_5_finish']:
    plt.bar([0, 1, 2, 3, 4]
        #['top_5_start', '6_10_start', '11_20_start', '21_30_start', '30+_start']
            , rb_frame.loc[col, :], label = col, width = 0.25)
plt.legend()
plt.title('RB: likelihood of performance based on draft position')
plt.savefig('rb_likelihood.png')
plt.show()


print('\n')
print('WR')
for col in ['30+_finish', 'top_30_finish', 'top_20_finish', 'top_10_finish',  'top_5_finish']:
    plt.bar(['top_5_start', '6_10_start', '11_20_start', '21_30_start', '30+_start']
            , wr_frame.loc[col, :], label = col)
plt.legend()
plt.title('WR: likelihood of performance based on draft position')
plt.savefig('wr_likelihood.png')

plt.show()

print('\n')
print('QB')
for col in ['30+_finish', 'top_30_finish', 'top_20_finish', 'top_10_finish',  'top_5_finish']:
    plt.bar(['top_5_start', '6_10_start', '11_20_start', '21_30_start', '30+_start']
            , qb_frame.loc[col, :], label = col)
plt.legend()
plt.title('QB: likelihood of performance based on draft position')
plt.savefig('qb_likelihood.png')
plt.show()

print('\n')
print('TE')
for col in ['30+_finish', 'top_30_finish', 'top_20_finish', 'top_10_finish',  'top_5_finish']:
    plt.bar(['top_5_start', '6_10_start', '11_20_start', '21_30_start', '30+_start']
            , te_frame.loc[col, :], label = col)
plt.legend()
plt.title('TE: likelihood of performance based on draft position')
plt.savefig('te_likelihood.png')
plt.show()
# Out:
# top_5_start
# 6_10_start
# 11_20_start
# 21_30_start
# outside_30_start
#
#
# RB
# WR
# QB
# TE

# %% [markdown]
# # How good is positional ADP at predicting rank finish within a position?

# %%
val
new_frame
# Out:
#                          QB          RB          WR         TE
# top_5_start            0.44        0.36         0.4       0.52
# 6_10_start         0.226667    0.293333    0.213333   0.226667
# 11_20_start        0.113333   0.0733333         0.1  0.0805369
# 21_30_start       0.0145985   0.0533333        0.04  0.0227273
# outside_30_start  0.0416667  0.00496278  0.00432277        NaN

# %% [markdown]
# # How good is points at predicting rank finish within a position

# %%
print('WR')
plt.scatter(shifted['PPR'].loc[shifted.FantPos == 'WR'],
            shifted['pts_next_year'].loc[shifted.FantPos == 'WR'])
plt.xlabel("Points Last Year")
plt.ylabel("Points Next Year")
plt.show()
print('\n')

print('QB')
plt.scatter(shifted['PPR'].loc[shifted.FantPos == 'QB'],
            shifted['pts_next_year'].loc[shifted.FantPos == 'QB'])
plt.xlabel("Points Last Year")
plt.ylabel("Points Next Year")
plt.show()
print('\n')

print('RB')
plt.scatter(shifted['PPR'].loc[shifted.FantPos == 'RB'],
            shifted['pts_next_year'].loc[shifted.FantPos == 'RB'])
plt.xlabel("Points Last Year")
plt.ylabel("Points Next Year")
plt.show()
print('\n')

print('TE')
plt.scatter(shifted['PPR'].loc[shifted.FantPos == 'TE'],
            shifted['pts_next_year'].loc[shifted.FantPos == 'TE'])
plt.xlabel("Points Last Year")
plt.ylabel("Points Next Year")
plt.show()
# Out:
# WR
# QB
# RB
# TE

# %%
shifted
# Out:
#        Rk               Name   Tm FantPos   Age     G    GS    Cmp  PaAtt  \
# 0     357         A.J. Derby  2TM      TE  25.0  10.0   3.0    0.0    0.0
# 1     271         A.J. Derby  2TM      TE  26.0  11.0   1.0    0.0    0.0
# 2     388         A.J. Derby  MIA      TE  27.0   4.0   0.0    0.0    0.0
# 3      13         A.J. Green  CIN      WR  24.0  16.0  16.0    0.0    0.0
# 4      12         A.J. Green  CIN      WR  25.0  16.0  16.0    0.0    0.0
# 5      59         A.J. Green  CIN      WR  26.0  13.0  13.0    0.0    0.0
# 4351  179        Zach Miller  SEA      TE  28.0  14.0  12.0    0.0    0.0
# 4352  413        Zach Miller  SEA      TE  29.0   3.0   3.0    0.0    0.0
# 4353  626        Zach Miller  CHI     NaN  30.0   0.0   NaN    0.0    0.0
# 4354  169        Zach Miller  CHI      TE  31.0  15.0  14.0    0.0    0.0
# 4355  172        Zach Miller  CHI      TE  32.0  10.0   8.0    0.0    0.0
# 4356  267        Zach Miller  CHI      TE  33.0   8.0   6.0    0.0    0.0
# 4357  253        Zach Pascal  IND      WR  24.0  16.0   4.0    0.0    0.0
# 4358  504        Zach Potter  JAX      TE  26.0  16.0   5.0    0.0    0.0
# 4359  420       Zach Sudfeld  2TM      TE  24.0  14.0   2.0    0.0    0.0
# 4360  406       Zach Sudfeld  NYJ      TE  25.0  16.0   3.0    0.0    0.0
# 4361  440        Zach Zenner  DET      RB  24.0   6.0   1.0    0.0    0.0
# 4362  167        Zach Zenner  DET      RB  25.0  14.0   4.0    0.0    0.0
# 4363  406        Zach Zenner  DET      RB  26.0   8.0   0.0    0.0    0.0
# 4364  222        Zach Zenner  DET      RB  27.0   8.0   1.0    0.0    0.0
# 4365  230          Zay Jones  BUF      WR  22.0  15.0  10.0    0.0    0.0
# 4366  113          Zay Jones  BUF      WR  23.0  16.0  15.0    0.0    1.0
# 4367  354      Zurlon Tipton  IND      RB  24.0   6.0   0.0    0.0    0.0
# 4368  436      Zurlon Tipton  IND      RB  25.0  10.0   0.0    0.0    0.0
#
#        PaYds     ...      Int_per_PaAtt  Rec_per_tgt  ReTD_per_rec  \
# 0        0.0     ...                NaN     0.800000      0.000000
# 1        0.0     ...                NaN     0.525000      0.095238
# 2        0.0     ...                NaN     0.600000      0.333333
# 3        0.0     ...                NaN     0.591463      0.113402
# 4        0.0     ...                NaN     0.550562      0.112245
# 5        0.0     ...                NaN     0.589744      0.086957
# 6        0.0     ...                NaN     0.651515      0.116279
# 7        0.0     ...                NaN     0.660000      0.060606
# 8        0.0     ...                NaN     0.524476      0.106667
# 9        0.0     ...                NaN     0.597403      0.130435
# 10       0.0     ...                NaN     0.000000           NaN
# 11       0.0     ...                NaN     0.470588      0.000000
# 12       0.0     ...                NaN     0.600000      0.000000
# 13       0.0     ...                NaN          NaN           NaN
# 14     854.0     ...           0.016807          NaN           NaN
# 15       0.0     ...                NaN          NaN           NaN
# 16      66.0     ...           0.000000          NaN           NaN
# 17       8.0     ...           0.000000          NaN           NaN
# 18       0.0     ...                NaN     0.437500      0.000000
# 19       0.0     ...                NaN     0.513889      0.108108
# 20       0.0     ...                NaN     0.600000      0.000000
# 21       0.0     ...                NaN     0.619048      0.000000
# 22       0.0     ...                NaN     0.614458      0.098039
# 23       0.0     ...                NaN     0.500000      0.000000
# 24       0.0     ...                NaN     0.742857      0.038462
# 25       0.0     ...                NaN          NaN           NaN
# 26       0.0     ...                NaN     1.000000      0.000000
# 27       0.0     ...                NaN     0.900000      0.111111
# 28       0.0     ...                NaN     0.700000      0.000000
# 29    4295.0     ...           0.014493     1.000000      0.000000
# 4346             1.0    0.007587
# 4347             0.0    0.013788
# 4348             NaN    0.061679
# 4349             0.0    0.032912
# 4350             NaN    0.072761
# 4351             0.0    0.078539
# 4352             0.0    0.010437
# 4353             1.0         NaN
# 4354             0.0    0.083026
# 4355             0.0    0.095132
# 4356             0.0    0.056967
# 4357             NaN    0.039760
# 4358             NaN    0.002423
# 4359             NaN         NaN
# 4360             1.0    0.012940
# 4361             NaN    0.006071
# 4362             0.0    0.066820
# 4363             0.0    0.006046
# 4364             0.0    0.049386
# 4365             NaN    0.073381
# 4366             0.0    0.184293
# 4367             NaN    0.012228
# 4368             0.0    0.009984
#
# [4369 rows x 60 columns]

# %%
for pos in ['QB', 'RB', 'WR', 'TE']:
    print(pos)
    ycol = 'ppg_next_year'
    xcols = 'PPR'
    frame = shifted.loc[shifted.FantPos == pos].reset_index(drop = True)
    frame = frame[['Name', ycol, xcols]].dropna()
    formula = ycol + " ~ " + xcols
    model = smf.ols(formula, frame)
    results = model.fit(cov_type='cluster', cov_kwds={'groups': frame['Name']})
    print(results.summary())
    print('\n')
# Out:
# QB
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          ppg_next_year   R-squared:                       0.495
# Model:                            OLS   Adj. R-squared:                  0.493
# Method:                 Least Squares   F-statistic:                     451.9
# Date:                Sat, 24 Aug 2019   Prob (F-statistic):           4.54e-39
# Time:                        13:40:58   Log-Likelihood:                -1029.9
# No. Observations:                 340   AIC:                             2064.
# Df Residuals:                     338   BIC:                             2071.
# Df Model:                           1
# Covariance Type:              cluster
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      5.0483      0.461     10.943      0.000       4.144       5.952
# PPR            0.0425      0.002     21.257      0.000       0.039       0.046
# ==============================================================================
# Omnibus:                        6.894   Durbin-Watson:                   2.124
# Prob(Omnibus):                  0.032   Jarque-Bera (JB):                8.361
# Skew:                           0.195   Prob(JB):                       0.0153
# Kurtosis:                       3.662   Cond. No.                         278.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are robust tocluster correlation (cluster)
#
#
# RB
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          ppg_next_year   R-squared:                       0.396
# Model:                            OLS   Adj. R-squared:                  0.395
# Method:                 Least Squares   F-statistic:                     227.4
# Date:                Sat, 24 Aug 2019   Prob (F-statistic):           3.26e-38
# Time:                        13:40:58   Log-Likelihood:                -2089.1
# No. Observations:                 722   AIC:                             4182.
# Df Residuals:                     720   BIC:                             4191.
# Df Model:                           1
# Covariance Type:              cluster
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      2.6705      0.279      9.587      0.000       2.125       3.216
# PPR            0.0430      0.003     15.080      0.000       0.037       0.049
# ==============================================================================
# Omnibus:                       97.334   Durbin-Watson:                   2.078
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              169.550
# Skew:                           0.842   Prob(JB):                     1.52e-37
# Kurtosis:                       4.672   Cond. No.                         177.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are robust tocluster correlation (cluster)
#
#
# WR
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          ppg_next_year   R-squared:                       0.509
# Model:                            OLS   Adj. R-squared:                  0.508
# Method:                 Least Squares   F-statistic:                     764.9
# Date:                Sat, 24 Aug 2019   Prob (F-statistic):           7.26e-90
# Time:                        13:40:58   Log-Likelihood:                -2495.6
# No. Observations:                 905   AIC:                             4995.
# Df Residuals:                     903   BIC:                             5005.
# Df Model:                           1
# Covariance Type:              cluster
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      2.6358      0.193     13.683      0.000       2.258       3.013
# PPR            0.0457      0.002     27.657      0.000       0.043       0.049
# ==============================================================================
# Omnibus:                       38.463   Durbin-Watson:                   2.171
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               42.262
# Skew:                           0.517   Prob(JB):                     6.65e-10
# Kurtosis:                       3.223   Cond. No.                         220.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are robust tocluster correlation (cluster)
#
#
# TE
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          ppg_next_year   R-squared:                       0.461
# Model:                            OLS   Adj. R-squared:                  0.460
# Method:                 Least Squares   F-statistic:                     272.8
# Date:                Sat, 24 Aug 2019   Prob (F-statistic):           1.79e-37
# Time:                        13:40:58   Log-Likelihood:                -1187.6
# No. Observations:                 456   AIC:                             2379.
# Df Residuals:                     454   BIC:                             2387.
# Df Model:                           1
# Covariance Type:              cluster
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.7865      0.279      6.401      0.000       1.240       2.334
# PPR            0.0476      0.003     16.517      0.000       0.042       0.053
# ==============================================================================
# Omnibus:                      201.689   Durbin-Watson:                   1.871
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1225.653
# Skew:                           1.821   Prob(JB):                    7.13e-267
# Kurtosis:                      10.158   Cond. No.                         142.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are robust tocluster correlation (cluster)

# %% [markdown]
# # Position Rank

# %%
new_df = shifted[['Name', 'PosRank', 'FantPos', 'Year']].sort_values(['PosRank', 'Year']).loc[pd.notna(shifted.FantPos)].reset_index(drop = True)
new_df
newer_df = shift_col(new_df, 'PosRankNextYear', 'PosRank', -1).sort_values(['Name', 'Year'])
newer_df
# Out:
#                    Name  PosRank FantPos  Year  PosRankNextYear
# 0            A.J. Derby     62.0      TE  2016             42.0
# 1            A.J. Derby     42.0      TE  2017             77.0
# 2            A.J. Derby     77.0      TE  2018              NaN
# 3            A.J. Green      4.0      WR  2012              5.0
# 4            A.J. Green      5.0      WR  2013             23.0
# 5            A.J. Green     23.0      WR  2014              8.0
# 6            A.J. Green      8.0      WR  2015             35.0
# 7            A.J. Green     35.0      WR  2016             10.0
# 8            A.J. Green     10.0      WR  2017             37.0
# 9            A.J. Green     37.0      WR  2018              NaN
# 10         A.J. Jenkins    133.0      WR  2013            155.0
# 11         A.J. Jenkins    155.0      WR  2014              NaN
# 12        A.J. McCarron     39.0      QB  2015             60.0
# 13        A.J. McCarron     60.0      QB  2017             65.0
# 14        A.J. McCarron     65.0      QB  2018              NaN
# 15      Aaron Burbridge    168.0      WR  2016              NaN
# 16         Aaron Dobson     60.0      WR  2013            179.0
# 17         Aaron Dobson    179.0      WR  2014            146.0
# 18         Aaron Dobson    146.0      WR  2015              NaN
# 19      Aaron Hernandez     16.0      TE  2012              NaN
# 20          Aaron Jones     50.0      RB  2017             23.0
# 21          Aaron Jones     23.0      RB  2018              NaN
# 22      Aaron Ripkowski    146.0      RB  2015             71.0
# 23      Aaron Ripkowski     71.0      RB  2016            127.0
# 24      Aaron Ripkowski    127.0      RB  2017              NaN
# 25        Aaron Rodgers      2.0      QB  2012             21.0
# 26        Aaron Rodgers     21.0      QB  2013              1.0
# 27        Aaron Rodgers      1.0      QB  2014              7.0
# 28        Aaron Rodgers      7.0      QB  2015              1.0
# 29        Aaron Rodgers      1.0      QB  2016             29.0
# ...                 ...      ...     ...   ...              ...
# 3758          Zach Ertz     13.0      TE  2014             10.0
# 3759          Zach Ertz     10.0      TE  2015              8.0
# 3760          Zach Ertz      8.0      TE  2016              3.0
# 3761          Zach Ertz      3.0      TE  2017              3.0
# 3762          Zach Ertz      3.0      TE  2018              NaN
# 3763          Zach Line    157.0      RB  2013             83.0
# 3764          Zach Line     83.0      RB  2015            147.0
# 3765          Zach Line    147.0      RB  2016            115.0
# 3766          Zach Line    115.0      RB  2017             91.0
# 3767          Zach Line     91.0      RB  2018              NaN
# 3768  Zach Mettenberger     38.0      QB  2014             40.0
# 3769  Zach Mettenberger     40.0      QB  2015              NaN
# 3770        Zach Miller     29.0      TE  2012             21.0
# 3771        Zach Miller     21.0      TE  2013             69.0
# 3772        Zach Miller     69.0      TE  2014             17.0
# 3773        Zach Miller     17.0      TE  2015             21.0
# 3774        Zach Miller     21.0      TE  2016             39.0
# 3775        Zach Miller     39.0      TE  2017              NaN
# 3776        Zach Pascal    102.0      WR  2018              NaN
# 3777        Zach Potter     95.0      TE  2012              NaN
# 3778       Zach Sudfeld     75.0      TE  2013             68.0
# 3779       Zach Sudfeld     68.0      TE  2014              NaN
# 3780        Zach Zenner    126.0      RB  2015             48.0
# 3781        Zach Zenner     48.0      RB  2016            116.0
# 3782        Zach Zenner    116.0      RB  2017             67.0
# 3783        Zach Zenner     67.0      RB  2018              NaN
# 3784          Zay Jones     89.0      WR  2017             34.0
# 3785          Zay Jones     34.0      WR  2018              NaN
# 3786      Zurlon Tipton    107.0      RB  2014            125.0
# 3787      Zurlon Tipton    125.0      RB  2015              NaN
#
# [3788 rows x 5 columns]

# %%
for pos in ['QB', 'RB', 'WR', 'TE']:
    print(pos)
    ycol = 'PosRankNextYear'
    xcols = 'PosRank'
    frame = newer_df.loc[newer_df.FantPos == pos].reset_index(drop = True)
    frame = frame[['Name', ycol, xcols]].dropna()
    formula = ycol + " ~ " + xcols
    model = smf.ols(formula, frame)
    results = model.fit(cov_type='cluster', cov_kwds={'groups': frame['Name']})
    print(results.summary())
    print('\n')
# Out:
# QB
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        PosRankNextYear   R-squared:                       0.384
# Model:                            OLS   Adj. R-squared:                  0.382
# Method:                 Least Squares   F-statistic:                     162.1
# Date:                Mon, 26 Aug 2019   Prob (F-statistic):           6.03e-23
# Time:                        11:13:24   Log-Likelihood:                -1575.3
# No. Observations:                 358   AIC:                             3155.
# Df Residuals:                     356   BIC:                             3162.
# Df Model:                           1
# Covariance Type:              cluster
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     12.1944      2.238      5.449      0.000       7.808      16.581
# PosRank        0.7171      0.056     12.732      0.000       0.607       0.828
# ==============================================================================
# Omnibus:                      205.516   Durbin-Watson:                   2.206
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2561.209
# Skew:                           2.136   Prob(JB):                         0.00
# Kurtosis:                      15.387   Cond. No.                         74.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are robust tocluster correlation (cluster)
#
#
# RB
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        PosRankNextYear   R-squared:                       0.324
# Model:                            OLS   Adj. R-squared:                  0.323
# Method:                 Least Squares   F-statistic:                     285.4
# Date:                Mon, 26 Aug 2019   Prob (F-statistic):           4.26e-45
# Time:                        11:13:24   Log-Likelihood:                -3728.3
# No. Observations:                 735   AIC:                             7461.
# Df Residuals:                     733   BIC:                             7470.
# Df Model:                           1
# Covariance Type:              cluster
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     35.7860      2.977     12.020      0.000      29.951      41.621
# PosRank        0.5787      0.034     16.894      0.000       0.512       0.646
# ==============================================================================
# Omnibus:                       11.186   Durbin-Watson:                   2.131
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):               11.409
# Skew:                           0.305   Prob(JB):                      0.00333
# Kurtosis:                       3.014   Cond. No.                         159.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are robust tocluster correlation (cluster)
#
#
# WR
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        PosRankNextYear   R-squared:                       0.340
# Model:                            OLS   Adj. R-squared:                  0.339
# Method:                 Least Squares   F-statistic:                     374.5
# Date:                Mon, 26 Aug 2019   Prob (F-statistic):           3.03e-57
# Time:                        11:13:24   Log-Likelihood:                -4792.8
# No. Observations:                 914   AIC:                             9590.
# Df Residuals:                     912   BIC:                             9599.
# Df Model:                           1
# Covariance Type:              cluster
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     37.7902      3.144     12.019      0.000      31.628      43.953
# PosRank        0.5948      0.031     19.351      0.000       0.535       0.655
# ==============================================================================
# Omnibus:                       14.310   Durbin-Watson:                   2.179
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               13.200
# Skew:                           0.247   Prob(JB):                      0.00136
# Kurtosis:                       2.679   Cond. No.                         191.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are robust tocluster correlation (cluster)
#
#
# TE
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        PosRankNextYear   R-squared:                       0.282
# Model:                            OLS   Adj. R-squared:                  0.281
# Method:                 Least Squares   F-statistic:                     141.6
# Date:                Mon, 26 Aug 2019   Prob (F-statistic):           2.11e-24
# Time:                        11:13:24   Log-Likelihood:                -2261.8
# No. Observations:                 472   AIC:                             4528.
# Df Residuals:                     470   BIC:                             4536.
# Df Model:                           1
# Covariance Type:              cluster
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     22.2203      2.721      8.166      0.000      16.887      27.554
# PosRank        0.6365      0.053     11.900      0.000       0.532       0.741
# ==============================================================================
# Omnibus:                       61.317   Durbin-Watson:                   1.945
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               99.259
# Skew:                           0.819   Prob(JB):                     2.79e-22
# Kurtosis:                       4.537   Cond. No.                         102.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are robust tocluster correlation (cluster)

# %% [markdown]
# # Positional ADP

# %%
adp_frame = ADP_assembly(2010, 2020)
adp_frame
# Out:
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:6211: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
#         #   Bye  Graph   High    Low                  Name  Overall   Pick  \
# 0       1   NaN    NaN   1.01   2.12         Chris Johnson      1.4   1.01
# 1       2   NaN    NaN   1.01   2.11       Adrian Peterson      2.3   1.02
# 2       3   NaN    NaN   1.01   2.10              Ray Rice      3.2   1.03
# 3       4   NaN    NaN   1.01   2.09    Maurice Jones-Drew      4.7   1.05
# 4       5   NaN    NaN   1.01   5.01         Andre Johnson      4.8   1.05
# 5       6   NaN    NaN   1.04   2.08            Frank Gore      6.2   1.06
# 6       7   NaN    NaN   1.01   2.05         Aaron Rodgers      7.8   1.08
# 7       8   NaN    NaN   1.02   5.02            Randy Moss      8.1   1.08
# 8       9   NaN    NaN   1.03   2.06        Michael Turner      9.1   1.09
# 9      10   NaN    NaN   1.05   5.03          Reggie Wayne     11.2   1.11
# 10     11   NaN    NaN   1.05   2.09        Steven Jackson     11.3   1.11
# 11     12   NaN    NaN   1.04   5.06        Calvin Johnson     12.3   1.12
# 12     13   NaN    NaN   1.02   2.12            Drew Brees     13.2   2.01
# 13     14   NaN    NaN   1.06   5.04          Miles Austin     13.9   2.02
# 14     15   NaN    NaN   1.01   5.07           Roddy White     14.8   2.03
# 15     16   NaN    NaN   1.06   3.06          Ryan Mathews     15.4   2.03
# 16     17   NaN    NaN   1.03   5.05      Brandon Marshall     17.3   2.05
# 17     18   NaN    NaN   1.10   5.08      Larry Fitzgerald     19.0   2.07
# 18     19   NaN    NaN   1.06   3.08    Rashard Mendenhall     19.2   2.07
# 19     20   NaN    NaN   1.11   5.11         Greg Jennings     20.4   2.08
# 20     21   NaN    NaN   1.02   3.10        Peyton Manning     20.6   2.09
# 21     22   NaN    NaN   1.08   3.10     DeAngelo Williams     22.3   2.10
# 22     23   NaN    NaN   2.04   6.05        DeSean Jackson     24.7   3.01
# 23     24   NaN    NaN   1.10   4.06        Jamaal Charles     24.9   3.01
# 24     25   NaN    NaN   2.05   5.10       Marques Colston     25.7   3.02
# 25     26   NaN    NaN   1.09   4.01          Shonn Greene     26.8   3.03
# 26     27   NaN    NaN   1.03   4.08             Tom Brady     26.9   3.03
# 27     28   NaN    NaN   1.06   5.09            Wes Welker     27.4   3.03
# 28     29   NaN    NaN   2.01   4.06            Ryan Grant     29.4   3.05
# 29     30   NaN    NaN   1.06   6.06         Anquan Boldin     30.8   3.07
# ...   ...   ...    ...    ...    ...                   ...      ...    ...
# 1822  173   6.0    NaN  11.07  16.04        Devin Funchess    158.8  14.03
# 1823  174   6.0    NaN  11.10  15.12          Cole Beasley    159.6  14.04
# 1824  175  10.0    NaN   9.06  16.06        Chris Thompson    160.1  14.04
# 1825  176   6.0    NaN   5.04  16.11            Derek Carr    160.1  14.04
# 1826  177   4.0    NaN   8.08  16.07      Chris Herndon IV    160.3  14.04
# 1827  178  10.0    NaN  11.03  15.05    Stephen Gostkowski    160.9  14.05
# 22     WR      4.4  PHI           316          NaN  2010
# 23     RB      6.1   KC           342          NaN  2010
# 24     WR      4.1   NO           403          NaN  2010
# 25     RB      5.6  NYJ           218          NaN  2010
# 26     QB      6.1   NE           366          NaN  2010
# 27     WR      4.6   NE           372          NaN  2010
# 28     RB      5.0   GB           321          NaN  2010
# 29     WR      5.3  BAL           352          NaN  2010
# ...   ...      ...  ...           ...          ...   ...
# 1822   WR     13.5  IND            60          NaN  2019
# 1823   WR     11.1  BUF           153          NaN  2019
# 1824   RB     19.1  WAS           104          NaN  2019
# 1825   QB     21.1  OAK            80          NaN  2019
# 1826   TE     17.7  NYJ            45          NaN  2019
# 1827   PK      7.6   NE            88          NaN  2019
# 1828   RB     16.0  LAR           139          NaN  2019
# 1829   QB     12.9  NYJ           128          NaN  2019
# 1830   PK      5.6  HOU            74          NaN  2019
# 1831   WR     15.9  MIA            39          NaN  2019
# 1832   QB     11.7  IND            46          NaN  2019
# 1833  DEF     24.4  PIT            47          NaN  2019
# 1834  DEF     10.1  PHI           302          NaN  2019
# 1835   WR     13.6  TEN            93          NaN  2019
# 1836  DEF     10.8   NE           238          NaN  2019
# 1837   WR     15.9   SF            65          NaN  2019
# 1838   QB     13.8  DET            50          NaN  2019
# 1839   WR     12.8  ATL            46          NaN  2019
# 1840  DEF     11.4   NO            87          NaN  2019
# 1841   RB     19.2  DET            54          NaN  2019
# 1842   WR     11.2   NO            96          NaN  2019
# 1843  DEF     10.1  BUF           131          NaN  2019
# 1844   PK      5.3  PHI           125          NaN  2019
# 1845   PK      5.5  ATL            86          NaN  2019
# 1846   PK      4.9   SF            95          NaN  2019
# 1847   PK      4.6   GB           104          NaN  2019
# 1848   PK      5.0  LAC           107          NaN  2019
# 1849   PK      4.3  DAL            67          NaN  2019
# 1850   PK      3.8  IND            41          NaN  2019
# 1851   PK      5.0  DET            53          NaN  2019
#
# [1852 rows x 14 columns]

# %%
adp_frame.loc[adp_frame.Year == 2019]
# Out:
#         #   Bye  Graph   High    Low                  Name  Overall   Pick  \
# 1650    1  11.0    NaN   1.01   1.05        Saquon Barkley      1.4   1.01
# 1651    2   9.0    NaN   1.01   1.06          Alvin Kamara      2.5   1.02
# 1652    3   7.0    NaN   1.01   1.06   Christian McCaffrey      2.5   1.03
# 1653    4   8.0    NaN   1.01   1.11       Ezekiel Elliott      4.6   1.05
# 1654    5  10.0    NaN   1.01   1.10       DeAndre Hopkins      5.1   1.05
# 1655    6  11.0    NaN   1.01   2.01         Davante Adams      6.8   1.07
# 1656    7  12.0    NaN   1.01   2.05         David Johnson      7.4   1.07
# 1657    8   4.0    NaN   1.02   2.06           LeVeon Bell      8.4   1.08
# 1658    9   9.0    NaN   1.02   2.09           Julio Jones      9.4   1.09
# 1659   10   9.0    NaN   1.03   2.06        Michael Thomas      9.8   1.10
# 1660   11   7.0    NaN   1.04   2.08          James Conner     11.2   1.11
# 1661   12   7.0    NaN   1.02   2.09            Nick Chubb     11.6   1.12
# 1662   13   7.0    NaN   1.02   2.09      Odell Beckham Jr     13.4   2.01
# 1837   WR     15.9   SF            65          NaN  2019
# 1838   QB     13.8  DET            50          NaN  2019
# 1839   WR     12.8  ATL            46          NaN  2019
# 1840  DEF     11.4   NO            87          NaN  2019
# 1841   RB     19.2  DET            54          NaN  2019
# 1842   WR     11.2   NO            96          NaN  2019
# 1843  DEF     10.1  BUF           131          NaN  2019
# 1844   PK      5.3  PHI           125          NaN  2019
# 1845   PK      5.5  ATL            86          NaN  2019
# 1846   PK      4.9   SF            95          NaN  2019
# 1847   PK      4.6   GB           104          NaN  2019
# 1848   PK      5.0  LAC           107          NaN  2019
# 1849   PK      4.3  DAL            67          NaN  2019
# 1850   PK      3.8  IND            41          NaN  2019
# 1851   PK      5.0  DET            53          NaN  2019
#
# [202 rows x 14 columns]

# %% [markdown]
# # Rookies

# %%
rk = pd.read_csv('rookie_database.csv')
rk = rk.rename(columns = {'PPR': 'pts_next_year'})

rk = rk.loc[pd.notna(rk.Name)].reset_index(drop = True)
rk = rk[['Name', 'FantPos', 'Year', 'pts_next_year', 'Overall']]
rk
# Out:
#                    Name FantPos  Year  pts_next_year  Overall
# 0           eli manning      QB  2004           51.2   153.38
# 1      larry fitzgerald      WR  2004          185.4    79.45
# 2         philip rivers      QB  2004            4.8   182.25
# 3        kellen winslow      TE  2004           10.0    71.14
# 4          roy williams      WR  2004          183.8   114.72
# ..                  ...     ...   ...            ...      ...
# 465      terry mclaurin      WR  2019            0.0    96.25
# 466  alexander mattison      RB  2019            0.0   125.71
# 467        tony pollard      RB  2019            0.0   162.33
# 468    ryquell armstead      RB  2019            0.0   201.00
# 469     gardner minshew      QB  2019            0.0   151.40
#
# [470 rows x 5 columns]

# %%
rk.groupby('Year').count()
# Density Plot
for i in ['QB', 'RB', 'WR', 'TE']:
    data = rk.loc[rk.FantPos == i].reset_index(drop = True)
    sns.distplot(data['pts_next_year'], hist=False, 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4}, label = i)
    plt.ylabel('% of players')
    plt.xlabel('Points')
    plt.title('Distribution of Points (drafted, rookies)')
plt.savefig('rookie_dist.png')
plt.show()


plt.style.use('seaborn-deep')
plt.hist([rk['pts_next_year'].loc[rk.FantPos == 'QB'],
         rk['pts_next_year'].loc[rk.FantPos == 'RB'],
         rk['pts_next_year'].loc[rk.FantPos == 'WR'],
         rk['pts_next_year'].loc[rk.FantPos == 'TE']], 
        #alpha = 0.3,
        label = ['QB', 'RB', 'WR', 'TE'])
plt.ylabel('# of players')
plt.xlabel('Points')
plt.title('Distribution of Points (drafted, rookies)')
plt.legend(loc='upper right')
plt.show()

# %%
# need to merge rookie frame with final, to see likelihood of rookie finishing near top of all pos

rk = rk.loc[rk.Year != 2019].reset_index(drop = True)
rk = rk.loc[rk.Year > 2004].reset_index(drop = True)
rk['Year'] = rk['Year'] - 1
rk['rookie'] = 1

non_rk = pd.read_csv('for_graphs.csv')
non_rk = non_rk[['Name', 'Year', 'FantPos', 'pts_next_year', 'Overall']]
non_rk = non_rk.loc[non_rk.Year != 2018].reset_index(drop = True)
non_rk['rookie'] = 0
combined = rk.append(non_rk).reset_index(drop = True)

combined['ADP_Pos_Rank'] = combined.groupby(['Year', 'FantPos'])['Overall'].rank()
combined['Actual_Next_Pos_Rank'] = combined.groupby(['Year', 'FantPos'])['pts_next_year'].rank(ascending = False)

# %%
combined.loc[(combined.rookie == 1) & (combined.ADP_Pos_Rank < 30)]
#combined.loc[(combined.Year == 2002) & (combined.ADP_Pos_Rank < 16) & (combined.rookie == 1)]
#combined.loc[(combined.Year == 2004) & (combined.Actual_Next_Pos_Rank < 10)]
# Out:
#     FantPos               Name  Overall  Year  pts_next_year  rookie  \
# 1        TE  brandon pettigrew   185.86  2004           76.6       1
# 2        QB       mark sanchez   162.60  2004          138.4       1
# 8        RB    knowshon moreno    63.99  2004          198.0       1
# 12       RB       donald brown    97.94  2004           74.0       1
# 17       TE         jared cook   218.24  2004           16.4       1
# ..      ...                ...      ...   ...            ...     ...
# 288      RB        sony michel    70.22  2013          139.1       1
# 289      RB       ronald jones   102.31  2013           20.7       1
# 291      RB      royce freeman    59.01  2013          101.3       1
# 293      TE       mike gesicki   160.36  2013           40.2       1
# 298      TE     jaylen samuels   242.49  2013           89.5       1
#
#      ADP_Pos_Rank  Actual_Next_Pos_Rank  top_5_finish  top_10_finish  \
# 1            21.0                  17.0             0              0
# 2            28.0                  22.0             0              0
# 8            21.0                  13.0             0              0
# 12           27.0                  40.0             0              0
# 17           27.0                  27.0             0              0
# ..            ...                   ...           ...            ...
# 288          24.0                  23.0             0              0
# 289          29.0                  58.0             0              0
# 291          19.0                  33.0             0              0
# 293          16.0                  31.0             0              0
# 298          25.0                  19.0             0              0
#
#      top_20_finish  top_30_finish  30+_finish  top_5_start  6_10_start  \
# 1                1              1           1            0           0
# 2                0              1           1            0           0
# 8                1              1           1            0           0
# 12               0              0           1            0           0
# 17               0              1           1            0           0
# ..             ...            ...         ...          ...         ...
# 288              0              1           1            0           0
# 289              0              0           1            0           0
# 291              0              0           1            0           0
# 293              0              0           1            0           0
# 298              1              1           1            0           0
#
#      11+_start  6_20_start  20+_start
# 1            1           0          1
# 2            1           0          1
# 8            1           0          1
# 12           1           0          1
# 17           1           0          1
# ..         ...         ...        ...
# 288          1           0          1
# 289          1           0          1
# 291          1           1          0
# 293          1           1          0
# 298          1           0          1
#
# [80 rows x 18 columns]

# %%
combined['top_5_finish'] = combined['Actual_Next_Pos_Rank'].apply(lambda x: 1 if x < 6 else 0)
combined['top_10_finish'] = combined['Actual_Next_Pos_Rank'].apply(lambda x: 1 if x < 11 else 0)
combined['top_20_finish'] = combined['Actual_Next_Pos_Rank'].apply(lambda x: 1 if x < 21 else 0)
combined['top_30_finish'] = combined['Actual_Next_Pos_Rank'].apply(lambda x: 1 if x < 31 else 0)
combined['30+_finish'] = 1

combined['top_5_start'] = combined['ADP_Pos_Rank'].apply(lambda x: 1 if x < 6 else 0)
combined['6_20_start'] = combined['ADP_Pos_Rank'].apply(lambda x: 1 if (x < 21) & (x > 5)
                                                            else 0)
combined['20_40_start'] = combined['ADP_Pos_Rank'].apply(lambda x: 1 if (x < 41) & (x > 20)
                                                             else 0)

combined['40+_start'] = combined['ADP_Pos_Rank'].apply(lambda x: 1 if (x > 40)
                                                             else 0)


new_frame = pd.DataFrame(columns = ['QB', 'RB', 'WR', 'TE'])
rb_frame = pd.DataFrame(columns = ['top_5_start', '6_20_start', '20+_start', '21_30_start', 'outside_30_start'])
wr_frame = pd.DataFrame(columns = ['top_5_start', '6_20_start', '20+_start', '21_30_start', 'outside_30_start'])
qb_frame = pd.DataFrame(columns = ['top_5_start', '6_20_start', '20+_start', '21_30_start', 'outside_30_start'])
te_frame = pd.DataFrame(columns = ['top_5_start', '6_20_start', '20+_start', '21_30_start', 'outside_30_start'])

cols = ['top_5_finish', 'top_10_finish', 'top_20_finish', 'top_30_finish', '30+_finish']

for y in ['top_5_start', '6_20_start','20_40_start', '40+_start']:
    print(y)
    
    for i in ['QB', 'RB', 'WR', 'TE']:
        #print(i)
        
        test2 = combined.loc[(combined.FantPos == i) & (combined[y] == 1) & (combined['rookie'] == 1)
                              ].reset_index(drop = True)
        #print(test2)
        val = test2.mean()
        #print(val[cols])
        new_frame[i] = val[cols]
    new_frame = new_frame.fillna(0)
    rb_frame[y] = new_frame['RB']
    wr_frame[y] = new_frame['WR']
    qb_frame[y] = new_frame['QB']
    te_frame[y] = new_frame['TE']
#plt.show()
    new_frame
    for i in ['30+_finish', 'top_30_finish', 'top_20_finish', 'top_10_finish', 'top_5_finish']:
        plt.bar(['QB', 'RB', 'WR', 'TE'], new_frame.loc[i, :], label = i)
    plt.legend()
    plt.show()
    
print('\n')
print('RB')
for col in ['30+_finish', 'top_30_finish', 'top_20_finish', 'top_10_finish',  'top_5_finish']:
    plt.bar(['top_5_start', '6_20_start','20_40_start', '40+_start']
            , rb_frame.loc[col, :], label = col)
plt.legend()
plt.show()


print('\n')
print('WR')
for col in ['30+_finish', 'top_30_finish', 'top_20_finish', 'top_10_finish',  'top_5_finish']:
    plt.bar(['top_5_start', '6_20_start','20_40_start', '40+_start']
            , wr_frame.loc[col, :], label = col)
plt.legend()
plt.show()

print('\n')
print('QB')
for col in ['30+_finish', 'top_30_finish', 'top_20_finish', 'top_10_finish',  'top_5_finish']:
    plt.bar(['top_5_start', '6_20_start','20_40_start', '40+_start']
            , qb_frame.loc[col, :], label = col)
plt.legend()
plt.show()

print('\n')
print('TE')
for col in ['30+_finish', 'top_30_finish', 'top_20_finish', 'top_10_finish',  'top_5_finish']:
    plt.bar(['top_5_start', '6_20_start','20_40_start', '40+_start']
            , te_frame.loc[col, :], label = col)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# top_5_start
# 6_20_start
# 20_40_start
# 40+_start
# RB
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-400-85cf972f2811> in <module>
#      51 for col in ['30+_finish', 'top_30_finish', 'top_20_finish', 'top_10_finish',  'top_5_finish']:
#      52     plt.bar(['top_5_start', '6_20_start','20_40_start', '40+_start']
# ---> 53             , rb_frame.loc[col, :], label = col)
#      54 plt.legend()
#      55 plt.show()
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2438     return gca().bar(
#    2439         x, height, width=width, bottom=bottom, align=align,
# -> 2440         **({"data": data} if data is not None else {}), **kwargs)
#    2441
#    2442
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
#    1600         if data is None:
# -> 1601             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1602
#    1603         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2373         x, height, width, y, linewidth = np.broadcast_arrays(
#    2374             # Make args iterable too.
# -> 2375             np.atleast_1d(x), height, width, y, linewidth)
#    2376
#    2377         # Now that units have been converted, set the tick locations.
#
# <__array_function__ internals> in broadcast_arrays(*args, **kwargs)
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/lib/stride_tricks.py in broadcast_arrays(*args, **kwargs)
#     262     args = [np.array(_m, copy=False, subok=subok) for _m in args]
#     263
# --> 264     shape = _broadcast_shape(*args)
#     265
#     266     if all(array.shape == shape for array in args):
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/lib/stride_tricks.py in _broadcast_shape(*args)
#     189     # use the old-iterator because np.nditer does not handle size 0 arrays
#     190     # consistently
# --> 191     b = np.broadcast(*args[:32])
#     192     # unfortunately, it cannot handle 32 or more arguments directly
#     193     for pos in range(32, len(args), 31):
#
# ValueError: shape mismatch: objects cannot be broadcast to a single shape

# %%
rk
# Out:
#                          Name FantPos  Year  pts_next_year  Overall
# 0                 eli manning      QB  2004           51.2   153.38
# 1            larry fitzgerald      WR  2004          185.4    79.45
# 2               philip rivers      QB  2004            4.8   182.25
# 3              kellen winslow      TE  2004           10.0    71.14
# 4                roy williams      WR  2004          183.8   114.72
# ..                        ...     ...   ...            ...      ...
# 436  marquez valdes-scantling      WR  2018          111.0   295.73
# 437     equanimeous st. brown      WR  2018           54.3   238.18
# 438                john kelly      RB  2018           12.1   210.56
# 439              boston scott      RB  2018            0.0   269.57
# 440            justin jackson      RB  2018           61.1   250.87
#
# [441 rows x 5 columns]
